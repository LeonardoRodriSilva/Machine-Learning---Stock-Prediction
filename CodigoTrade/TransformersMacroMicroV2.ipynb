# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from datetime import datetime

# --- Parâmetros Reais de Mercado (B3 2026) ---
TAXA_NEGOCIACAO_LIQUIDACAO = 0.00030  # 0,03%
TAXA_DAY_TRADE = 0.00023              # 0,023%
SLIPPAGE = 0.0001                     # 0,01%
IR_SWING_TRADE = 0.15                 # 15%
IR_DAY_TRADE = 0.20                   # 20%
ISENCAO_VENDA_MENSAL = 20000          # R$ 20k

# Diretório FLAT onde estão os arquivos de previsões (ALTERADO)
input_dir = r"C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_micro"

# Diretório onde os resultados serão salvos
output_dir = r"C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\MicroResultados"
os.makedirs(output_dir, exist_ok=True)

transactions_dir = os.path.join(output_dir, "Transacoes")
os.makedirs(transactions_dir, exist_ok=True)

# Lista de tickers
tickers = ["BEEF3.SA", "BRFS3.SA", "VALE3.SA", "JBSS3.SA", "SOJA3.SA", 
           "SUZB3.SA", "GGBR3.SA", "CSNA3.SA"]

# Lista de janelas (AJUSTADO para o formato Transformer)
janelas = ["Janela_5", "Janela_10", "Janela_15", "Janela_20"]

def calcular_metricas_risco(historico_patrimonio, saldo_inicial):
    """Calcula Maximum Drawdown e Sharpe Ratio."""
    if not historico_patrimonio or len(historico_patrimonio) < 2:
        return {'max_drawdown': 0.0, 'sharpe_ratio': 0.0}
    
    patrimonio_array = np.array(historico_patrimonio)
    pico = np.maximum.accumulate(patrimonio_array)
    drawdown = (patrimonio_array - pico) / pico
    max_drawdown = np.min(drawdown) * 100
    
    retornos = np.diff(patrimonio_array) / patrimonio_array[:-1]
    if len(retornos) > 0 and np.std(retornos) != 0:
        sharpe_ratio = np.mean(retornos) / np.std(retornos) * np.sqrt(252)
    else:
        sharpe_ratio = 0.0
    
    return {
        'max_drawdown': max_drawdown,
        'sharpe_ratio': sharpe_ratio
    }

def estrategia_all_in_realista(dados_brutos, saldo_inicial):
    """Estratégia All-In com custos reais da B3 e IR CORRIGIDO."""
    dados = dados_brutos.copy()
    dados['Preço Real'] = pd.to_numeric(dados['Preço Real'], errors='coerce')
    dados['Preço Previsto'] = pd.to_numeric(dados['Preço Previsto'], errors='coerce')
    dados['Data'] = pd.to_datetime(dados['Data'])
    
    previsoes = dados['Preço Previsto'].dropna()
    min_previsto = previsoes.min() if len(previsoes) > 0 else None
    max_previsto = previsoes.max() if len(previsoes) > 0 else None
    media_previsoes = previsoes.mean() if len(previsoes) > 0 else None
    
    identifier = dados_brutos['Data'].iloc[0] if not dados_brutos.empty else "Unknown"
    print(f"\n--- Simulação para {identifier} ---")
    print(f"Min: {min_previsto}, Max: {max_previsto}, Média: {media_previsoes}")
    
    # Bloquear previsões extremas
    is_extremely_negative = False
    if min_previsto is not None and isinstance(min_previsto, (int, float)) and min_previsto < -1000:
        is_extremely_negative = True
        print(f"!!! Previsão mínima ({min_previsto}) < -1000. Bloqueando transações. !!!")
    
    if is_extremely_negative:
        diagnostico = {
            'Previsões Razoáveis': False,
            'Estratégia Usada': 'Sem transações - Previsões Negativas',
            'Total de Transações': 0,
            'Retorno (%)': 0.0,
            'Retorno Liquido (%)': 0.0,
            'Max Drawdown (%)': 0.0,
            'Sharpe Ratio': 0.0,
            'Total Custos (R$)': 0.0,
            'Total Impostos (R$)': 0.0,
            'Min Previsto': min_previsto,
            'Max Previsto': max_previsto,
            'Média Previsto': media_previsoes
        }
        return saldo_inicial, [], diagnostico
    
    # Inicializar variáveis
    saldo = saldo_inicial
    quantidade_acoes = 0
    transacoes = []
    historico_patrimonio = [saldo_inicial]
    
    total_custos_operacionais = 0.0
    total_impostos = 0.0
    vendas_no_mes = {}  # ✅ (ano, mês): valor_vendas_acumulado
    data_compra = None
    preco_compra = 0.0
    
    for i in range(len(dados) - 1):
        data_atual = dados.iloc[i]['Data']
        preco_real = dados.iloc[i]['Preço Real']
        
        if pd.isna(preco_real) or preco_real <= 0:
            continue
        
        preco_previsto = dados.iloc[i + 1]['Preço Previsto']
        if pd.isna(preco_previsto):
            continue
        
        # COMPRA
        if quantidade_acoes == 0 and preco_previsto > preco_real:
            preco_com_slippage = preco_real * (1 + SLIPPAGE)
            custos_compra = saldo * (TAXA_NEGOCIACAO_LIQUIDACAO + SLIPPAGE)
            saldo_pos_custo = saldo - custos_compra
            
            if saldo_pos_custo > 0:
                quantidade_acoes = saldo_pos_custo / preco_com_slippage
                valor_investido = quantidade_acoes * preco_com_slippage
                saldo = 0
                total_custos_operacionais += custos_compra
                
                data_compra = data_atual
                preco_compra = preco_com_slippage
                
                transacoes.append({
                    'Data': data_atual,
                    'Acao': 'Compra',
                    'Preco': preco_real,
                    'Preco_Executado': preco_com_slippage,
                    'Quantidade': quantidade_acoes,
                    'Valor_Total': valor_investido,
                    'Custos_Operacionais': custos_compra,
                    'Saldo_Restante': saldo
                })
        
        # VENDA
        elif quantidade_acoes > 0 and preco_previsto < preco_real and i < len(dados) - 2:
            preco_com_slippage = preco_real * (1 - SLIPPAGE)
            valor_bruto_venda = quantidade_acoes * preco_com_slippage
            custos_venda = valor_bruto_venda * (TAXA_NEGOCIACAO_LIQUIDACAO + SLIPPAGE)
            
            is_day_trade = (data_atual.date() == data_compra.date()) if data_compra else False
            
            custo_aquisicao = quantidade_acoes * preco_compra
            lucro_bruto = valor_bruto_venda - custo_aquisicao - custos_venda
            
            imposto = 0.0
            mes_ano = (data_atual.year, data_atual.month)
            
            # ✅ LOG DETALHADO PARA DEBUG
            vendas_mes_atual = vendas_no_mes.get(mes_ano, 0.0)
            print(f"  [VENDA] Data: {data_atual.date()} | Venda: R$ {valor_bruto_venda:.2f} | "
                  f"Vendas Mês {mes_ano}: R$ {vendas_mes_atual:.2f} | Lucro: R$ {lucro_bruto:.2f}")
            
            if lucro_bruto > 0:
                if is_day_trade:
                    # Day Trade: SEMPRE cobra 20%
                    imposto = lucro_bruto * IR_DAY_TRADE
                    print(f"    → DAY TRADE: IR = R$ {imposto:.2f} (20% sobre lucro)")
                else:
                    # ✅ SWING TRADE: Lógica CORRIGIDA
                    vendas_anteriores = vendas_no_mes.get(mes_ano, 0.0)
                    vendas_totais_mes = vendas_anteriores + valor_bruto_venda
                    
                    if vendas_totais_mes > ISENCAO_VENDA_MENSAL:
                        if vendas_anteriores >= ISENCAO_VENDA_MENSAL:
                            # Já ultrapassou antes: tributa TUDO
                            imposto = lucro_bruto * IR_SWING_TRADE
                            print(f"    → SWING: Mês já ultrapassou isenção | IR = R$ {imposto:.2f}")
                        else:
                            # Primeira vez ultrapassando: tributar proporcionalmente
                            valor_excedente = vendas_totais_mes - ISENCAO_VENDA_MENSAL
                            proporcao_tributavel = valor_excedente / valor_bruto_venda
                            lucro_tributavel = lucro_bruto * proporcao_tributavel
                            imposto = lucro_tributavel * IR_SWING_TRADE
                            print(f"    → SWING: 1ª vez ultrapassando | Excedente: R$ {valor_excedente:.2f} | "
                                  f"Proporção: {proporcao_tributavel:.2%} | IR = R$ {imposto:.2f}")
                    else:
                        print(f"    → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00")
                    
                    # Atualizar contador do mês
                    vendas_no_mes[mes_ano] = vendas_totais_mes
            
            valor_liquido_venda = valor_bruto_venda - custos_venda - imposto
            saldo = valor_liquido_venda
            total_custos_operacionais += custos_venda
            total_impostos += imposto
            
            transacoes.append({
                'Data': data_atual,
                'Acao': 'Venda Day Trade' if is_day_trade else 'Venda',
                'Preco': preco_real,
                'Preco_Executado': preco_com_slippage,
                'Quantidade': quantidade_acoes,
                'Valor_Bruto': valor_bruto_venda,
                'Custos_Operacionais': custos_venda,
                'Lucro_Bruto': lucro_bruto,
                'Imposto': imposto,
                'Valor_Liquido': valor_liquido_venda,
                'Saldo_Restante': saldo,
                'Vendas_Acumuladas_Mes': vendas_no_mes.get(mes_ano, 0.0)  # ✅ NOVO CAMPO
            })
            
            quantidade_acoes = 0
            data_compra = None
        
        patrimonio_atual = saldo + (quantidade_acoes * preco_real if quantidade_acoes > 0 else 0)
        historico_patrimonio.append(patrimonio_atual)
    
    # Venda final (MESMA LÓGICA)
    if quantidade_acoes > 0:
        ultimo_preco = dados.iloc[-1]['Preço Real']
        data_final = dados.iloc[-1]['Data']
        
        if not pd.isna(ultimo_preco) and ultimo_preco > 0:
            preco_com_slippage = ultimo_preco * (1 - SLIPPAGE)
            valor_bruto_venda = quantidade_acoes * preco_com_slippage
            custos_venda = valor_bruto_venda * (TAXA_NEGOCIACAO_LIQUIDACAO + SLIPPAGE)
            
            is_day_trade = (data_final.date() == data_compra.date()) if data_compra else False
            
            custo_aquisicao = quantidade_acoes * preco_compra
            lucro_bruto = valor_bruto_venda - custo_aquisicao - custos_venda
            
            imposto = 0.0
            mes_ano = (data_final.year, data_final.month)
            
            if lucro_bruto > 0:
                if is_day_trade:
                    imposto = lucro_bruto * IR_DAY_TRADE
                else:
                    vendas_anteriores = vendas_no_mes.get(mes_ano, 0.0)
                    vendas_totais_mes = vendas_anteriores + valor_bruto_venda
                    
                    if vendas_totais_mes > ISENCAO_VENDA_MENSAL:
                        if vendas_anteriores >= ISENCAO_VENDA_MENSAL:
                            imposto = lucro_bruto * IR_SWING_TRADE
                        else:
                            valor_excedente = vendas_totais_mes - ISENCAO_VENDA_MENSAL
                            proporcao_tributavel = valor_excedente / valor_bruto_venda
                            lucro_tributavel = lucro_bruto * proporcao_tributavel
                            imposto = lucro_tributavel * IR_SWING_TRADE
                    
                    vendas_no_mes[mes_ano] = vendas_totais_mes
            
            valor_liquido_venda = valor_bruto_venda - custos_venda - imposto
            saldo = valor_liquido_venda
            total_custos_operacionais += custos_venda
            total_impostos += imposto
            
            transacoes.append({
                'Data': data_final,
                'Acao': 'Venda Final',
                'Preco': ultimo_preco,
                'Preco_Executado': preco_com_slippage,
                'Quantidade': quantidade_acoes,
                'Valor_Bruto': valor_bruto_venda,
                'Custos_Operacionais': custos_venda,
                'Lucro_Bruto': lucro_bruto,
                'Imposto': imposto,
                'Valor_Liquido': valor_liquido_venda,
                'Saldo_Restante': saldo,
                'Vendas_Acumuladas_Mes': vendas_no_mes.get(mes_ano, 0.0)
            })
    
    # ✅ RESUMO MENSAL DE IR (DEBUG)
    print(f"\n📊 Resumo de Vendas Mensais:")
    for mes_ano, total_vendas in sorted(vendas_no_mes.items()):
        status = "TRIBUTÁVEL" if total_vendas > ISENCAO_VENDA_MENSAL else "ISENTO"
        print(f"  {mes_ano[1]:02d}/{mes_ano[0]}: R$ {total_vendas:,.2f} [{status}]")
    
    metricas_risco = calcular_metricas_risco(historico_patrimonio, saldo_inicial)
    
    retorno_bruto = ((saldo + total_custos_operacionais + total_impostos - saldo_inicial) / saldo_inicial) * 100
    retorno_liquido = ((saldo - saldo_inicial) / saldo_inicial) * 100
    
    previsoes_razoaveis = not is_extremely_negative
    estrategia_usada = 'Trading Realista (B3)' if len(transacoes) > 0 else 'Sem transações'
    
    diagnostico = {
        'Previsões Razoáveis': previsoes_razoaveis,
        'Estratégia Usada': estrategia_usada,
        'Total de Transações': len(transacoes),
        'Retorno Bruto (%)': retorno_bruto,
        'Retorno Liquido (%)': retorno_liquido,
        'Max Drawdown (%)': metricas_risco['max_drawdown'],
        'Sharpe Ratio': metricas_risco['sharpe_ratio'],
        'Total Custos (R$)': total_custos_operacionais,
        'Total Impostos (R$)': total_impostos,
        'Min Previsto': min_previsto,
        'Max Previsto': max_previsto,
        'Média Previsto': media_previsoes
    }
    
    print(f"Resultado: Retorno Líquido={retorno_liquido:.2f}%, Sharpe={metricas_risco['sharpe_ratio']:.2f}, Total IR={total_impostos:.2f}")
    
    return saldo, transacoes, diagnostico

def processar_previsoes_realista(input_dir, tickers, janelas, saldo_inicial):
    """
    Processa previsões com estrutura FLAT de arquivos.
    Formato esperado: TICKER_JANELA_X_previsoes_teste_final.csv
    """
    resultados = []
    todas_transacoes = {}
    todos_diagnosticos = {}
    
    for ticker in tickers:
        print(f"\n{'='*60}")
        print(f"Processando {ticker}...")
        print(f"{'='*60}")
        
        ticker_resultados = {'Ticker': ticker}
        todas_transacoes[ticker] = {}
        todos_diagnosticos[ticker] = {}
        
        for janela in janelas:
            previsoes_file = os.path.join(input_dir, f"{ticker}_{janela}_previsoes_teste_final.csv")
            
            print(f"\n  Buscando: {janela}")
            print(f"  Caminho: {previsoes_file}")
            
            if os.path.exists(previsoes_file):
                try:
                    dados = pd.read_csv(previsoes_file)
                    print(f"  ✓ Arquivo encontrado! Shape: {dados.shape}")
                    
                    saldo_final, transacoes, diagnostico = estrategia_all_in_realista(dados, saldo_inicial)
                    
                    todas_transacoes[ticker][janela] = transacoes
                    todos_diagnosticos[ticker][janela] = diagnostico
                    
                    ticker_resultados[f"Saldo Final {janela}"] = saldo_final
                    ticker_resultados[f"Retorno Liquido {janela} (%)"] = diagnostico['Retorno Liquido (%)']
                    ticker_resultados[f"Sharpe {janela}"] = diagnostico['Sharpe Ratio']
                    ticker_resultados[f"Drawdown {janela} (%)"] = diagnostico['Max Drawdown (%)']
                    ticker_resultados[f"Custos {janela} (R$)"] = diagnostico['Total Custos (R$)']
                    ticker_resultados[f"Impostos {janela} (R$)"] = diagnostico['Total Impostos (R$)']
                    
                except Exception as e:
                    print(f"  ❌ Erro ao processar {ticker} - {janela}: {str(e)}")
                    import traceback
                    traceback.print_exc()
                    
                    ticker_resultados[f"Saldo Final {janela}"] = saldo_inicial
                    ticker_resultados[f"Retorno Liquido {janela} (%)"] = 0.0
            else:
                print(f"  ❌ Arquivo não encontrado!")
                ticker_resultados[f"Saldo Final {janela}"] = saldo_inicial
                ticker_resultados[f"Retorno Liquido {janela} (%)"] = 0.0
        
        resultados.append(ticker_resultados)
    
    return pd.DataFrame(resultados), todas_transacoes, todos_diagnosticos

# --- CÓDIGO PRINCIPAL ---
saldo_inicial = 10000

print("\n" + "="*80)
print(" "*20 + "SIMULAÇÃO REALISTA DE TRADING - B3 2026")
print("="*80)
print(f"Saldo Inicial: R$ {saldo_inicial:,.2f}")
print(f"Taxa B3: {TAXA_NEGOCIACAO_LIQUIDACAO*100:.3f}% | Slippage: {SLIPPAGE*100:.3f}%")
print(f"IR Swing Trade: {IR_SWING_TRADE*100:.1f}% | IR Day Trade: {IR_DAY_TRADE*100:.1f}%")
print(f"Isenção Mensal: R$ {ISENCAO_VENDA_MENSAL:,.2f}")
print(f"Pasta de Dados: {input_dir}")
print("="*80 + "\n")

df_resultados, todas_transacoes, todos_diagnosticos = processar_previsoes_realista(
    input_dir, tickers, janelas, saldo_inicial
)

# Salvar resultados
resultados_filepath = os.path.join(output_dir, "resultados_trading_realista_transformer.csv")
df_resultados.to_csv(resultados_filepath, index=False)
print(f"\n✓ Resultados salvos em: {resultados_filepath}")

# Salvar diagnósticos
diagnosticos_list = []
for ticker in todos_diagnosticos:
    for janela in todos_diagnosticos.get(ticker, {}):
        if todos_diagnosticos[ticker][janela]:
            diagnostico = todos_diagnosticos[ticker][janela].copy()
            diagnostico['Ticker'] = ticker
            diagnostico['Janela'] = janela
            diagnosticos_list.append(diagnostico)

if diagnosticos_list:
    df_diagnosticos = pd.DataFrame(diagnosticos_list)
    diagnosticos_filepath = os.path.join(output_dir, "diagnosticos_trading_realista_transformer.csv")
    df_diagnosticos.to_csv(diagnosticos_filepath, index=False)
    print(f"✓ Diagnósticos salvos em: {diagnosticos_filepath}")

# Salvar transações
for ticker in tickers:
    ticker_dir = os.path.join(transactions_dir, ticker)
    os.makedirs(ticker_dir, exist_ok=True)
    
    for janela in janelas:
        if janela in todas_transacoes.get(ticker, {}):
            transacoes = todas_transacoes[ticker][janela]
            
            if transacoes:
                df_transacoes = pd.DataFrame(transacoes)
                transacoes_filepath = os.path.join(ticker_dir, f"{ticker}_{janela}_transacoes_realista.csv")
                df_transacoes.to_csv(transacoes_filepath, index=False)

# Identificar melhor janela por Sharpe Ratio
melhores_resultados = []
for _, row in df_resultados.iterrows():
    ticker = row['Ticker']
    melhor_janela = None
    melhor_sharpe = -np.inf
    
    for janela in janelas:
        sharpe = row.get(f"Sharpe {janela}", -np.inf)
        saldo = row.get(f"Saldo Final {janela}", 0)
        
        if sharpe > melhor_sharpe and saldo > saldo_inicial * 0.95:
            melhor_sharpe = sharpe
            melhor_janela = janela
    
    if melhor_janela:
        melhores_resultados.append({
            'Ticker': ticker,
            'Melhor Janela': melhor_janela,
            'Saldo Final': row[f"Saldo Final {melhor_janela}"],
            'Retorno Liquido (%)': row[f"Retorno Liquido {melhor_janela} (%)"],
            'Sharpe Ratio': melhor_sharpe,
            'Drawdown (%)': row[f"Drawdown {melhor_janela} (%)"],
            'Custos (R$)': row[f"Custos {melhor_janela} (R$)"],
            'Impostos (R$)': row[f"Impostos {melhor_janela} (R$)"]
        })

if melhores_resultados:
    df_melhores = pd.DataFrame(melhores_resultados).sort_values(by='Sharpe Ratio', ascending=False)
    
    melhores_filepath = os.path.join(output_dir, "melhores_resultados_realista_transformer.csv")
    df_melhores.to_csv(melhores_filepath, index=False)
    print(f"✓ Melhores resultados salvos em: {melhores_filepath}")
    
    # Gráfico com escala ajustada
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(18, 14))
    
    # Gráfico 1: Retorno Líquido
    colors = ['darkgreen' if r > 10 else 'green' if r > 0 else 'red' for r in df_melhores['Retorno Liquido (%)']]
    bars = ax1.bar(df_melhores['Ticker'], df_melhores['Saldo Final'], 
                   color=colors, edgecolor='black', linewidth=1.5, alpha=0.8)
    ax1.axhline(y=saldo_inicial, color='blue', linestyle='--', linewidth=2.5, 
                label=f'Saldo Inicial: R$ {saldo_inicial:,.2f}')
    
    max_saldo = df_melhores['Saldo Final'].max()
    ax1.set_ylim(0, max_saldo * 1.25)
    
    for i, bar in enumerate(bars):
        row = df_melhores.iloc[i]
        saldo = row['Saldo Final']
        retorno = row['Retorno Liquido (%)']
        janela = row['Melhor Janela']
        custos = row['Custos (R$)']
        impostos = row['Impostos (R$)']
        
        offset = max_saldo * 0.03
        ax1.text(i, saldo + offset, 
                f"R$ {saldo:,.0f}\n{retorno:+.1f}%\n{janela}\nC: R${custos:.0f} | I: R${impostos:.0f}",
                ha='center', va='bottom', fontsize=10, fontweight='bold')
    
    ax1.set_title('🤖 Transformers - Trading Realista 2023 (Retorno Líquido)', 
                  fontsize=16, fontweight='bold', pad=20)
    ax1.set_ylabel('Saldo Final (R$)', fontsize=13, fontweight='bold')
    ax1.legend(fontsize=11, loc='upper left')
    ax1.grid(axis='y', alpha=0.4, linestyle='--')
    ax1.set_axisbelow(True)
    
    # Gráfico 2: Sharpe Ratio
    colors2 = ['darkgreen' if s > 1.5 else 'green' if s > 0.5 else 'orange' if s > 0 else 'darkred' 
               for s in df_melhores['Sharpe Ratio']]
    ax2.bar(df_melhores['Ticker'], df_melhores['Sharpe Ratio'], 
            color=colors2, edgecolor='black', linewidth=1.5, alpha=0.8)
    ax2.axhline(y=0, color='black', linestyle='-', linewidth=1.5)
    ax2.axhline(y=1, color='green', linestyle='--', linewidth=2, 
                label='Sharpe > 1 (Bom)', alpha=0.7)
    
    max_sharpe = df_melhores['Sharpe Ratio'].max()
    min_sharpe = df_melhores['Sharpe Ratio'].min()
    sharpe_range = max_sharpe - min_sharpe
    ax2.set_ylim(min_sharpe - sharpe_range * 0.2, max_sharpe + sharpe_range * 0.3)
    
    for i, (idx, row) in enumerate(df_melhores.iterrows()):
        sharpe = row['Sharpe Ratio']
        drawdown = row['Drawdown (%)']
        
        offset = sharpe_range * 0.08 if sharpe > 0 else -sharpe_range * 0.08
        ax2.text(i, sharpe + offset, 
                f"{sharpe:.2f}\nDD: {drawdown:.1f}%", 
                ha='center', va='bottom' if sharpe > 0 else 'top', 
                fontsize=10, fontweight='bold')
    
    ax2.set_title('📊 Sharpe Ratio e Maximum Drawdown', 
                  fontsize=16, fontweight='bold', pad=20)
    ax2.set_xlabel('Ticker', fontsize=13, fontweight='bold')
    ax2.set_ylabel('Sharpe Ratio', fontsize=13, fontweight='bold')
    ax2.legend(fontsize=11, loc='upper left')
    ax2.grid(axis='y', alpha=0.4, linestyle='--')
    ax2.set_axisbelow(True)
    
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    
    grafico_filepath = os.path.join(output_dir, "trading_realista_transformer_completo.png")
    plt.savefig(grafico_filepath, dpi=300, bbox_inches='tight')
    print(f"✓ Gráfico salvo em: {grafico_filepath}")
    plt.show()

print("\n" + "="*80)
print(" "*30 + "✅ EXECUÇÃO CONCLUÍDA")
print("="*80)
# Out:
# ================================================================================
#                     SIMULAÇÃO REALISTA DE TRADING - B3 2026
# ================================================================================
# Saldo Inicial: R$ 10,000.00
# Taxa B3: 0.030% | Slippage: 0.010%
# IR Swing Trade: 15.0% | IR Day Trade: 20.0%
# Isenção Mensal: R$ 20,000.00
# Pasta de Dados: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_micro
# ================================================================================
#
#
# ============================================================
# Processando BEEF3.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_micro\BEEF3.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (360, 3)
#
# --- Simulação para 2023-01-06 ---
# Min: 10.299587, Max: 10.649377, Média: 10.450620194444443
#   [VENDA] Data: 2023-03-03 | Venda: R$ 10720.84 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ 720.55
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-03-16 | Venda: R$ 10941.90 | Vendas Mês (2023, 3): R$ 10720.84 | Lucro: R$ 225.26
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 1662.74 | Proporção: 15.20% | IR = R$ 5.13
#   [VENDA] Data: 2023-06-06 | Venda: R$ 11543.58 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ 610.95
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-09 | Venda: R$ 11910.68 | Vendas Mês (2023, 6): R$ 11543.58 | Lucro: R$ 371.56
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 3454.26 | Proporção: 29.00% | IR = R$ 16.16
#   [VENDA] Data: 2023-08-04 | Venda: R$ 11927.20 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ 37.44
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-08-09 | Venda: R$ 12061.14 | Vendas Mês (2023, 8): R$ 11927.20 | Lucro: R$ 138.65
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 3988.34 | Proporção: 33.07% | IR = R$ 6.88
#   [VENDA] Data: 2023-08-17 | Venda: R$ 12410.15 | Vendas Mês (2023, 8): R$ 23988.34 | Lucro: R$ 360.57
#     → SWING: Mês já ultrapassou isenção | IR = R$ 54.09
#   [VENDA] Data: 2023-08-28 | Venda: R$ 12862.93 | Vendas Mês (2023, 8): R$ 36398.49 | Lucro: R$ 511.62
#     → SWING: Mês já ultrapassou isenção | IR = R$ 76.74
#
# 📊 Resumo de Vendas Mensais:
#   03/2023: R$ 21,662.74 [TRIBUTÁVEL]
#   06/2023: R$ 23,454.26 [TRIBUTÁVEL]
#   08/2023: R$ 49,261.41 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=7.05%, Sharpe=0.32, Total IR=159.00
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_micro\BEEF3.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 9.558731, Max: 10.342998, Média: 9.819294973239435
#   [VENDA] Data: 2023-05-19 | Venda: R$ 10483.40 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 483.20
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-31 | Venda: R$ 11000.33 | Vendas Mês (2023, 5): R$ 10483.40 | Lucro: R$ 520.92
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 1483.73 | Proporção: 13.49% | IR = R$ 10.54
#   [VENDA] Data: 2023-07-13 | Venda: R$ 11225.77 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ 240.28
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-21 | Venda: R$ 11396.16 | Vendas Mês (2023, 7): R$ 11225.77 | Lucro: R$ 174.81
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 2621.93 | Proporção: 23.01% | IR = R$ 6.03
#   [VENDA] Data: 2023-07-31 | Venda: R$ 11959.53 | Vendas Mês (2023, 7): R$ 22621.93 | Lucro: R$ 573.73
#     → SWING: Mês já ultrapassou isenção | IR = R$ 86.06
#
# 📊 Resumo de Vendas Mensais:
#   05/2023: R$ 21,483.73 [TRIBUTÁVEL]
#   07/2023: R$ 34,581.45 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=-0.59%, Sharpe=0.10, Total IR=102.63
#
#   Buscando: Janela_15
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_micro\BEEF3.SA_Janela_15_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (350, 3)
#
# --- Simulação para 2023-01-16 ---
# Min: 7.9201393, Max: 9.075936, Média: 8.219927020857142
#   [VENDA] Data: 2023-04-27 | Venda: R$ 10175.93 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ 175.86
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-03 | Venda: R$ 10512.04 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 340.04
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-06 | Venda: R$ 10660.44 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 152.55
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#
# 📊 Resumo de Vendas Mensais:
#   04/2023: R$ 10,175.93 [ISENTO]
#   05/2023: R$ 10,512.04 [ISENTO]
#   11/2023: R$ 10,660.44 [ISENTO]
# Resultado: Retorno Líquido=0.92%, Sharpe=0.13, Total IR=0.00
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_micro\BEEF3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 7.8991227, Max: 9.001126, Média: 8.26491961652174
#   [VENDA] Data: 2023-04-27 | Venda: R$ 10175.93 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ 175.86
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-03 | Venda: R$ 10512.04 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 340.04
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-09-30 | Venda: R$ 10501.53 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ -6.30
#   [VENDA] Data: 2023-10-06 | Venda: R$ 10569.03 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ 71.67
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-06 | Venda: R$ 10718.24 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 153.38
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#
# 📊 Resumo de Vendas Mensais:
#   04/2023: R$ 10,175.93 [ISENTO]
#   05/2023: R$ 10,512.04 [ISENTO]
#   10/2023: R$ 10,569.03 [ISENTO]
#   11/2023: R$ 10,718.24 [ISENTO]
# Resultado: Retorno Líquido=1.46%, Sharpe=0.15, Total IR=0.00
#
# ============================================================
# Processando BRFS3.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_micro\BRFS3.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (360, 3)
#
# --- Simulação para 2023-01-06 ---
# Min: 11.584164, Max: 15.37282, Média: 12.758272259722222
#
# 📊 Resumo de Vendas Mensais:
#   12/2023: R$ 15,974.21 [ISENTO]
# Resultado: Retorno Líquido=59.68%, Sharpe=0.91, Total IR=0.00
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_micro\BRFS3.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 9.632932, Max: 14.673634, Média: 11.052629663380282
#   [VENDA] Data: 2023-11-06 | Venda: R$ 15120.95 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 5118.90
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-14 | Venda: R$ 15381.57 | Vendas Mês (2023, 11): R$ 15120.95 | Lucro: R$ 266.57
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 10502.52 | Proporção: 68.28% | IR = R$ 27.30
#   [VENDA] Data: 2023-11-16 | Venda: R$ 16570.33 | Vendas Mês (2023, 11): R$ 30502.52 | Lucro: R$ 1221.72
#     → SWING: Mês já ultrapassou isenção | IR = R$ 183.26
#   [VENDA] Data: 2023-12-01 | Venda: R$ 16951.29 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-09 | Venda: R$ 10646.29 | Vendas Mês (2023, 5): R$ 10662.94 | Lucro: R$ -12.37
#   [VENDA] Data: 2023-06-06 | Venda: R$ 10832.38 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ 190.27
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-09 | Venda: R$ 10870.57 | Vendas Mês (2023, 6): R$ 10832.38 | Lucro: R$ 42.51
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 1702.95 | Proporção: 15.67% | IR = R$ 1.00
#   [VENDA] Data: 2023-06-11 | Venda: R$ 10858.71 | Vendas Mês (2023, 6): R$ 21702.95 | Lucro: R$ -6.52
#   [VENDA] Data: 2023-06-27 | Venda: R$ 11114.98 | Vendas Mês (2023, 6): R$ 21702.95 | Lucro: R$ 260.51
#     → SWING: Mês já ultrapassou isenção | IR = R$ 39.08
#   [VENDA] Data: 2023-06-29 | Venda: R$ 11802.92 | Vendas Mês (2023, 6): R$ 32817.93 | Lucro: R$ 731.17
#     → SWING: Mês já ultrapassou isenção | IR = R$ 109.68
#
# 📊 Resumo de Vendas Mensais:
#   04/2023: R$ 10,340.61 [ISENTO]
#   05/2023: R$ 10,662.94 [ISENTO]
#   06/2023: R$ 44,620.85 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=16.89%, Sharpe=0.92, Total IR=149.75
#
# ============================================================
# Processando SOJA3.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_micro\SOJA3.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (360, 3)
#
# --- Simulação para 2023-01-06 ---
# Min: 9.104235, Max: 13.104307, Média: 10.005742445833334
#
# 📊 Resumo de Vendas Mensais:
# Resultado: Retorno Líquido=0.00%, Sharpe=0.00, Total IR=0.00
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_micro\SOJA3.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 10.725476, Max: 14.472144, Média: 12.160866015492958
#   [VENDA] Data: 2023-08-18 | Venda: R$ 12694.41 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ 2693.34
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-08-22 | Venda: R$ 13100.01 | Vendas Mês (2023, 8): R$ 12694.41 | Lucro: R$ 410.51
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 5794.43 | Proporção: 44.23% | IR = R$ 27.24
#   [VENDA] Data: 2023-08-28 | Venda: R$ 13331.38 | Vendas Mês (2023, 8): R$ 25794.43 | Lucro: R$ 263.74
#     → SWING: Mês já ultrapassou isenção | IR = R$ 39.56
#   [VENDA] Data: 2023-09-12 | Venda: R$ 13443.58 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ 157.03
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-09-20 | Venda: R$ 13206.00 | Vendas Mês (2023, 9): R$ 13443.58 | Lucro: R$ -232.12
#   [VENDA] Data: 2023-09-22 | Venda: R$ 13308.60 | Vendas Mês (2023, 9): R$ 13443.58 | Lucro: R$ 107.85
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 6752.19 | Proporção: 50.74% | IR = R$ 8.21
#   [VENDA] Data: 2023-11-08 | Venda: R$ 13127.16 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ -167.84
#   [VENDA] Data: 2023-11-10 | Venda: R$ 14044.46 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 922.18
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-23 | Venda: R$ 13926.56 | Vendas Mês (2023, 11): R$ 14044.46 | Lucro: R$ -112.24
#   [VENDA] Data: 2023-12-05 | Venda: R$ 13995.67 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ 74.65
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12-07 | Venda: R$ 14614.07 | Vendas Mês (2023, 12): R$ 13995.67 | Lucro: R$ 623.75
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 8609.75 | Proporção: 58.91% | IR = R$ 55.12
#
# 📊 Resumo de Vendas Mensais:
#   08/2023: R$ 39,125.81 [TRIBUTÁVEL]
#   09/2023: R$ 26,752.19 [TRIBUTÁVEL]
#   11/2023: R$ 14,044.46 [ISENTO]
#   12/2023: R$ 28,609.75 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=45.53%, Sharpe=1.10, Total IR=130.13
#
#   Buscando: Janela_15
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_micro\SOJA3.SA_Janela_15_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (350, 3)
#
# --- Simulação para 2023-01-16 ---
# Min: 9.717337, Max: 13.75634, Média: 11.058312101428571
#   [VENDA] Data: 2023-01-20 | Venda: R$ 10431.76 | Vendas Mês (2023, 1): R$ 0.00 | Lucro: R$
| Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ 222.72
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-12 | Venda: R$ 9968.56 | Vendas Mês (2023, 6): R$ 9918.71 | Lucro: R$ 53.80
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-15 | Venda: R$ 10231.64 | Vendas Mês (2023, 6): R$ 19887.27 | Lucro: R$ 266.96
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 10118.91 | Proporção: 98.90% | IR = R$ 39.60
#   [VENDA] Data: 2023-07-24 | Venda: R$ 9490.40 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ -697.27
#   [VENDA] Data: 2023-07-26 | Venda: R$ 9740.83 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ 254.13
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-30 | Venda: R$ 9731.10 | Vendas Mês (2023, 7): R$ 9740.83 | Lucro: R$ -5.84
#   [VENDA] Data: 2023-08-03 | Venda: R$ 10076.61 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ 349.26
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-08-11 | Venda: R$ 10046.51 | Vendas Mês (2023, 8): R$ 10076.61 | Lucro: R$ -26.06
#   [VENDA] Data: 2023-08-14 | Venda: R$ 10186.50 | Vendas Mês (2023, 8): R$ 10076.61 | Lucro: R$ 143.96
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 263.11 | Proporção: 2.58% | IR = R$ 0.56
#   [VENDA] Data: 2023-08-17 | Venda: R$ 10248.97 | Vendas Mês (2023, 8): R$ 20263.11 | Lucro: R$ 67.07
#     → SWING: Mês já ultrapassou isenção | IR = R$ 10.06
#   [VENDA] Data: 2023-09-01 | Venda: R$ 10313.44 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ 78.60
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-09-11 | Venda: R$ 10075.29 | Vendas Mês (2023, 9): R$ 10313.44 | Lucro: R$ -233.93
#   [VENDA] Data: 2023-09-14 | Venda: R$ 10257.43 | Vendas Mês (2023, 9): R$ 10313.44 | Lucro: R$ 186.10
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 570.87 | Proporção: 5.57% | IR = R$ 1.55
#   [VENDA] Data: 2023-09-20 | Venda: R$ 10705.93 | Vendas Mês (2023, 9): R$ 20570.87 | Lucro: R$ 453.97
#     → SWING: Mês já ultrapassou isenção | IR = R$ 68.10
#   [VENDA] Data: 2023-10-03 | Venda: R$ 10607.98 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ -25.56
#   [VENDA] Data: 2023-10-06 | Venda: R$ 10828.59 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ 224.76
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-13 | Venda: R$ 11272.04 | Vendas Mês (2023, 10): R$ 10828.59 | Lucro: R$ 447.60
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 2100.63 | Proporção: 18.64% | IR = R$ 12.51
#   [VENDA] Data: 2023-10-17 | Venda: R$ 11038.89 | Vendas Mês (2023, 10): R$ 22100.63 | Lucro: R$ -216.03
#
# 📊 Resumo de Vendas Mensais:
#   01/2023: R$ 10,198.95 [ISENTO]
#   02/2023: R$ 9,697.96 [ISENTO]
#   03/2023: R$ 9,970.32 [ISENTO]
#   04/2023: R$ 8,864.91 [ISENTO]
#   05/2023: R$ 37,525.45 [TRIBUTÁVEL]
#   06/2023: R$ 30,118.91 [TRIBUTÁVEL]
#   07/2023: R$ 9,740.83 [ISENTO]
#   08/2023: R$ 30,512.08 [TRIBUTÁVEL]
#   09/2023: R$ 31,276.79 [TRIBUTÁVEL]
#   10/2023: R$ 22,100.63 [TRIBUTÁVEL]
#   12/2023: R$ 11,195.20 [ISENTO]
# Resultado: Retorno Líquido=11.91%, Sharpe=0.50, Total IR=166.48
#
#   Buscando: Janela_15
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_micro\SUZB3.SA_Janela_15_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (350, 3)
#
# --- Simulação para 2023-01-16 ---
# Min: 36.08075, Max: 55.738304, Média: 45.905466045714284
#   [VENDA] Data: 2023-01-24 | Venda: R$ 9522.96 | Vendas Mês (2023, 1): R$ 0.00 | Lucro: R$
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 1328.02 | Proporção: 12.41% | IR = R$ 1.56
#   [VENDA] Data: 2023-07-12 | Venda: R$ 11006.42 | Vendas Mês (2023, 7): R$ 21328.02 | Lucro: R$ 308.39
#     → SWING: Mês já ultrapassou isenção | IR = R$ 46.26
#   [VENDA] Data: 2023-08-14 | Venda: R$ 10498.22 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ -457.36
#   [VENDA] Data: 2023-08-19 | Venda: R$ 10487.72 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ -6.29
#   [VENDA] Data: 2023-08-22 | Venda: R$ 10590.76 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ 107.19
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-08-29 | Venda: R$ 10760.35 | Vendas Mês (2023, 8): R$ 10590.76 | Lucro: R$ 173.76
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 1351.10 | Proporção: 12.56% | IR = R$ 3.27
#   [VENDA] Data: 2023-09-01 | Venda: R$ 10808.67 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ 55.88
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-09-04 | Venda: R$ 10872.63 | Vendas Mês (2023, 9): R$ 10808.67 | Lucro: R$ 68.25
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 1681.30 | Proporção: 15.46% | IR = R$ 1.58
#   [VENDA] Data: 2023-11-10 | Venda: R$ 10005.34 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ -861.01
#
# 📊 Resumo de Vendas Mensais:
#   02/2023: R$ 10,162.02 [ISENTO]
#   03/2023: R$ 10,201.77 [ISENTO]
#   04/2023: R$ 10,280.44 [ISENTO]
#   05/2023: R$ 10,231.74 [ISENTO]
#   06/2023: R$ 20,856.94 [TRIBUTÁVEL]
#   07/2023: R$ 32,334.44 [TRIBUTÁVEL]
#   08/2023: R$ 21,351.10 [TRIBUTÁVEL]
#   09/2023: R$ 21,681.30 [TRIBUTÁVEL]
#   12/2023: R$ 10,190.76 [ISENTO]
# Resultado: Retorno Líquido=1.87%, Sharpe=0.17, Total IR=57.33
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_micro\GGBR3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 16.941538, Max: 20.850597, Média: 18.97463323188406
#   [VENDA] Data: 2023-03-12 | Venda: R$ 9851.65 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ -148.29
#   [VENDA] Data: 2023-03-14 | Venda: R$ 9970.81 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ 123.06
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-03-19 | Venda: R$ 9921.93 | Vendas Mês (2023, 3): R$ 9970.81 | Lucro: R$ -44.87
#   [VENDA] Data: 2023-03-21 | Venda: R$ 10017.59 | Vendas Mês (2023, 3): R$ 9970.81 | Lucro: R$ 99.58
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-04-10 | Venda: R$ 9938.92 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -74.63
#   [VENDA] Data: 2023-04-28 | Venda: R$ 9944.78 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ 9.83
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-03 | Venda: R$ 10048.70 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 107.86
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-05 | Venda: R$ 10504.78 | Vendas Mês (2023, 5): R$ 10048.70 | Lucro: R$ 459.92
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 553.49 | Proporção: 5.27% | IR = R$ 3.63
#   [VENDA] Data: 2023-05-17 | Venda: R$ 10604.50 | Vendas Mês (2023, 5): R$ 20553.49 | Lucro: R$ 107.51
#     → SWING: Mês já ultrapassou isenção | IR = R$ 16.13
#   [VENDA] Data: 2023-05-22 | Venda: R$ 11021.45 | Vendas Mês (2023, 5): R$ 31157.99 | Lucro: R$ 437.15
#     → SWING: Mês já ultrapassou isenção | IR = R$ 65.57
#   [VENDA] Data: 2023-05-26 | Venda: R$ 11168.63 | Vendas Mês (2023, 5): R$ 42179.44 | Lucro: R$ 217.07
#     → SWING: Mês já ultrapassou isenção | IR = R$ 32.56
#   [VENDA] Data: 2023-06-02 | Venda: R$ 11472.58 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ 340.84
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-23 | Venda: R$ 11447.44 | Vendas Mês (2023, 6): R$ 11472.58 | Lucro: R$ -20.54
#   [VENDA] Data: 2023-08-10 | Venda: R$ 11444.85 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ 1.98
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-09-20 | Venda: R$ 11447.16 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ 6.89
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-09-23 | Venda: R$ 11374.76 | Vendas Mês (2023, 9): R$ 11447.16 | Lucro: R$ -67.79
#   [VENDA] Data: 2023-10-16 | Venda: R$ 10770.85 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ -599.12
#   [VENDA] Data: 2023-10-23 | Venda: R$ 10485.42 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ -281.01
#   [VENDA] Data: 2023-11-03 | Venda: R$ 11106.83 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 625.36
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-10 | Venda: R$ 11537.62 | Vendas Mês (2023, 11): R$ 11106.83 | Lucro: R$ 435.05
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 2644.45 | Proporção: 22.92% | IR = R$ 14.96
#   [VENDA] Data: 2023-11-14 | Venda: R$ 11704.93 | Vendas Mês (2023, 11): R$ 22644.45 | Lucro: R$ 186.81
#     → SWING: Mês já ultrapassou isenção | IR = R$ 28.02
#   [VENDA] Data: 2023-12-05 | Venda: R$ 11289.91 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ -382.17
#   [VENDA] Data: 2023-12-13 | Venda: R$ 11524.13 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ 238.65
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12-18 | Venda: R$ 11666.25 | Vendas Mês (2023, 12): R$ 11524.13 | Lucro: R$ 146.66
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 3190.38 | Proporção: 27.35% | IR = R$ 6.02
#   [VENDA] Data: 2023-12-21 | Venda: R$ 11871.80 | Vendas Mês (2023, 12): R$ 23190.38 | Lucro: R$ 216.15
#     → SWING: Mês já ultrapassou isenção | IR = R$ 32.42
#   [VENDA] Data: 2023-12-28 | Venda: R$ 11882.54 | Vendas Mês (2023, 12): R$ 35062.18 | Lucro: R$ 47.89
#     → SWING: Mês já ultrapassou isenção | IR = R$ 7.18
#
# 📊 Resumo de Vendas Mensais:
#   03/2023: R$ 19,988.40 [ISENTO]
#   04/2023: R$ 9,944.78 [ISENTO]
#   05/2023: R$ 53,348.07 [TRIBUTÁVEL]
#   06/2023: R$ 11,472.58 [ISENTO]
#   08/2023: R$ 11,444.85 [ISENTO]
#   09/2023: R$ 11,447.16 [ISENTO]
#   11/2023: R$ 34,349.38 [TRIBUTÁVEL]
#   12/2023: R$ 46,944.73 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=18.71%, Sharpe=1.04, Total IR=206.50
#
# ============================================================
# Processando CSNA3.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_micro\CSNA3.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (360, 3)
#
# --- Simulação para 2023-01-06 ---
# Min: 18.475657, Max: 23.640995, Média: 20.225609483333333
#
# 📊 Resumo de Vendas Mensais:
#   12/2023: R$ 13,198.36 [ISENTO]
# Resultado: Retorno Líquido=31.93%, Sharpe=0.76, Total IR=0.00
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_micro\CSNA3.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 8.906538, Max: 13.415988, Média: 10.631024608450703
#
# 📊 Resumo de Vendas Mensais:
# Resultado: Retorno Líquido=0.00%, Sharpe=0.00, Total IR=0.00
#
#   Buscando: Janela_15
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_micro\CSNA3.SA_Janela_15_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (350, 3)
#
# --- Simulação para 2023-01-16 ---
# Min: 21.812725, Max: 27.229477, Média: 23.64357843428571
#
# 📊 Resumo de Vendas Mensais:
#   12/2023: R$ 12,928.20 [ISENTO]
# Resultado: Retorno Líquido=29.23%, Sharpe=0.73, Total IR=0.00
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_micro\CSNA3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 8.133583, Max: 12.614373, Média: 9.345177705797102
#
# 📊 Resumo de Vendas Mensais:
# Resultado: Retorno Líquido=0.00%, Sharpe=0.00, Total IR=0.00
#
# ✓ Resultados salvos em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\MicroResultados\resultados_trading_realista_transformer.csv
# ✓ Diagnósticos salvos em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\MicroResultados\diagnosticos_trading_realista_transformer.csv
# ✓ Melhores resultados salvos em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\MicroResultados\melhores_resultados_realista_transformer.csv
# C:\Users\leona\AppData\Local\Temp\ipykernel_28168\1025705166.py:514: UserWarning: Glyph 129302 (\N{ROBOT FACE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\leona\AppData\Local\Temp\ipykernel_28168\1025705166.py:514: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\leona\AppData\Local\Temp\ipykernel_28168\1025705166.py:517: UserWarning: Glyph 129302 (\N{ROBOT FACE}) missing from font(s) DejaVu Sans.
#   plt.savefig(grafico_filepath, dpi=300, bbox_inches='tight')
# C:\Users\leona\AppData\Local\Temp\ipykernel_28168\1025705166.py:517: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.savefig(grafico_filepath, dpi=300, bbox_inches='tight')
# ✓ Gráfico salvo em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\MicroResultados\trading_realista_transformer_completo.png
# c:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129302 (\N{ROBOT FACE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ================================================================================
#                               ✅ EXECUÇÃO CONCLUÍDA
# ================================================================================
