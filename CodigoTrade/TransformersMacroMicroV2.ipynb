# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from datetime import datetime

# --- Parâmetros Reais de Mercado (B3 2026) ---
TAXA_NEGOCIACAO_LIQUIDACAO = 0.00030  # 0,03%
TAXA_DAY_TRADE = 0.00023              # 0,023%
SLIPPAGE = 0.0001                     # 0,01%
IR_SWING_TRADE = 0.15                 # 15%
IR_DAY_TRADE = 0.20                   # 20%
ISENCAO_VENDA_MENSAL = 20000          # R$ 20k

# Diretório FLAT onde estão os arquivos de previsões (ALTERADO)
input_dir = r"C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro"

# Diretório onde os resultados serão salvos
output_dir = r"C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\MacroResultados"
os.makedirs(output_dir, exist_ok=True)

transactions_dir = os.path.join(output_dir, "Transacoes")
os.makedirs(transactions_dir, exist_ok=True)

# Lista de tickers
tickers = ["BEEF3.SA", "BRFS3.SA", "VALE3.SA", "JBSS3.SA", "SOJA3.SA", 
           "SUZB3.SA", "GGBR3.SA", "CSNA3.SA"]

# Lista de janelas (AJUSTADO para o formato Transformer)
janelas = ["Janela_5", "Janela_10", "Janela_15", "Janela_20"]

def calcular_metricas_risco(historico_patrimonio, saldo_inicial):
    """Calcula Maximum Drawdown e Sharpe Ratio."""
    if not historico_patrimonio or len(historico_patrimonio) < 2:
        return {'max_drawdown': 0.0, 'sharpe_ratio': 0.0}
    
    patrimonio_array = np.array(historico_patrimonio)
    pico = np.maximum.accumulate(patrimonio_array)
    drawdown = (patrimonio_array - pico) / pico
    max_drawdown = np.min(drawdown) * 100
    
    retornos = np.diff(patrimonio_array) / patrimonio_array[:-1]
    if len(retornos) > 0 and np.std(retornos) != 0:
        sharpe_ratio = np.mean(retornos) / np.std(retornos) * np.sqrt(252)
    else:
        sharpe_ratio = 0.0
    
    return {
        'max_drawdown': max_drawdown,
        'sharpe_ratio': sharpe_ratio
    }

def estrategia_all_in_realista(dados_brutos, saldo_inicial):
    """Estratégia All-In com custos reais da B3 e IR CORRIGIDO."""
    dados = dados_brutos.copy()
    dados['Preço Real'] = pd.to_numeric(dados['Preço Real'], errors='coerce')
    dados['Preço Previsto'] = pd.to_numeric(dados['Preço Previsto'], errors='coerce')
    dados['Data'] = pd.to_datetime(dados['Data'])
    
    previsoes = dados['Preço Previsto'].dropna()
    min_previsto = previsoes.min() if len(previsoes) > 0 else None
    max_previsto = previsoes.max() if len(previsoes) > 0 else None
    media_previsoes = previsoes.mean() if len(previsoes) > 0 else None
    
    identifier = dados_brutos['Data'].iloc[0] if not dados_brutos.empty else "Unknown"
    print(f"\n--- Simulação para {identifier} ---")
    print(f"Min: {min_previsto}, Max: {max_previsto}, Média: {media_previsoes}")
    
    # Bloquear previsões extremas
    is_extremely_negative = False
    if min_previsto is not None and isinstance(min_previsto, (int, float)) and min_previsto < -1000:
        is_extremely_negative = True
        print(f"!!! Previsão mínima ({min_previsto}) < -1000. Bloqueando transações. !!!")
    
    if is_extremely_negative:
        diagnostico = {
            'Previsões Razoáveis': False,
            'Estratégia Usada': 'Sem transações - Previsões Negativas',
            'Total de Transações': 0,
            'Retorno (%)': 0.0,
            'Retorno Liquido (%)': 0.0,
            'Max Drawdown (%)': 0.0,
            'Sharpe Ratio': 0.0,
            'Total Custos (R$)': 0.0,
            'Total Impostos (R$)': 0.0,
            'Min Previsto': min_previsto,
            'Max Previsto': max_previsto,
            'Média Previsto': media_previsoes
        }
        return saldo_inicial, [], diagnostico
    
    # Inicializar variáveis
    saldo = saldo_inicial
    quantidade_acoes = 0
    transacoes = []
    historico_patrimonio = [saldo_inicial]
    
    total_custos_operacionais = 0.0
    total_impostos = 0.0
    vendas_no_mes = {}  # ✅ (ano, mês): valor_vendas_acumulado
    data_compra = None
    preco_compra = 0.0
    
    for i in range(len(dados) - 1):
        data_atual = dados.iloc[i]['Data']
        preco_real = dados.iloc[i]['Preço Real']
        
        if pd.isna(preco_real) or preco_real <= 0:
            continue
        
        preco_previsto = dados.iloc[i + 1]['Preço Previsto']
        if pd.isna(preco_previsto):
            continue
        
        # COMPRA
        if quantidade_acoes == 0 and preco_previsto > preco_real:
            preco_com_slippage = preco_real * (1 + SLIPPAGE)
            custos_compra = saldo * (TAXA_NEGOCIACAO_LIQUIDACAO + SLIPPAGE)
            saldo_pos_custo = saldo - custos_compra
            
            if saldo_pos_custo > 0:
                quantidade_acoes = saldo_pos_custo / preco_com_slippage
                valor_investido = quantidade_acoes * preco_com_slippage
                saldo = 0
                total_custos_operacionais += custos_compra
                
                data_compra = data_atual
                preco_compra = preco_com_slippage
                
                transacoes.append({
                    'Data': data_atual,
                    'Acao': 'Compra',
                    'Preco': preco_real,
                    'Preco_Executado': preco_com_slippage,
                    'Quantidade': quantidade_acoes,
                    'Valor_Total': valor_investido,
                    'Custos_Operacionais': custos_compra,
                    'Saldo_Restante': saldo
                })
        
        # VENDA
        elif quantidade_acoes > 0 and preco_previsto < preco_real and i < len(dados) - 2:
            preco_com_slippage = preco_real * (1 - SLIPPAGE)
            valor_bruto_venda = quantidade_acoes * preco_com_slippage
            custos_venda = valor_bruto_venda * (TAXA_NEGOCIACAO_LIQUIDACAO + SLIPPAGE)
            
            is_day_trade = (data_atual.date() == data_compra.date()) if data_compra else False
            
            custo_aquisicao = quantidade_acoes * preco_compra
            lucro_bruto = valor_bruto_venda - custo_aquisicao - custos_venda
            
            imposto = 0.0
            mes_ano = (data_atual.year, data_atual.month)
            
            # ✅ LOG DETALHADO PARA DEBUG
            vendas_mes_atual = vendas_no_mes.get(mes_ano, 0.0)
            print(f"  [VENDA] Data: {data_atual.date()} | Venda: R$ {valor_bruto_venda:.2f} | "
                  f"Vendas Mês {mes_ano}: R$ {vendas_mes_atual:.2f} | Lucro: R$ {lucro_bruto:.2f}")
            
            if lucro_bruto > 0:
                if is_day_trade:
                    # Day Trade: SEMPRE cobra 20%
                    imposto = lucro_bruto * IR_DAY_TRADE
                    print(f"    → DAY TRADE: IR = R$ {imposto:.2f} (20% sobre lucro)")
                else:
                    # ✅ SWING TRADE: Lógica CORRIGIDA
                    vendas_anteriores = vendas_no_mes.get(mes_ano, 0.0)
                    vendas_totais_mes = vendas_anteriores + valor_bruto_venda
                    
                    if vendas_totais_mes > ISENCAO_VENDA_MENSAL:
                        if vendas_anteriores >= ISENCAO_VENDA_MENSAL:
                            # Já ultrapassou antes: tributa TUDO
                            imposto = lucro_bruto * IR_SWING_TRADE
                            print(f"    → SWING: Mês já ultrapassou isenção | IR = R$ {imposto:.2f}")
                        else:
                            # Primeira vez ultrapassando: tributar proporcionalmente
                            valor_excedente = vendas_totais_mes - ISENCAO_VENDA_MENSAL
                            proporcao_tributavel = valor_excedente / valor_bruto_venda
                            lucro_tributavel = lucro_bruto * proporcao_tributavel
                            imposto = lucro_tributavel * IR_SWING_TRADE
                            print(f"    → SWING: 1ª vez ultrapassando | Excedente: R$ {valor_excedente:.2f} | "
                                  f"Proporção: {proporcao_tributavel:.2%} | IR = R$ {imposto:.2f}")
                    else:
                        print(f"    → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00")
                    
                    # Atualizar contador do mês
                    vendas_no_mes[mes_ano] = vendas_totais_mes
            
            valor_liquido_venda = valor_bruto_venda - custos_venda - imposto
            saldo = valor_liquido_venda
            total_custos_operacionais += custos_venda
            total_impostos += imposto
            
            transacoes.append({
                'Data': data_atual,
                'Acao': 'Venda Day Trade' if is_day_trade else 'Venda',
                'Preco': preco_real,
                'Preco_Executado': preco_com_slippage,
                'Quantidade': quantidade_acoes,
                'Valor_Bruto': valor_bruto_venda,
                'Custos_Operacionais': custos_venda,
                'Lucro_Bruto': lucro_bruto,
                'Imposto': imposto,
                'Valor_Liquido': valor_liquido_venda,
                'Saldo_Restante': saldo,
                'Vendas_Acumuladas_Mes': vendas_no_mes.get(mes_ano, 0.0)  # ✅ NOVO CAMPO
            })
            
            quantidade_acoes = 0
            data_compra = None
        
        patrimonio_atual = saldo + (quantidade_acoes * preco_real if quantidade_acoes > 0 else 0)
        historico_patrimonio.append(patrimonio_atual)
    
    # Venda final (MESMA LÓGICA)
    if quantidade_acoes > 0:
        ultimo_preco = dados.iloc[-1]['Preço Real']
        data_final = dados.iloc[-1]['Data']
        
        if not pd.isna(ultimo_preco) and ultimo_preco > 0:
            preco_com_slippage = ultimo_preco * (1 - SLIPPAGE)
            valor_bruto_venda = quantidade_acoes * preco_com_slippage
            custos_venda = valor_bruto_venda * (TAXA_NEGOCIACAO_LIQUIDACAO + SLIPPAGE)
            
            is_day_trade = (data_final.date() == data_compra.date()) if data_compra else False
            
            custo_aquisicao = quantidade_acoes * preco_compra
            lucro_bruto = valor_bruto_venda - custo_aquisicao - custos_venda
            
            imposto = 0.0
            mes_ano = (data_final.year, data_final.month)
            
            if lucro_bruto > 0:
                if is_day_trade:
                    imposto = lucro_bruto * IR_DAY_TRADE
                else:
                    vendas_anteriores = vendas_no_mes.get(mes_ano, 0.0)
                    vendas_totais_mes = vendas_anteriores + valor_bruto_venda
                    
                    if vendas_totais_mes > ISENCAO_VENDA_MENSAL:
                        if vendas_anteriores >= ISENCAO_VENDA_MENSAL:
                            imposto = lucro_bruto * IR_SWING_TRADE
                        else:
                            valor_excedente = vendas_totais_mes - ISENCAO_VENDA_MENSAL
                            proporcao_tributavel = valor_excedente / valor_bruto_venda
                            lucro_tributavel = lucro_bruto * proporcao_tributavel
                            imposto = lucro_tributavel * IR_SWING_TRADE
                    
                    vendas_no_mes[mes_ano] = vendas_totais_mes
            
            valor_liquido_venda = valor_bruto_venda - custos_venda - imposto
            saldo = valor_liquido_venda
            total_custos_operacionais += custos_venda
            total_impostos += imposto
            
            transacoes.append({
                'Data': data_final,
                'Acao': 'Venda Final',
                'Preco': ultimo_preco,
                'Preco_Executado': preco_com_slippage,
                'Quantidade': quantidade_acoes,
                'Valor_Bruto': valor_bruto_venda,
                'Custos_Operacionais': custos_venda,
                'Lucro_Bruto': lucro_bruto,
                'Imposto': imposto,
                'Valor_Liquido': valor_liquido_venda,
                'Saldo_Restante': saldo,
                'Vendas_Acumuladas_Mes': vendas_no_mes.get(mes_ano, 0.0)
            })
    
    # ✅ RESUMO MENSAL DE IR (DEBUG)
    print(f"\n📊 Resumo de Vendas Mensais:")
    for mes_ano, total_vendas in sorted(vendas_no_mes.items()):
        status = "TRIBUTÁVEL" if total_vendas > ISENCAO_VENDA_MENSAL else "ISENTO"
        print(f"  {mes_ano[1]:02d}/{mes_ano[0]}: R$ {total_vendas:,.2f} [{status}]")
    
    metricas_risco = calcular_metricas_risco(historico_patrimonio, saldo_inicial)
    
    retorno_bruto = ((saldo + total_custos_operacionais + total_impostos - saldo_inicial) / saldo_inicial) * 100
    retorno_liquido = ((saldo - saldo_inicial) / saldo_inicial) * 100
    
    previsoes_razoaveis = not is_extremely_negative
    estrategia_usada = 'Trading Realista (B3)' if len(transacoes) > 0 else 'Sem transações'
    
    diagnostico = {
        'Previsões Razoáveis': previsoes_razoaveis,
        'Estratégia Usada': estrategia_usada,
        'Total de Transações': len(transacoes),
        'Retorno Bruto (%)': retorno_bruto,
        'Retorno Liquido (%)': retorno_liquido,
        'Max Drawdown (%)': metricas_risco['max_drawdown'],
        'Sharpe Ratio': metricas_risco['sharpe_ratio'],
        'Total Custos (R$)': total_custos_operacionais,
        'Total Impostos (R$)': total_impostos,
        'Min Previsto': min_previsto,
        'Max Previsto': max_previsto,
        'Média Previsto': media_previsoes
    }
    
    print(f"Resultado: Retorno Líquido={retorno_liquido:.2f}%, Sharpe={metricas_risco['sharpe_ratio']:.2f}, Total IR={total_impostos:.2f}")
    
    return saldo, transacoes, diagnostico

def processar_previsoes_realista(input_dir, tickers, janelas, saldo_inicial):
    """
    Processa previsões com estrutura FLAT de arquivos.
    Formato esperado: TICKER_JANELA_X_previsoes_teste_final.csv
    """
    resultados = []
    todas_transacoes = {}
    todos_diagnosticos = {}
    
    for ticker in tickers:
        print(f"\n{'='*60}")
        print(f"Processando {ticker}...")
        print(f"{'='*60}")
        
        ticker_resultados = {'Ticker': ticker}
        todas_transacoes[ticker] = {}
        todos_diagnosticos[ticker] = {}
        
        for janela in janelas:
            previsoes_file = os.path.join(input_dir, f"{ticker}_{janela}_previsoes_teste_final.csv")
            
            print(f"\n  Buscando: {janela}")
            print(f"  Caminho: {previsoes_file}")
            
            if os.path.exists(previsoes_file):
                try:
                    dados = pd.read_csv(previsoes_file)
                    print(f"  ✓ Arquivo encontrado! Shape: {dados.shape}")
                    
                    saldo_final, transacoes, diagnostico = estrategia_all_in_realista(dados, saldo_inicial)
                    
                    todas_transacoes[ticker][janela] = transacoes
                    todos_diagnosticos[ticker][janela] = diagnostico
                    
                    ticker_resultados[f"Saldo Final {janela}"] = saldo_final
                    ticker_resultados[f"Retorno Liquido {janela} (%)"] = diagnostico['Retorno Liquido (%)']
                    ticker_resultados[f"Sharpe {janela}"] = diagnostico['Sharpe Ratio']
                    ticker_resultados[f"Drawdown {janela} (%)"] = diagnostico['Max Drawdown (%)']
                    ticker_resultados[f"Custos {janela} (R$)"] = diagnostico['Total Custos (R$)']
                    ticker_resultados[f"Impostos {janela} (R$)"] = diagnostico['Total Impostos (R$)']
                    
                except Exception as e:
                    print(f"  ❌ Erro ao processar {ticker} - {janela}: {str(e)}")
                    import traceback
                    traceback.print_exc()
                    
                    ticker_resultados[f"Saldo Final {janela}"] = saldo_inicial
                    ticker_resultados[f"Retorno Liquido {janela} (%)"] = 0.0
            else:
                print(f"  ❌ Arquivo não encontrado!")
                ticker_resultados[f"Saldo Final {janela}"] = saldo_inicial
                ticker_resultados[f"Retorno Liquido {janela} (%)"] = 0.0
        
        resultados.append(ticker_resultados)
    
    return pd.DataFrame(resultados), todas_transacoes, todos_diagnosticos

# --- CÓDIGO PRINCIPAL ---
saldo_inicial = 10000

print("\n" + "="*80)
print(" "*20 + "SIMULAÇÃO REALISTA DE TRADING - B3 2026")
print("="*80)
print(f"Saldo Inicial: R$ {saldo_inicial:,.2f}")
print(f"Taxa B3: {TAXA_NEGOCIACAO_LIQUIDACAO*100:.3f}% | Slippage: {SLIPPAGE*100:.3f}%")
print(f"IR Swing Trade: {IR_SWING_TRADE*100:.1f}% | IR Day Trade: {IR_DAY_TRADE*100:.1f}%")
print(f"Isenção Mensal: R$ {ISENCAO_VENDA_MENSAL:,.2f}")
print(f"Pasta de Dados: {input_dir}")
print("="*80 + "\n")

df_resultados, todas_transacoes, todos_diagnosticos = processar_previsoes_realista(
    input_dir, tickers, janelas, saldo_inicial
)

# Salvar resultados
resultados_filepath = os.path.join(output_dir, "resultados_trading_realista_transformer.csv")
df_resultados.to_csv(resultados_filepath, index=False)
print(f"\n✓ Resultados salvos em: {resultados_filepath}")

# Salvar diagnósticos
diagnosticos_list = []
for ticker in todos_diagnosticos:
    for janela in todos_diagnosticos.get(ticker, {}):
        if todos_diagnosticos[ticker][janela]:
            diagnostico = todos_diagnosticos[ticker][janela].copy()
            diagnostico['Ticker'] = ticker
            diagnostico['Janela'] = janela
            diagnosticos_list.append(diagnostico)

if diagnosticos_list:
    df_diagnosticos = pd.DataFrame(diagnosticos_list)
    diagnosticos_filepath = os.path.join(output_dir, "diagnosticos_trading_realista_transformer.csv")
    df_diagnosticos.to_csv(diagnosticos_filepath, index=False)
    print(f"✓ Diagnósticos salvos em: {diagnosticos_filepath}")

# Salvar transações
for ticker in tickers:
    ticker_dir = os.path.join(transactions_dir, ticker)
    os.makedirs(ticker_dir, exist_ok=True)
    
    for janela in janelas:
        if janela in todas_transacoes.get(ticker, {}):
            transacoes = todas_transacoes[ticker][janela]
            
            if transacoes:
                df_transacoes = pd.DataFrame(transacoes)
                transacoes_filepath = os.path.join(ticker_dir, f"{ticker}_{janela}_transacoes_realista.csv")
                df_transacoes.to_csv(transacoes_filepath, index=False)

# Identificar melhor janela por Sharpe Ratio
melhores_resultados = []
for _, row in df_resultados.iterrows():
    ticker = row['Ticker']
    melhor_janela = None
    melhor_sharpe = -np.inf
    
    for janela in janelas:
        sharpe = row.get(f"Sharpe {janela}", -np.inf)
        saldo = row.get(f"Saldo Final {janela}", 0)
        
        if sharpe > melhor_sharpe and saldo > saldo_inicial * 0.95:
            melhor_sharpe = sharpe
            melhor_janela = janela
    
    if melhor_janela:
        melhores_resultados.append({
            'Ticker': ticker,
            'Melhor Janela': melhor_janela,
            'Saldo Final': row[f"Saldo Final {melhor_janela}"],
            'Retorno Liquido (%)': row[f"Retorno Liquido {melhor_janela} (%)"],
            'Sharpe Ratio': melhor_sharpe,
            'Drawdown (%)': row[f"Drawdown {melhor_janela} (%)"],
            'Custos (R$)': row[f"Custos {melhor_janela} (R$)"],
            'Impostos (R$)': row[f"Impostos {melhor_janela} (R$)"]
        })

if melhores_resultados:
    df_melhores = pd.DataFrame(melhores_resultados).sort_values(by='Sharpe Ratio', ascending=False)
    
    melhores_filepath = os.path.join(output_dir, "melhores_resultados_realista_transformer.csv")
    df_melhores.to_csv(melhores_filepath, index=False)
    print(f"✓ Melhores resultados salvos em: {melhores_filepath}")
    
    # Gráfico com escala ajustada
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(18, 14))
    
    # Gráfico 1: Retorno Líquido
    colors = ['darkgreen' if r > 10 else 'green' if r > 0 else 'red' for r in df_melhores['Retorno Liquido (%)']]
    bars = ax1.bar(df_melhores['Ticker'], df_melhores['Saldo Final'], 
                   color=colors, edgecolor='black', linewidth=1.5, alpha=0.8)
    ax1.axhline(y=saldo_inicial, color='blue', linestyle='--', linewidth=2.5, 
                label=f'Saldo Inicial: R$ {saldo_inicial:,.2f}')
    
    max_saldo = df_melhores['Saldo Final'].max()
    ax1.set_ylim(0, max_saldo * 1.25)
    
    for i, bar in enumerate(bars):
        row = df_melhores.iloc[i]
        saldo = row['Saldo Final']
        retorno = row['Retorno Liquido (%)']
        janela = row['Melhor Janela']
        custos = row['Custos (R$)']
        impostos = row['Impostos (R$)']
        
        offset = max_saldo * 0.03
        ax1.text(i, saldo + offset, 
                f"R$ {saldo:,.0f}\n{retorno:+.1f}%\n{janela}\nC: R${custos:.0f} | I: R${impostos:.0f}",
                ha='center', va='bottom', fontsize=10, fontweight='bold')
    
    ax1.set_title('🤖 Transformers - Trading Realista 2023 (Retorno Líquido)', 
                  fontsize=16, fontweight='bold', pad=20)
    ax1.set_ylabel('Saldo Final (R$)', fontsize=13, fontweight='bold')
    ax1.legend(fontsize=11, loc='upper left')
    ax1.grid(axis='y', alpha=0.4, linestyle='--')
    ax1.set_axisbelow(True)
    
    # Gráfico 2: Sharpe Ratio
    colors2 = ['darkgreen' if s > 1.5 else 'green' if s > 0.5 else 'orange' if s > 0 else 'darkred' 
               for s in df_melhores['Sharpe Ratio']]
    ax2.bar(df_melhores['Ticker'], df_melhores['Sharpe Ratio'], 
            color=colors2, edgecolor='black', linewidth=1.5, alpha=0.8)
    ax2.axhline(y=0, color='black', linestyle='-', linewidth=1.5)
    ax2.axhline(y=1, color='green', linestyle='--', linewidth=2, 
                label='Sharpe > 1 (Bom)', alpha=0.7)
    
    max_sharpe = df_melhores['Sharpe Ratio'].max()
    min_sharpe = df_melhores['Sharpe Ratio'].min()
    sharpe_range = max_sharpe - min_sharpe
    ax2.set_ylim(min_sharpe - sharpe_range * 0.2, max_sharpe + sharpe_range * 0.3)
    
    for i, (idx, row) in enumerate(df_melhores.iterrows()):
        sharpe = row['Sharpe Ratio']
        drawdown = row['Drawdown (%)']
        
        offset = sharpe_range * 0.08 if sharpe > 0 else -sharpe_range * 0.08
        ax2.text(i, sharpe + offset, 
                f"{sharpe:.2f}\nDD: {drawdown:.1f}%", 
                ha='center', va='bottom' if sharpe > 0 else 'top', 
                fontsize=10, fontweight='bold')
    
    ax2.set_title('📊 Sharpe Ratio e Maximum Drawdown', 
                  fontsize=16, fontweight='bold', pad=20)
    ax2.set_xlabel('Ticker', fontsize=13, fontweight='bold')
    ax2.set_ylabel('Sharpe Ratio', fontsize=13, fontweight='bold')
    ax2.legend(fontsize=11, loc='upper left')
    ax2.grid(axis='y', alpha=0.4, linestyle='--')
    ax2.set_axisbelow(True)
    
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    
    grafico_filepath = os.path.join(output_dir, "trading_realista_transformer_completo.png")
    plt.savefig(grafico_filepath, dpi=300, bbox_inches='tight')
    print(f"✓ Gráfico salvo em: {grafico_filepath}")
    plt.show()

print("\n" + "="*80)
print(" "*30 + "✅ EXECUÇÃO CONCLUÍDA")
print("="*80)
# Out:
# ================================================================================
#                     SIMULAÇÃO REALISTA DE TRADING - B3 2026
# ================================================================================
# Saldo Inicial: R$ 10,000.00
# Taxa B3: 0.030% | Slippage: 0.010%
# IR Swing Trade: 15.0% | IR Day Trade: 20.0%
# Isenção Mensal: R$ 20,000.00
# Pasta de Dados: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro
# ================================================================================
#
#
# ============================================================
# Processando BEEF3.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\BEEF3.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (360, 3)
#
# --- Simulação para 2023-01-06 ---
# Min: 6.9679327, Max: 13.296474, Média: 10.282142034444446
#   [VENDA] Data: 2023-01-09 | Venda: R$ 10129.56 | Vendas Mês (2023, 1): R$ 0.00 | Lucro: R$ 129.51
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-02-06 | Venda: R$ 10269.58 | Vendas Mês (2023, 2): R$ 0.00 | Lucro: R$ 144.01
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-02-14 | Venda: R$ 10022.50 | Vendas Mês (2023, 2): R$ 10269.58 | Lucro: R$ -242.87
#   [VENDA] Data: 2023-03-02 | Venda: R$ 9551.11 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ -467.19
#   [VENDA] Data: 2023-05-17 | Venda: R$ 8188.30 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ -1358.46
#
# 📊 Resumo de Vendas Mensais:
#   01/2023: R$ 10,129.56 [ISENTO]
#   02/2023: R$ 10,269.58 [ISENTO]
# Resultado: Retorno Líquido=-38.99%, Sharpe=-0.85, Total IR=0.00
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\BEEF3.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 7.235546, Max: 12.99399, Média: 10.14269440056338
#   [VENDA] Data: 2023-02-09 | Venda: R$ 10054.99 | Vendas Mês (2023, 2): R$ 0.00 | Lucro: R$ 54.96
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-02-14 | Venda: R$ 10161.11 | Vendas Mês (2023, 2): R$ 10054.99 | Lucro: R$ 110.10
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 216.09 | Proporção: 2.13% | IR = R$ 0.35
#   [VENDA] Data: 2023-02-22 | Venda: R$ 9682.87 | Vendas Mês (2023, 2): R$ 20216.09 | Lucro: R$ -473.63
#   [VENDA] Data: 2023-03-02 | Venda: R$ 9908.30 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ 229.21
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-03-16 | Venda: R$ 9814.51 | Vendas Mês (2023, 3): R$ 9908.30 | Lucro: R$ -89.79
#
# 📊 Resumo de Vendas Mensais:
#   02/2023: R$ 20,216.09 [TRIBUTÁVEL]
#   03/2023: R$ 9,908.30 [ISENTO]
# Resultado: Retorno Líquido=-33.65%, Sharpe=-0.68, Total IR=0.35
#
#   Buscando: Janela_15
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\BEEF3.SA_Janela_15_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (350, 3)
#
# --- Simulação para 2023-01-16 ---
# Min: 6.952409, Max: 13.189077, Média: 10.091812824285714
#   [VENDA] Data: 2023-02-09 | Venda: R$ 10054.99 | Vendas Mês (2023, 2): R$ 0.00 | Lucro: R$ 54.96
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-02-14 | Venda: R$ 10161.11 | Vendas Mês (2023, 2): R$ 10054.99 | Lucro: R$ 110.10
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 216.09 | Proporção: 2.13% | IR = R$ 0.35
#   [VENDA] Data: 2023-03-02 | Venda: R$ 9682.87 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ -473.63
#   [VENDA] Data: 2023-04-27 | Venda: R$ 7294.52 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -2383.52
#   [VENDA] Data: 2023-05-02 | Venda: R$ 7244.61 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ -46.97
#   [VENDA] Data: 2023-05-04 | Venda: R$ 7554.65 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 312.81
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-17 | Venda: R$ 8335.21 | Vendas Mês (2023, 5): R$ 7554.65 | Lucro: R$ 783.27
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-01 | Venda: R$ 6845.55 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ -1485.74
#   [VENDA] Data: 2023-10-14 | Venda: R$ 6670.47 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ -172.27
#   [VENDA] Data: 2023-10-23 | Venda: R$ 6416.05 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ -251.66
#   [VENDA] Data: 2023-10-25 | Venda: R$ 6609.66 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ 196.10
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-02 | Venda: R$ 6759.24 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 152.16
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-05 | Venda: R$ 6977.85 | Vendas Mês (2023, 11): R$ 6759.24 | Lucro: R$ 221.23
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-13 | Venda: R$ 6096.27 | Vendas Mês (2023, 11): R$ 13737.09 | Lucro: R$ -878.44
#   [VENDA] Data: 2023-11-15 | Venda: R$ 6237.24 | Vendas Mês (2023, 11): R$ 13737.09 | Lucro: R$ 143.35
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#
# 📊 Resumo de Vendas Mensais:
#   02/2023: R$ 20,216.09 [TRIBUTÁVEL]
#   05/2023: R$ 15,889.86 [ISENTO]
#   10/2023: R$ 6,609.66 [ISENTO]
#   11/2023: R$ 19,974.33 [ISENTO]
#   12/2023: R$ 6,528.14 [ISENTO]
# Resultado: Retorno Líquido=-34.74%, Sharpe=-0.73, Total IR=0.35
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\BEEF3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 7.0523143, Max: 13.357982, Média: 9.940521673333333
#   [VENDA] Data: 2023-02-03 | Venda: R$ 9994.00 | Vendas Mês (2023, 2): R$ 0.00 | Lucro: R$ -6.00
#   [VENDA] Data: 2023-02-06 | Venda: R$ 10132.14 | Vendas Mês (2023, 2): R$ 0.00 | Lucro: R$ 142.08
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-03-02 | Venda: R$ 8893.50 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ -1234.09
#   [VENDA] Data: 2023-04-05 | Venda: R$ 7619.69 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -1269.75
#   [VENDA] Data: 2023-04-19 | Venda: R$ 6974.98 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -641.40
#   [VENDA] Data: 2023-04-27 | Venda: R$ 6686.47 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -285.60
#   [VENDA] Data: 2023-05-02 | Venda: R$ 6640.72 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ -43.06
#   [VENDA] Data: 2023-05-04 | Venda: R$ 6924.92 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 286.73
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-07 | Venda: R$ 7067.19 | Vendas Mês (2023, 5): R$ 6924.92 | Lucro: R$ 144.98
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-17 | Venda: R$ 7103.93 | Vendas Mês (2023, 5): R$ 13992.10 | Lucro: R$ 39.55
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 1096.03 | Proporção: 15.43% | IR = R$ 0.92
#   [VENDA] Data: 2023-09-03 | Venda: R$ 6343.92 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ -755.95
#   [VENDA] Data: 2023-09-17 | Venda: R$ 6097.89 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ -243.39
#   [VENDA] Data: 2023-09-21 | Venda: R$ 5823.25 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ -272.10
#   [VENDA] Data: 2023-09-25 | Venda: R$ 5803.17 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ -17.74
#   [VENDA] Data: 2023-09-29 | Venda: R$ 5754.69 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ -46.14
#   [VENDA] Data: 2023-10-09 | Venda: R$ 5770.15 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ 17.76
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-11 | Venda: R$ 5764.38 | Vendas Mês (2023, 10): R$ 5770.15 | Lucro: R$ -3.46
#   [VENDA] Data: 2023-10-25 | Venda: R$ 5518.98 | Vendas Mês (2023, 10): R$ 5770.15 | Lucro: R$ -243.00
#   [VENDA] Data: 2023-11-02 | Venda: R$ 5643.87 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 127.05
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-27 | Venda: R$ 5165.99 | Vendas Mês (2023, 11): R$ 5643.87 | Lucro: R$ -475.43
#   [VENDA] Data: 2023-11-30 | Venda: R$ 5295.52 | Vendas Mês (2023, 11): R$ 5643.87 | Lucro: R$ 131.54
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12-17 | Venda: R$ 5240.65 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ -52.73
#   [VENDA] Data: 2023-12-25 | Venda: R$ 5291.86 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ 53.28
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#
# 📊 Resumo de Vendas Mensais:
#   02/2023: R$ 10,132.14 [ISENTO]
#   05/2023: R$ 21,096.03 [TRIBUTÁVEL]
#   10/2023: R$ 5,770.15 [ISENTO]
#   11/2023: R$ 10,939.39 [ISENTO]
#   12/2023: R$ 5,291.86 [ISENTO]
# Resultado: Retorno Líquido=-47.44%, Sharpe=-1.20, Total IR=0.92
#
# ============================================================
# Processando BRFS3.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\BRFS3.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (360, 3)
#
# --- Simulação para 2023-01-06 ---
# Min: 10.366938, Max: 14.123899, Média: 11.360700879166668
#   [VENDA] Data: 2023-11-05 | Venda: R$ 14805.93 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 4804.01
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-15 | Venda: R$ 16270.24 | Vendas Mês (2023, 11): R$ 14805.93 | Lucro: R$ 1469.64
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 11076.17 | Proporção: 68.08% | IR = R$ 150.07
#   [VENDA] Data: 2023-12-06 | Venda: R$ 15205.01 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ -908.29
#
# 📊 Resumo de Vendas Mensais:
#   11/2023: R$ 31,076.17 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=51.99%, Sharpe=0.84, Total IR=150.07
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\BRFS3.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 10.196596, Max: 14.210651, Média: 11.400867225352112
#   [VENDA] Data: 2023-11-05 | Venda: R$ 14944.30 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 4942.32
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-15 | Venda: R$ 16422.29 | Vendas Mês (2023, 11): R$ 14944.30 | Lucro: R$ 1483.38
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 11366.59 | Proporção: 69.21% | IR = R$ 154.01
#   [VENDA] Data: 2023-12-12 | Venda: R$ 15759.14 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ -502.38
#   [VENDA] Data: 2023-12-17 | Venda: R$ 15834.59 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ 81.72
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12-26 | Venda: R$ 15626.40 | Vendas Mês (2023, 12): R$ 15834.59 | Lucro: R$ -201.77
#
# 📊 Resumo de Vendas Mensais:
#   11/2023: R$ 31,366.59 [TRIBUTÁVEL]
#   12/2023: R$ 15,834.59 [ISENTO]
# Resultado: Retorno Líquido=56.20%, Sharpe=0.89, Total IR=154.01
#
#   Buscando: Janela_15
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\BRFS3.SA_Janela_15_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (350, 3)
#
# --- Simulação para 2023-01-16 ---
# Min: 10.313664, Max: 13.724752, Média: 11.288897338571429
#   [VENDA] Data: 2023-11-05 | Venda: R$ 16316.74 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 6314.21
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-13 | Venda: R$ 18249.08 | Vendas Mês (2023, 11): R$ 16316.74 | Lucro: R$ 1938.09
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 14565.82 | Proporção: 79.82% | IR = R$ 232.04
#
# 📊 Resumo de Vendas Mensais:
#   11/2023: R$ 34,565.82 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=80.10%, Sharpe=1.13, Total IR=232.04
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\BRFS3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 11.075073, Max: 14.188229, Média: 11.634580420289856
#   [VENDA] Data: 2023-11-05 | Venda: R$ 16192.81 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 6190.33
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-13 | Venda: R$ 16471.91 | Vendas Mês (2023, 11): R$ 16192.81 | Lucro: R$ 285.46
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 12664.72 | Proporção: 76.89% | IR = R$ 32.92
#   [VENDA] Data: 2023-11-15 | Venda: R$ 17740.95 | Vendas Mês (2023, 11): R$ 32664.72 | Lucro: R$ 1308.03
#     → SWING: Mês já ultrapassou isenção | IR = R$ 196.20
#
# 📊 Resumo de Vendas Mensais:
#   11/2023: R$ 50,405.68 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=75.38%, Sharpe=1.09, Total IR=229.13
#
# ============================================================
# Processando VALE3.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\VALE3.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (360, 3)
#
# --- Simulação para 2023-01-06 ---
# Min: 54.769814, Max: 74.16478, Média: 62.89051842222222
#   [VENDA] Data: 2023-02-02 | Venda: R$ 9972.70 | Vendas Mês (2023, 2): R$ 0.00 | Lucro: R$ -27.29
#   [VENDA] Data: 2023-03-06 | Venda: R$ 9867.90 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ -100.77
#   [VENDA] Data: 2023-03-15 | Venda: R$ 9894.35 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ 30.38
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-03-23 | Venda: R$ 9771.43 | Vendas Mês (2023, 3): R$ 9894.35 | Lucro: R$ -118.91
#   [VENDA] Data: 2023-03-31 | Venda: R$ 9761.66 | Vendas Mês (2023, 3): R$ 9894.35 | Lucro: R$ -5.86
#   [VENDA] Data: 2023-04-06 | Venda: R$ 9590.70 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -166.99
#   [VENDA] Data: 2023-04-09 | Venda: R$ 9765.87 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ 178.93
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-04-14 | Venda: R$ 9539.44 | Vendas Mês (2023, 4): R$ 9765.87 | Lucro: R$ -222.44
#   [VENDA] Data: 2023-04-17 | Venda: R$ 9611.90 | Vendas Mês (2023, 4): R$ 9765.87 | Lucro: R$ 76.24
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-13 | Venda: R$ 9549.49 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ -58.54
#   [VENDA] Data: 2023-11-19 | Venda: R$ 9857.46 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 311.67
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-24 | Venda: R$ 9702.89 | Vendas Mês (2023, 11): R$ 9857.46 | Lucro: R$ -150.57
#   [VENDA] Data: 2023-11-27 | Venda: R$ 9714.35 | Vendas Mês (2023, 11): R$ 9857.46 | Lucro: R$ 15.33
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12-06 | Venda: R$ 9366.61 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ -343.71
#   [VENDA] Data: 2023-12-13 | Venda: R$ 9434.37 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ 71.47
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12-17 | Venda: R$ 9469.60 | Vendas Mês (2023, 12): R$ 9434.37 | Lucro: R$ 38.99
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12-20 | Venda: R$ 9775.09 | Vendas Mês (2023, 12): R$ 18903.97 | Lucro: R$ 309.15
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 8679.05 | Proporção: 88.79% | IR = R$ 41.17
#   [VENDA] Data: 2023-12-22 | Venda: R$ 9724.17 | Vendas Mês (2023, 12): R$ 28679.05 | Lucro: R$ -5.83
#
# 📊 Resumo de Vendas Mensais:
#   03/2023: R$ 9,894.35 [ISENTO]
#   04/2023: R$ 19,377.77 [ISENTO]
#   11/2023: R$ 19,571.81 [ISENTO]
#   12/2023: R$ 28,679.05 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=-2.80%, Sharpe=-0.02, Total IR=41.17
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\VALE3.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 54.652206, Max: 73.64194, Média: 61.62232045915493
#   [VENDA] Data: 2023-03-15 | Venda: R$ 10030.81 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ 30.80
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-03-23 | Venda: R$ 9906.20 | Vendas Mês (2023, 3): R$ 10030.81 | Lucro: R$ -120.55
#   [VENDA] Data: 2023-03-31 | Venda: R$ 9896.29 | Vendas Mês (2023, 3): R$ 10030.81 | Lucro: R$ -5.94
#   [VENDA] Data: 2023-04-05 | Venda: R$ 9722.98 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -169.29
#   [VENDA] Data: 2023-04-13 | Venda: R$ 9627.74 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -91.31
#   [VENDA] Data: 2023-04-20 | Venda: R$ 9417.56 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -206.25
#   [VENDA] Data: 2023-04-26 | Venda: R$ 9381.99 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -31.78
#   [VENDA] Data: 2023-05-04 | Venda: R$ 8937.64 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ -440.42
#   [VENDA] Data: 2023-05-16 | Venda: R$ 9037.34 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 103.23
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-01 | Venda: R$ 8765.12 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ -268.50
#   [VENDA] Data: 2023-06-06 | Venda: R$ 8850.44 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ 88.79
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-13 | Venda: R$ 8886.66 | Vendas Mês (2023, 6): R$ 8850.44 | Lucro: R$ 39.74
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-02 | Venda: R$ 8439.43 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ -443.50
#   [VENDA] Data: 2023-07-12 | Venda: R$ 8777.70 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ 341.51
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-23 | Venda: R$ 8927.41 | Vendas Mês (2023, 7): R$ 8777.70 | Lucro: R$ 153.16
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-30 | Venda: R$ 8595.35 | Vendas Mês (2023, 7): R$ 17705.11 | Lucro: R$ -328.36
#   [VENDA] Data: 2023-08-31 | Venda: R$ 8935.31 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ 343.26
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-09-13 | Venda: R$ 9085.75 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ 153.96
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-31 | Venda: R$ 9178.48 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ 96.32
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-09 | Venda: R$ 9329.69 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 154.82
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-13 | Venda: R$ 9588.70 | Vendas Mês (2023, 11): R$ 9329.69 | Lucro: R$ 262.64
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-24 | Venda: R$ 9579.12 | Vendas Mês (2023, 11): R$ 18918.39 | Lucro: R$ -5.75
#   [VENDA] Data: 2023-12-05 | Venda: R$ 9418.57 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ -156.65
#
# 📊 Resumo de Vendas Mensais:
#   03/2023: R$ 10,030.81 [ISENTO]
#   05/2023: R$ 9,037.34 [ISENTO]
#   06/2023: R$ 17,737.11 [ISENTO]
#   07/2023: R$ 17,705.11 [ISENTO]
#   08/2023: R$ 8,935.31 [ISENTO]
#   09/2023: R$ 9,085.75 [ISENTO]
#   10/2023: R$ 9,178.48 [ISENTO]
#   11/2023: R$ 18,918.39 [ISENTO]
# Resultado: Retorno Líquido=-5.85%, Sharpe=-0.16, Total IR=0.00
#
#   Buscando: Janela_15
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\VALE3.SA_Janela_15_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (350, 3)
#
# --- Simulação para 2023-01-16 ---
# Min: 54.308044, Max: 76.85426, Média: 62.30263350285714
#   [VENDA] Data: 2023-01-17 | Venda: R$ 10125.26 | Vendas Mês (2023, 1): R$ 0.00 | Lucro: R$ 125.21
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-02-28 | Venda: R$ 9654.08 | Vendas Mês (2023, 2): R$ 0.00 | Lucro: R$ -466.94
#   [VENDA] Data: 2023-04-10 | Venda: R$ 9090.25 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -559.75
#   [VENDA] Data: 2023-05-08 | Venda: R$ 7964.60 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ -1121.56
#   [VENDA] Data: 2023-05-16 | Venda: R$ 8016.29 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 54.85
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-01 | Venda: R$ 7861.33 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ -151.70
#   [VENDA] Data: 2023-06-13 | Venda: R$ 8075.78 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ 217.51
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-26 | Venda: R$ 7974.63 | Vendas Mês (2023, 6): R$ 8075.78 | Lucro: R$ -97.88
#   [VENDA] Data: 2023-07-02 | Venda: R$ 8152.54 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ 181.02
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-10 | Venda: R$ 8301.49 | Vendas Mês (2023, 7): R$ 8152.54 | Lucro: R$ 152.15
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-20 | Venda: R$ 8287.08 | Vendas Mês (2023, 7): R$ 16454.02 | Lucro: R$ -11.08
#   [VENDA] Data: 2023-07-30 | Venda: R$ 8130.66 | Vendas Mês (2023, 7): R$ 16454.02 | Lucro: R$ -153.04
#   [VENDA] Data: 2023-08-03 | Venda: R$ 8046.31 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ -81.07
#   [VENDA] Data: 2023-08-28 | Venda: R$ 7975.12 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ -67.94
#   [VENDA] Data: 2023-09-10 | Venda: R$ 7929.65 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ -42.26
#   [VENDA] Data: 2023-09-13 | Venda: R$ 8246.31 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ 319.70
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-09-28 | Venda: R$ 8005.88 | Vendas Mês (2023, 9): R$ 8246.31 | Lucro: R$ -237.04
#   [VENDA] Data: 2023-10-05 | Venda: R$ 7912.66 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ -89.97
#   [VENDA] Data: 2023-10-26 | Venda: R$ 7988.70 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ 79.17
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-29 | Venda: R$ 8052.76 | Vendas Mês (2023, 10): R$ 7988.70 | Lucro: R$ 67.23
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-09 | Venda: R$ 8213.45 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 163.85
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-13 | Venda: R$ 8441.48 | Vendas Mês (2023, 11): R$ 8213.45 | Lucro: R$ 231.22
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-19 | Venda: R$ 8639.78 | Vendas Mês (2023, 11): R$ 16654.93 | Lucro: R$ 201.59
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 5294.70 | Proporção: 61.28% | IR = R$ 18.53
#   [VENDA] Data: 2023-11-30 | Venda: R$ 8709.88 | Vendas Mês (2023, 11): R$ 25294.70 | Lucro: R$ 92.06
#     → SWING: Mês já ultrapassou isenção | IR = R$ 13.81
#   [VENDA] Data: 2023-12-20 | Venda: R$ 8889.49 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ 196.82
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#
# 📊 Resumo de Vendas Mensais:
#   01/2023: R$ 10,125.26 [ISENTO]
#   05/2023: R$ 8,016.29 [ISENTO]
#   06/2023: R$ 8,075.78 [ISENTO]
#   07/2023: R$ 16,454.02 [ISENTO]
#   09/2023: R$ 8,246.31 [ISENTO]
#   10/2023: R$ 16,041.45 [ISENTO]
#   11/2023: R$ 34,004.59 [TRIBUTÁVEL]
#   12/2023: R$ 17,864.26 [ISENTO]
# Resultado: Retorno Líquido=-10.29%, Sharpe=-0.30, Total IR=32.34
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\VALE3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 50.819267, Max: 75.161804, Média: 61.38823620579709
#   [VENDA] Data: 2023-02-02 | Venda: R$ 9972.70 | Vendas Mês (2023, 2): R$ 0.00 | Lucro: R$ -27.29
#   [VENDA] Data: 2023-02-24 | Venda: R$ 9962.73 | Vendas Mês (2023, 2): R$ 0.00 | Lucro: R$ -5.98
#   [VENDA] Data: 2023-03-07 | Venda: R$ 9948.15 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ -10.59
#   [VENDA] Data: 2023-03-15 | Venda: R$ 9974.81 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ 30.63
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-03-24 | Venda: R$ 9850.89 | Vendas Mês (2023, 3): R$ 9974.81 | Lucro: R$ -119.88
#   [VENDA] Data: 2023-03-31 | Venda: R$ 9841.04 | Vendas Mês (2023, 3): R$ 9974.81 | Lucro: R$ -5.90
#   [VENDA] Data: 2023-04-09 | Venda: R$ 9855.14 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ 18.03
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-04-17 | Venda: R$ 9593.66 | Vendas Mês (2023, 4): R$ 9855.14 | Lucro: R$ -257.44
#   [VENDA] Data: 2023-04-26 | Venda: R$ 9019.71 | Vendas Mês (2023, 4): R$ 9855.14 | Lucro: R$ -569.89
#   [VENDA] Data: 2023-05-04 | Venda: R$ 8945.91 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ -70.17
#   [VENDA] Data: 2023-05-14 | Venda: R$ 8898.31 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ -44.00
#   [VENDA] Data: 2023-05-16 | Venda: R$ 9183.79 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 288.93
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-25 | Venda: R$ 8696.09 | Vendas Mês (2023, 5): R$ 9183.79 | Lucro: R$ -483.84
#   [VENDA] Data: 2023-05-30 | Venda: R$ 8357.34 | Vendas Mês (2023, 5): R$ 9183.79 | Lucro: R$ -335.13
#   [VENDA] Data: 2023-06-13 | Venda: R$ 8481.71 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ 127.66
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-25 | Venda: R$ 8044.45 | Vendas Mês (2023, 6): R$ 8481.71 | Lucro: R$ -433.69
#   [VENDA] Data: 2023-06-28 | Venda: R$ 8134.51 | Vendas Mês (2023, 6): R$ 8481.71 | Lucro: R$ 93.24
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-30 | Venda: R$ 8126.37 | Vendas Mês (2023, 6): R$ 16616.21 | Lucro: R$ -4.88
#   [VENDA] Data: 2023-07-06 | Venda: R$ 8135.65 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ 12.52
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-10 | Venda: R$ 8266.58 | Vendas Mês (2023, 7): R$ 8135.65 | Lucro: R$ 134.13
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-23 | Venda: R$ 8407.57 | Vendas Mês (2023, 7): R$ 16402.23 | Lucro: R$ 144.24
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 4809.80 | Proporção: 57.21% | IR = R$ 12.38
#   [VENDA] Data: 2023-07-30 | Venda: R$ 8082.92 | Vendas Mês (2023, 7): R$ 24809.80 | Lucro: R$ -308.78
#   [VENDA] Data: 2023-08-11 | Venda: R$ 7756.35 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ -323.21
#   [VENDA] Data: 2023-08-14 | Venda: R$ 7672.24 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ -80.98
#   [VENDA] Data: 2023-08-31 | Venda: R$ 8488.94 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ 819.44
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-09-13 | Venda: R$ 8631.87 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ 146.27
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-09-27 | Venda: R$ 8271.07 | Vendas Mês (2023, 9): R$ 8631.87 | Lucro: R$ -357.21
#   [VENDA] Data: 2023-10-05 | Venda: R$ 8174.77 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ -92.96
#   [VENDA] Data: 2023-10-26 | Venda: R$ 8253.32 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ 81.79
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-13 | Venda: R$ 8982.08 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 731.77
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-19 | Venda: R$ 9271.76 | Vendas Mês (2023, 11): R$ 8982.08 | Lucro: R$ 293.15
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-30 | Venda: R$ 9308.28 | Vendas Mês (2023, 11): R$ 18253.84 | Lucro: R$ 40.21
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 7562.12 | Proporção: 81.24% | IR = R$ 4.90
#   [VENDA] Data: 2023-12-20 | Venda: R$ 9510.30 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ 210.56
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12-26 | Venda: R$ 9626.41 | Vendas Mês (2023, 12): R$ 9510.30 | Lucro: R$ 119.87
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#
# 📊 Resumo de Vendas Mensais:
#   03/2023: R$ 9,974.81 [ISENTO]
#   04/2023: R$ 9,855.14 [ISENTO]
#   05/2023: R$ 9,183.79 [ISENTO]
#   06/2023: R$ 16,616.21 [ISENTO]
#   07/2023: R$ 24,809.80 [TRIBUTÁVEL]
#   08/2023: R$ 8,488.94 [ISENTO]
#   09/2023: R$ 8,631.87 [ISENTO]
#   10/2023: R$ 8,253.32 [ISENTO]
#   11/2023: R$ 27,562.12 [TRIBUTÁVEL]
#   12/2023: R$ 19,136.72 [ISENTO]
# Resultado: Retorno Líquido=-3.87%, Sharpe=-0.09, Total IR=17.28
#
# ============================================================
# Processando JBSS3.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\JBSS3.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (360, 3)
#
# --- Simulação para 2023-01-06 ---
# Min: 13.952577, Max: 24.461023, Média: 16.780018595833337
#   [VENDA] Data: 2023-01-08 | Venda: R$ 10295.48 | Vendas Mês (2023, 1): R$ 0.00 | Lucro: R$ 295.37
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-01-12 | Venda: R$ 9762.99 | Vendas Mês (2023, 1): R$ 10295.48 | Lucro: R$ -528.17
#   [VENDA] Data: 2023-01-21 | Venda: R$ 9753.23 | Vendas Mês (2023, 1): R$ 10295.48 | Lucro: R$ -5.85
#   [VENDA] Data: 2023-01-25 | Venda: R$ 9677.25 | Vendas Mês (2023, 1): R$ 10295.48 | Lucro: R$ -72.04
#   [VENDA] Data: 2023-01-27 | Venda: R$ 9667.58 | Vendas Mês (2023, 1): R$ 10295.48 | Lucro: R$ -5.80
#   [VENDA] Data: 2023-02-22 | Venda: R$ 10191.77 | Vendas Mês (2023, 2): R$ 0.00 | Lucro: R$ 527.85
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-03-20 | Venda: R$ 10256.60 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ 68.88
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-04-03 | Venda: R$ 10335.19 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ 82.66
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-04-06 | Venda: R$ 10324.86 | Vendas Mês (2023, 4): R$ 10335.19 | Lucro: R$ -6.20
#   [VENDA] Data: 2023-04-14 | Venda: R$ 10119.35 | Vendas Mês (2023, 4): R$ 10335.19 | Lucro: R$ -201.30
#   [VENDA] Data: 2023-05-14 | Venda: R$ 10128.03 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 12.72
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-24 | Venda: R$ 10293.32 | Vendas Mês (2023, 5): R$ 10128.03 | Lucro: R$ 169.28
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 421.34 | Proporção: 4.09% | IR = R$ 1.04
#   [VENDA] Data: 2023-11-09 | Venda: R$ 10399.11 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 110.90
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-21 | Venda: R$ 10643.15 | Vendas Mês (2023, 11): R$ 10399.11 | Lucro: R$ 248.10
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 1042.26 | Proporção: 9.79% | IR = R$ 3.64
#
# 📊 Resumo de Vendas Mensais:
#   01/2023: R$ 10,295.48 [ISENTO]
#   02/2023: R$ 10,191.77 [ISENTO]
#   03/2023: R$ 10,256.60 [ISENTO]
#   04/2023: R$ 10,335.19 [ISENTO]
#   05/2023: R$ 20,421.34 [TRIBUTÁVEL]
#   11/2023: R$ 21,042.26 [TRIBUTÁVEL]
#   12/2023: R$ 11,526.56 [ISENTO]
# Resultado: Retorno Líquido=15.22%, Sharpe=1.10, Total IR=4.68
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\JBSS3.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 15.377197, Max: 25.373518, Média: 18.76425957887324
#   [VENDA] Data: 2023-06-19 | Venda: R$ 8773.67 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ -1225.84
#   [VENDA] Data: 2023-07-11 | Venda: R$ 9213.76 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ 443.42
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#
# 📊 Resumo de Vendas Mensais:
#   07/2023: R$ 9,213.76 [ISENTO]
#   12/2023: R$ 12,061.30 [ISENTO]
# Resultado: Retorno Líquido=20.56%, Sharpe=0.64, Total IR=0.00
#
#   Buscando: Janela_15
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\JBSS3.SA_Janela_15_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (350, 3)
#
# --- Simulação para 2023-01-16 ---
# Min: 17.601301, Max: 25.29925, Média: 20.694048945714286
#
# 📊 Resumo de Vendas Mensais:
#   12/2023: R$ 12,134.39 [ISENTO]
# Resultado: Retorno Líquido=21.30%, Sharpe=0.66, Total IR=0.00
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\JBSS3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 16.34845, Max: 25.10826, Média: 19.34316411304348
#
# 📊 Resumo de Vendas Mensais:
#   12/2023: R$ 12,173.72 [ISENTO]
# Resultado: Retorno Líquido=21.69%, Sharpe=0.67, Total IR=0.00
#
# ============================================================
# Processando SOJA3.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\SOJA3.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (360, 3)
#
# --- Simulação para 2023-01-06 ---
# Min: 10.431848, Max: 13.568785, Média: 11.199592376388889
#   [VENDA] Data: 2023-02-14 | Venda: R$ 11423.05 | Vendas Mês (2023, 2): R$ 0.00 | Lucro: R$ 1422.48
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-02-28 | Venda: R$ 11291.80 | Vendas Mês (2023, 2): R$ 11423.05 | Lucro: R$ -126.63
#   [VENDA] Data: 2023-03-05 | Venda: R$ 11618.47 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ 331.05
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-03-26 | Venda: R$ 11930.86 | Vendas Mês (2023, 3): R$ 11618.47 | Lucro: R$ 316.91
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 3549.33 | Proporção: 29.75% | IR = R$ 14.14
#   [VENDA] Data: 2023-05-10 | Venda: R$ 11759.59 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ -152.29
#   [VENDA] Data: 2023-05-21 | Venda: R$ 11817.76 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 62.85
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-04 | Venda: R$ 11919.17 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ 106.09
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-17 | Venda: R$ 12383.54 | Vendas Mês (2023, 7): R$ 11919.17 | Lucro: R$ 468.96
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 4302.71 | Proporção: 34.75% | IR = R$ 24.44
#   [VENDA] Data: 2023-07-20 | Venda: R$ 12529.89 | Vendas Mês (2023, 7): R$ 24302.71 | Lucro: R$ 175.67
#     → SWING: Mês já ultrapassou isenção | IR = R$ 26.35
#   [VENDA] Data: 2023-07-23 | Venda: R$ 12727.32 | Vendas Mês (2023, 7): R$ 36832.60 | Lucro: R$ 228.70
#     → SWING: Mês já ultrapassou isenção | IR = R$ 34.30
#   [VENDA] Data: 2023-07-30 | Venda: R$ 12925.02 | Vendas Mês (2023, 7): R$ 49559.92 | Lucro: R$ 237.00
#     → SWING: Mês já ultrapassou isenção | IR = R$ 35.55
#   [VENDA] Data: 2023-08-10 | Venda: R$ 13900.46 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ 1015.76
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-09 | Venda: R$ 14924.92 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ 1029.61
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-18 | Venda: R$ 15056.18 | Vendas Mês (2023, 10): R$ 14924.92 | Lucro: R$ 137.17
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 9981.10 | Proporção: 66.29% | IR = R$ 13.64
#
# 📊 Resumo de Vendas Mensais:
#   02/2023: R$ 11,423.05 [ISENTO]
#   03/2023: R$ 23,549.33 [TRIBUTÁVEL]
#   05/2023: R$ 11,817.76 [ISENTO]
#   07/2023: R$ 62,484.93 [TRIBUTÁVEL]
#   08/2023: R$ 13,900.46 [ISENTO]
#   10/2023: R$ 29,981.10 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=50.37%, Sharpe=1.54, Total IR=148.43
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\SOJA3.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 10.858762, Max: 14.415308, Média: 11.702664866197184
#   [VENDA] Data: 2023-03-29 | Venda: R$ 12044.05 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ 2043.24
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-08-10 | Venda: R$ 12601.60 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ 562.14
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-09 | Venda: R$ 13530.33 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ 933.40
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-18 | Venda: R$ 13227.85 | Vendas Mês (2023, 10): R$ 13530.33 | Lucro: R$ -296.95
#   [VENDA] Data: 2023-10-30 | Venda: R$ 13538.02 | Vendas Mês (2023, 10): R$ 13530.33 | Lucro: R$ 315.34
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 7068.36 | Proporção: 52.21% | IR = R$ 24.70
#
# 📊 Resumo de Vendas Mensais:
#   03/2023: R$ 12,044.05 [ISENTO]
#   08/2023: R$ 12,601.60 [ISENTO]
#   10/2023: R$ 27,068.36 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=35.08%, Sharpe=1.07, Total IR=24.70
#
#   Buscando: Janela_15
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\SOJA3.SA_Janela_15_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (350, 3)
#
# --- Simulação para 2023-01-16 ---
# Min: 10.447226, Max: 14.155717, Média: 11.444593447142857
#   [VENDA] Data: 2023-02-14 | Venda: R$ 11391.11 | Vendas Mês (2023, 2): R$ 0.00 | Lucro: R$ 1390.56
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-03-01 | Venda: R$ 11639.83 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ 253.17
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-03-05 | Venda: R$ 11976.57 | Vendas Mês (2023, 3): R$ 11639.83 | Lucro: R$ 341.26
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 3616.40 | Proporção: 30.20% | IR = R$ 15.46
#   [VENDA] Data: 2023-03-26 | Venda: R$ 12282.70 | Vendas Mês (2023, 3): R$ 23616.40 | Lucro: R$ 326.25
#     → SWING: Mês já ultrapassou isenção | IR = R$ 48.94
#   [VENDA] Data: 2023-05-11 | Venda: R$ 12338.90 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 110.00
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-14 | Venda: R$ 12449.42 | Vendas Mês (2023, 5): R$ 12338.90 | Lucro: R$ 115.41
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 4788.32 | Proporção: 38.46% | IR = R$ 6.66
#   [VENDA] Data: 2023-07-17 | Venda: R$ 12366.90 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ -70.85
#   [VENDA] Data: 2023-07-23 | Venda: R$ 12774.98 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ 412.86
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-31 | Venda: R$ 12926.25 | Vendas Mês (2023, 7): R$ 12774.98 | Lucro: R$ 156.32
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 5701.24 | Proporção: 44.11% | IR = R$ 10.34
#   [VENDA] Data: 2023-08-03 | Venda: R$ 13167.67 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ 256.83
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-08-10 | Venda: R$ 13923.71 | Vendas Mês (2023, 8): R$ 13167.67 | Lucro: R$ 761.00
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 7091.38 | Proporção: 50.93% | IR = R$ 58.14
#   [VENDA] Data: 2023-10-09 | Venda: R$ 14887.44 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ 1027.02
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-18 | Venda: R$ 14554.61 | Vendas Mês (2023, 10): R$ 14887.44 | Lucro: R$ -326.74
#   [VENDA] Data: 2023-10-30 | Venda: R$ 14895.90 | Vendas Mês (2023, 10): R$ 14887.44 | Lucro: R$ 346.97
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 9783.34 | Proporção: 65.68% | IR = R$ 34.18
#
# 📊 Resumo de Vendas Mensais:
#   02/2023: R$ 11,391.11 [ISENTO]
#   03/2023: R$ 35,899.10 [TRIBUTÁVEL]
#   05/2023: R$ 24,788.32 [TRIBUTÁVEL]
#   07/2023: R$ 25,701.24 [TRIBUTÁVEL]
#   08/2023: R$ 27,091.38 [TRIBUTÁVEL]
#   10/2023: R$ 29,783.34 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=48.56%, Sharpe=1.47, Total IR=173.71
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\SOJA3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 10.899397, Max: 13.954016, Média: 11.623743686956521
#   [VENDA] Data: 2023-03-09 | Venda: R$ 11546.64 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ 1546.02
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-03-26 | Venda: R$ 11857.09 | Vendas Mês (2023, 3): R$ 11546.64 | Lucro: R$ 314.95
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 3403.73 | Proporção: 28.71% | IR = R$ 13.56
#   [VENDA] Data: 2023-08-10 | Venda: R$ 12391.79 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ 552.78
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-09 | Venda: R$ 13305.06 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ 917.86
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-19 | Venda: R$ 13670.62 | Vendas Mês (2023, 10): R$ 13305.06 | Lucro: R$ 370.74
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 6975.68 | Proporção: 51.03% | IR = R$ 28.38
#   [VENDA] Data: 2023-10-30 | Venda: R$ 13962.13 | Vendas Mês (2023, 10): R$ 26975.68 | Lucro: R$ 325.22
#     → SWING: Mês já ultrapassou isenção | IR = R$ 48.78
#
# 📊 Resumo de Vendas Mensais:
#   03/2023: R$ 23,403.73 [TRIBUTÁVEL]
#   08/2023: R$ 12,391.79 [ISENTO]
#   10/2023: R$ 40,937.81 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=39.08%, Sharpe=1.21, Total IR=90.72
#
# ============================================================
# Processando SUZB3.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\SUZB3.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (360, 3)
#
# --- Simulação para 2023-01-06 ---
# Min: 37.320923, Max: 52.168716, Média: 45.86675355555556
#   [VENDA] Data: 2023-01-08 | Venda: R$ 10128.08 | Vendas Mês (2023, 1): R$ 0.00 | Lucro: R$ 128.03
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-01-11 | Venda: R$ 10174.64 | Vendas Mês (2023, 1): R$ 10128.08 | Lucro: R$ 50.59
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 302.72 | Proporção: 2.98% | IR = R$ 0.23
#   [VENDA] Data: 2023-01-16 | Venda: R$ 10323.47 | Vendas Mês (2023, 1): R$ 20302.72 | Lucro: R$ 153.06
#     → SWING: Mês já ultrapassou isenção | IR = R$ 22.96
#   [VENDA] Data: 2023-04-27 | Venda: R$ 8214.00 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -2081.55
#   [VENDA] Data: 2023-05-04 | Venda: R$ 8578.97 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 368.11
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-17 | Venda: R$ 9340.72 | Vendas Mês (2023, 5): R$ 8578.97 | Lucro: R$ 764.88
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-25 | Venda: R$ 9317.00 | Vendas Mês (2023, 5): R$ 17919.69 | Lucro: R$ -19.97
#   [VENDA] Data: 2023-06-01 | Venda: R$ 9527.29 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ 213.93
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-11 | Venda: R$ 9575.18 | Vendas Mês (2023, 6): R$ 9527.29 | Lucro: R$ 51.68
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-14 | Venda: R$ 9827.87 | Vendas Mês (2023, 6): R$ 19102.47 | Lucro: R$ 256.42
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 8930.35 | Proporção: 90.87% | IR = R$ 34.95
#   [VENDA] Data: 2023-07-30 | Venda: R$ 9736.53 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ -52.44
#   [VENDA] Data: 2023-08-02 | Venda: R$ 10082.24 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ 349.46
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-08-09 | Venda: R$ 9991.18 | Vendas Mês (2023, 8): R$ 10082.24 | Lucro: R$ -86.99
#   [VENDA] Data: 2023-08-15 | Venda: R$ 9955.26 | Vendas Mês (2023, 8): R$ 10082.24 | Lucro: R$ -31.91
#   [VENDA] Data: 2023-08-21 | Venda: R$ 9899.63 | Vendas Mês (2023, 8): R$ 10082.24 | Lucro: R$ -51.63
#   [VENDA] Data: 2023-08-23 | Venda: R$ 9863.75 | Vendas Mês (2023, 8): R$ 10082.24 | Lucro: R$ -31.91
#   [VENDA] Data: 2023-08-31 | Venda: R$ 10040.55 | Vendas Mês (2023, 8): R$ 10082.24 | Lucro: R$ 180.68
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 122.79 | Proporção: 1.22% | IR = R$ 0.33
#   [VENDA] Data: 2023-09-06 | Venda: R$ 10030.18 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ -6.02
#   [VENDA] Data: 2023-09-08 | Venda: R$ 10020.16 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ -6.01
#   [VENDA] Data: 2023-12-01 | Venda: R$ 10010.14 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ -6.01
#
# 📊 Resumo de Vendas Mensais:
#   01/2023: R$ 30,626.19 [TRIBUTÁVEL]
#   05/2023: R$ 17,919.69 [ISENTO]
#   06/2023: R$ 28,930.35 [TRIBUTÁVEL]
#   08/2023: R$ 20,122.79 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=0.06%, Sharpe=0.09, Total IR=58.47
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\SUZB3.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 36.292202, Max: 54.14424, Média: 46.37154748169014
#   [VENDA] Data: 2023-04-10 | Venda: R$ 8460.90 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -1538.49
#   [VENDA] Data: 2023-04-27 | Venda: R$ 7971.73 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -485.59
#   [VENDA] Data: 2023-05-04 | Venda: R$ 8325.94 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 357.25
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-17 | Venda: R$ 9065.22 | Vendas Mês (2023, 5): R$ 8325.94 | Lucro: R$ 742.32
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-25 | Venda: R$ 9042.20 | Vendas Mês (2023, 5): R$ 17391.15 | Lucro: R$ -19.39
#   [VENDA] Data: 2023-06-01 | Venda: R$ 9246.29 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ 207.62
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-11 | Venda: R$ 9292.76 | Vendas Mês (2023, 6): R$ 9246.29 | Lucro: R$ 50.15
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-14 | Venda: R$ 9538.01 | Vendas Mês (2023, 6): R$ 18539.05 | Lucro: R$ 248.86
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 8077.06 | Proporção: 84.68% | IR = R$ 31.61
#   [VENDA] Data: 2023-07-25 | Venda: R$ 9137.06 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ -365.37
#   [VENDA] Data: 2023-07-30 | Venda: R$ 9296.17 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ 162.70
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-08-02 | Venda: R$ 9528.74 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ 236.20
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-08-10 | Venda: R$ 9500.28 | Vendas Mês (2023, 8): R$ 9528.74 | Lucro: R$ -24.64
#   [VENDA] Data: 2023-08-13 | Venda: R$ 9632.66 | Vendas Mês (2023, 8): R$ 9528.74 | Lucro: R$ 136.13
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-08-16 | Venda: R$ 9692.27 | Vendas Mês (2023, 8): R$ 19161.41 | Lucro: R$ 63.43
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 8853.67 | Proporção: 91.35% | IR = R$ 8.69
# ...
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 7448.60 | Proporção: 79.88% | IR = R$ 29.15
#   [VENDA] Data: 2023-07-30 | Venda: R$ 9241.84 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ -49.77
#   [VENDA] Data: 2023-08-02 | Venda: R$ 9473.05 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ 234.82
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-09-06 | Venda: R$ 9463.58 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ -5.68
#   [VENDA] Data: 2023-09-10 | Venda: R$ 9680.79 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ 220.90
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-24 | Venda: R$ 9687.69 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ 10.77
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-14 | Venda: R$ 9678.00 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ -5.81
#   [VENDA] Data: 2023-12-01 | Venda: R$ 9668.33 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ -5.80
#
# 📊 Resumo de Vendas Mensais:
#   05/2023: R$ 8,839.81 [ISENTO]
#   06/2023: R$ 27,448.60 [TRIBUTÁVEL]
#   08/2023: R$ 9,473.05 [ISENTO]
#   09/2023: R$ 9,680.79 [ISENTO]
#   10/2023: R$ 9,687.69 [ISENTO]
# Resultado: Retorno Líquido=-3.36%, Sharpe=-0.06, Total IR=29.15
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\SUZB3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 38.28282, Max: 53.243423, Média: 46.4245221768116
#   [VENDA] Data: 2023-06-01 | Venda: R$ 9841.35 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ -158.58
#   [VENDA] Data: 2023-06-11 | Venda: R$ 9890.82 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ 53.38
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-14 | Venda: R$ 10238.89 | Vendas Mês (2023, 6): R$ 9890.82 | Lucro: R$ 351.89
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 129.71 | Proporção: 1.27% | IR = R$ 0.67
#   [VENDA] Data: 2023-07-30 | Venda: R$ 10179.28 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ -54.82
#   [VENDA] Data: 2023-08-02 | Venda: R$ 10433.95 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ 258.63
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-08-06 | Venda: R$ 10475.36 | Vendas Mês (2023, 8): R$ 10433.95 | Lucro: R$ 45.56
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 909.31 | Proporção: 8.68% | IR = R$ 0.59
#   [VENDA] Data: 2023-08-10 | Venda: R$ 10552.63 | Vendas Mês (2023, 8): R$ 20909.31 | Lucro: R$ 82.03
#     → SWING: Mês já ultrapassou isenção | IR = R$ 12.30
#   [VENDA] Data: 2023-08-13 | Venda: R$ 10687.20 | Vendas Mês (2023, 8): R$ 31461.94 | Lucro: R$ 151.03
#     → SWING: Mês já ultrapassou isenção | IR = R$ 22.65
#   [VENDA] Data: 2023-08-24 | Venda: R$ 10624.07 | Vendas Mês (2023, 8): R$ 42149.14 | Lucro: R$ -36.19
#   [VENDA] Data: 2023-08-28 | Venda: R$ 10879.32 | Vendas Mês (2023, 8): R$ 42149.14 | Lucro: R$ 259.39
#     → SWING: Mês já ultrapassou isenção | IR = R$ 38.91
#   [VENDA] Data: 2023-08-31 | Venda: R$ 10887.08 | Vendas Mês (2023, 8): R$ 53028.45 | Lucro: R$ 51.00
#     → SWING: Mês já ultrapassou isenção | IR = R$ 7.65
#   [VENDA] Data: 2023-09-10 | Venda: R$ 10628.21 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ -246.77
#   [VENDA] Data: 2023-09-13 | Venda: R$ 10820.35 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ 196.31
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-09-18 | Venda: R$ 10961.13 | Vendas Mês (2023, 9): R$ 10820.35 | Lucro: R$ 145.06
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 1781.48 | Proporção: 16.25% | IR = R$ 3.54
#   [VENDA] Data: 2023-10-25 | Venda: R$ 10988.34 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ 35.11
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-27 | Venda: R$ 10977.35 | Vendas Mês (2023, 10): R$ 10988.34 | Lucro: R$ -6.59
#   [VENDA] Data: 2023-11-05 | Venda: R$ 11017.33 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 44.36
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-14 | Venda: R$ 11006.32 | Vendas Mês (2023, 11): R$ 11017.33 | Lucro: R$ -6.60
#   [VENDA] Data: 2023-12-02 | Venda: R$ 10995.32 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ -6.60
#   [VENDA] Data: 2023-12-07 | Venda: R$ 11092.64 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ 101.67
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12-12 | Venda: R$ 11275.08 | Vendas Mês (2023, 12): R$ 11092.64 | Lucro: R$ 186.81
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 2367.72 | Proporção: 21.00% | IR = R$ 5.88
#
# 📊 Resumo de Vendas Mensais:
#   06/2023: R$ 20,129.71 [TRIBUTÁVEL]
#   08/2023: R$ 63,915.53 [TRIBUTÁVEL]
#   09/2023: R$ 21,781.48 [TRIBUTÁVEL]
#   10/2023: R$ 10,988.34 [ISENTO]
#   11/2023: R$ 11,017.33 [ISENTO]
#   12/2023: R$ 22,367.72 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=12.65%, Sharpe=0.58, Total IR=92.20
#
# ============================================================
# Processando GGBR3.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\GGBR3.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (360, 3)
#
# --- Simulação para 2023-01-06 ---
# Min: 15.130935, Max: 16.53504, Média: 15.777552954166667
#
# 📊 Resumo de Vendas Mensais:
# Resultado: Retorno Líquido=0.00%, Sharpe=0.00, Total IR=0.00
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\GGBR3.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 14.809369, Max: 16.103897, Média: 15.495092461971831
#
# 📊 Resumo de Vendas Mensais:
# Resultado: Retorno Líquido=0.00%, Sharpe=0.00, Total IR=0.00
#
#   Buscando: Janela_15
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\GGBR3.SA_Janela_15_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (350, 3)
#
# --- Simulação para 2023-01-16 ---
# Min: 14.726762, Max: 16.040504, Média: 15.442972390000001
#
# 📊 Resumo de Vendas Mensais:
# Resultado: Retorno Líquido=0.00%, Sharpe=0.00, Total IR=0.00
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\GGBR3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 15.0608, Max: 16.702908, Média: 15.87440807536232
#
# 📊 Resumo de Vendas Mensais:
# Resultado: Retorno Líquido=0.00%, Sharpe=0.00, Total IR=0.00
#
# ============================================================
# Processando CSNA3.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\CSNA3.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (360, 3)
#
# --- Simulação para 2023-01-06 ---
# Min: 11.091227, Max: 17.838554, Média: 13.218561798611113
#   [VENDA] Data: 2023-01-09 | Venda: R$ 10516.12 | Vendas Mês (2023, 1): R$ 0.00 | Lucro: R$ 515.91
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-03-02 | Venda: R$ 11173.31 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ 661.13
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-04-10 | Venda: R$ 9895.39 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -1272.95
#   [VENDA] Data: 2023-11-19 | Venda: R$ 10499.80 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 608.12
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12-14 | Venda: R$ 11984.92 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ 1488.73
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12-17 | Venda: R$ 12304.97 | Vendas Mês (2023, 12): R$ 11984.92 | Lucro: R$ 324.71
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 4289.89 | Proporção: 34.86% | IR = R$ 16.98
#   [VENDA] Data: 2023-12-20 | Venda: R$ 12723.18 | Vendas Mês (2023, 12): R$ 24289.89 | Lucro: R$ 439.94
#     → SWING: Mês já ultrapassou isenção | IR = R$ 65.99
#   [VENDA] Data: 2023-12-27 | Venda: R$ 13008.43 | Vendas Mês (2023, 12): R$ 37013.07 | Lucro: R$ 356.18
#     → SWING: Mês já ultrapassou isenção | IR = R$ 53.43
#
# 📊 Resumo de Vendas Mensais:
#   01/2023: R$ 10,516.12 [ISENTO]
#   03/2023: R$ 11,173.31 [ISENTO]
#   11/2023: R$ 10,499.80 [ISENTO]
#   12/2023: R$ 50,021.50 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=29.37%, Sharpe=0.72, Total IR=136.40
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\CSNA3.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 11.269419, Max: 16.983746, Média: 13.449687509859155
#   [VENDA] Data: 2023-11-19 | Venda: R$ 10050.75 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 50.73
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-30 | Venda: R$ 11030.63 | Vendas Mês (2023, 11): R$ 10050.75 | Lucro: R$ 983.51
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 1081.38 | Proporção: 9.80% | IR = R$ 14.46
#   [VENDA] Data: 2023-12-07 | Venda: R$ 11154.31 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ 142.50
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12-12 | Venda: R$ 11350.47 | Vendas Mês (2023, 12): R$ 11154.31 | Lucro: R$ 200.54
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 2504.78 | Proporção: 22.07% | IR = R$ 6.64
#
# 📊 Resumo de Vendas Mensais:
#   11/2023: R$ 21,081.38 [TRIBUTÁVEL]
#   12/2023: R$ 22,504.78 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=13.39%, Sharpe=0.44, Total IR=21.10
#
#   Buscando: Janela_15
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\CSNA3.SA_Janela_15_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (350, 3)
#
# --- Simulação para 2023-01-16 ---
# Min: 11.172258, Max: 15.645166, Média: 12.860363999999999
#   [VENDA] Data: 2023-06-05 | Venda: R$ 8233.39 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ -1765.90
#   [VENDA] Data: 2023-06-08 | Venda: R$ 8295.24 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ 65.12
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-13 | Venda: R$ 8318.77 | Vendas Mês (2023, 6): R$ 8295.24 | Lucro: R$ 26.84
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-24 | Venda: R$ 8753.85 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ 438.23
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-30 | Venda: R$ 8795.94 | Vendas Mês (2023, 7): R$ 8753.85 | Lucro: R$ 45.58
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-15 | Venda: R$ 9422.13 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 629.46
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#
# 📊 Resumo de Vendas Mensais:
#   06/2023: R$ 16,614.01 [ISENTO]
#   07/2023: R$ 17,549.79 [ISENTO]
#   11/2023: R$ 9,422.13 [ISENTO]
# Resultado: Retorno Líquido=-5.82%, Sharpe=0.01, Total IR=0.00
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro\CSNA3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 10.524379, Max: 16.91585, Média: 13.093967973913042
#   [VENDA] Data: 2023-05-31 | Venda: R$ 7167.83 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ -2831.04
#   [VENDA] Data: 2023-06-13 | Venda: R$ 7386.73 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ 221.68
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-22 | Venda: R$ 7362.13 | Vendas Mês (2023, 6): R$ 7386.73 | Lucro: R$ -21.64
#   [VENDA] Data: 2023-06-28 | Venda: R$ 7441.10 | Vendas Mês (2023, 6): R$ 7386.73 | Lucro: R$ 81.88
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-06 | Venda: R$ 7795.23 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ 356.97
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-12 | Venda: R$ 8211.63 | Vendas Mês (2023, 7): R$ 7795.23 | Lucro: R$ 419.35
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-24 | Venda: R$ 8795.29 | Vendas Mês (2023, 7): R$ 16006.86 | Lucro: R$ 586.71
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 4802.15 | Proporção: 54.60% | IR = R$ 48.05
#   [VENDA] Data: 2023-07-30 | Venda: R$ 8985.18 | Vendas Mês (2023, 7): R$ 24802.15 | Lucro: R$ 241.36
#     → SWING: Mês já ultrapassou isenção | IR = R$ 36.20
#   [VENDA] Data: 2023-11-15 | Venda: R$ 9874.34 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 928.59
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-19 | Venda: R$ 10800.47 | Vendas Mês (2023, 11): R$ 9874.34 | Lucro: R$ 929.70
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 674.82 | Proporção: 6.25% | IR = R$ 8.71
#   [VENDA] Data: 2023-11-26 | Venda: R$ 11043.24 | Vendas Mês (2023, 11): R$ 20674.82 | Lucro: R$ 255.70
#     → SWING: Mês já ultrapassou isenção | IR = R$ 38.36
#   [VENDA] Data: 2023-12-14 | Venda: R$ 11653.11 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ 652.38
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#
# 📊 Resumo de Vendas Mensais:
#   06/2023: R$ 14,827.83 [ISENTO]
#   07/2023: R$ 33,787.32 [TRIBUTÁVEL]
#   11/2023: R$ 31,718.06 [TRIBUTÁVEL]
#   12/2023: R$ 11,653.11 [ISENTO]
# Resultado: Retorno Líquido=16.48%, Sharpe=0.52, Total IR=131.32
#
# ✓ Resultados salvos em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\MacroResultados\resultados_trading_realista_transformer.csv
# ✓ Diagnósticos salvos em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\MacroResultados\diagnosticos_trading_realista_transformer.csv
# ✓ Melhores resultados salvos em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\MacroResultados\melhores_resultados_realista_transformer.csv
# C:\Users\leona\AppData\Local\Temp\ipykernel_28168\3400981006.py:514: UserWarning: Glyph 129302 (\N{ROBOT FACE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\leona\AppData\Local\Temp\ipykernel_28168\3400981006.py:514: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\leona\AppData\Local\Temp\ipykernel_28168\3400981006.py:517: UserWarning: Glyph 129302 (\N{ROBOT FACE}) missing from font(s) DejaVu Sans.
#   plt.savefig(grafico_filepath, dpi=300, bbox_inches='tight')
# C:\Users\leona\AppData\Local\Temp\ipykernel_28168\3400981006.py:517: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.savefig(grafico_filepath, dpi=300, bbox_inches='tight')
# ✓ Gráfico salvo em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\MacroResultados\trading_realista_transformer_completo.png
# c:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129302 (\N{ROBOT FACE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ================================================================================
#                               ✅ EXECUÇÃO CONCLUÍDA
# ================================================================================
