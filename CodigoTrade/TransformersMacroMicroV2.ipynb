# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from datetime import datetime

# --- Parâmetros Reais de Mercado (B3 2026) ---
TAXA_NEGOCIACAO_LIQUIDACAO = 0.00030  # 0,03%
TAXA_DAY_TRADE = 0.00023              # 0,023%
SLIPPAGE = 0.0001                     # 0,01%
IR_SWING_TRADE = 0.15                 # 15%
IR_DAY_TRADE = 0.20                   # 20%
ISENCAO_VENDA_MENSAL = 20000          # R$ 20k

# Diretório FLAT onde estão os arquivos de previsões (ALTERADO)
input_dir = r"C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro"

# Diretório onde os resultados serão salvos
output_dir = r"C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\MacroResultados"
os.makedirs(output_dir, exist_ok=True)

transactions_dir = os.path.join(output_dir, "Transacoes")
os.makedirs(transactions_dir, exist_ok=True)

# Lista de tickers
tickers = ["BEEF3.SA", "BRFS3.SA", "VALE3.SA", "JBSS3.SA", "SOJA3.SA", 
           "SUZB3.SA", "GGBR3.SA", "CSNA3.SA"]

# Lista de janelas (AJUSTADO para o formato Transformer)
janelas = ["Janela_5", "Janela_10", "Janela_15", "Janela_20"]

def calcular_metricas_risco(historico_patrimonio, saldo_inicial):
    """Calcula Maximum Drawdown e Sharpe Ratio."""
    if not historico_patrimonio or len(historico_patrimonio) < 2:
        return {'max_drawdown': 0.0, 'sharpe_ratio': 0.0}
    
    patrimonio_array = np.array(historico_patrimonio)
    pico = np.maximum.accumulate(patrimonio_array)
    drawdown = (patrimonio_array - pico) / pico
    max_drawdown = np.min(drawdown) * 100
    
    retornos = np.diff(patrimonio_array) / patrimonio_array[:-1]
    if len(retornos) > 0 and np.std(retornos) != 0:
        sharpe_ratio = np.mean(retornos) / np.std(retornos) * np.sqrt(252)
    else:
        sharpe_ratio = 0.0
    
    return {
        'max_drawdown': max_drawdown,
        'sharpe_ratio': sharpe_ratio
    }

def estrategia_all_in_realista(dados_brutos, saldo_inicial):
    """Estratégia All-In com custos reais da B3 e IR CORRIGIDO."""
    dados = dados_brutos.copy()
    dados['Preço Real'] = pd.to_numeric(dados['Preço Real'], errors='coerce')
    dados['Preço Previsto'] = pd.to_numeric(dados['Preço Previsto'], errors='coerce')
    dados['Data'] = pd.to_datetime(dados['Data'])
    
    previsoes = dados['Preço Previsto'].dropna()
    min_previsto = previsoes.min() if len(previsoes) > 0 else None
    max_previsto = previsoes.max() if len(previsoes) > 0 else None
    media_previsoes = previsoes.mean() if len(previsoes) > 0 else None
    
    identifier = dados_brutos['Data'].iloc[0] if not dados_brutos.empty else "Unknown"
    print(f"\n--- Simulação para {identifier} ---")
    print(f"Min: {min_previsto}, Max: {max_previsto}, Média: {media_previsoes}")
    
    # Bloquear previsões extremas
    is_extremely_negative = False
    if min_previsto is not None and isinstance(min_previsto, (int, float)) and min_previsto < -1000:
        is_extremely_negative = True
        print(f"!!! Previsão mínima ({min_previsto}) < -1000. Bloqueando transações. !!!")
    
    if is_extremely_negative:
        diagnostico = {
            'Previsões Razoáveis': False,
            'Estratégia Usada': 'Sem transações - Previsões Negativas',
            'Total de Transações': 0,
            'Retorno (%)': 0.0,
            'Retorno Liquido (%)': 0.0,
            'Max Drawdown (%)': 0.0,
            'Sharpe Ratio': 0.0,
            'Total Custos (R$)': 0.0,
            'Total Impostos (R$)': 0.0,
            'Min Previsto': min_previsto,
            'Max Previsto': max_previsto,
            'Média Previsto': media_previsoes
        }
        return saldo_inicial, [], diagnostico
    
    # Inicializar variáveis
    saldo = saldo_inicial
    quantidade_acoes = 0
    transacoes = []
    historico_patrimonio = [saldo_inicial]
    
    total_custos_operacionais = 0.0
    total_impostos = 0.0
    vendas_no_mes = {}  # ✅ (ano, mês): valor_vendas_acumulado
    data_compra = None
    preco_compra = 0.0
    
    for i in range(len(dados) - 1):
        data_atual = dados.iloc[i]['Data']
        preco_real = dados.iloc[i]['Preço Real']
        
        if pd.isna(preco_real) or preco_real <= 0:
            continue
        
        preco_previsto = dados.iloc[i + 1]['Preço Previsto']
        if pd.isna(preco_previsto):
            continue
        
        # COMPRA
        if quantidade_acoes == 0 and preco_previsto > preco_real:
            preco_com_slippage = preco_real * (1 + SLIPPAGE)
            custos_compra = saldo * (TAXA_NEGOCIACAO_LIQUIDACAO + SLIPPAGE)
            saldo_pos_custo = saldo - custos_compra
            
            if saldo_pos_custo > 0:
                quantidade_acoes = saldo_pos_custo / preco_com_slippage
                valor_investido = quantidade_acoes * preco_com_slippage
                saldo = 0
                total_custos_operacionais += custos_compra
                
                data_compra = data_atual
                preco_compra = preco_com_slippage
                
                transacoes.append({
                    'Data': data_atual,
                    'Acao': 'Compra',
                    'Preco': preco_real,
                    'Preco_Executado': preco_com_slippage,
                    'Quantidade': quantidade_acoes,
                    'Valor_Total': valor_investido,
                    'Custos_Operacionais': custos_compra,
                    'Saldo_Restante': saldo
                })
        
        # VENDA
        elif quantidade_acoes > 0 and preco_previsto < preco_real and i < len(dados) - 2:
            preco_com_slippage = preco_real * (1 - SLIPPAGE)
            valor_bruto_venda = quantidade_acoes * preco_com_slippage
            custos_venda = valor_bruto_venda * (TAXA_NEGOCIACAO_LIQUIDACAO + SLIPPAGE)
            
            is_day_trade = (data_atual.date() == data_compra.date()) if data_compra else False
            
            custo_aquisicao = quantidade_acoes * preco_compra
            lucro_bruto = valor_bruto_venda - custo_aquisicao - custos_venda
            
            imposto = 0.0
            mes_ano = (data_atual.year, data_atual.month)
            
            # ✅ LOG DETALHADO PARA DEBUG
            vendas_mes_atual = vendas_no_mes.get(mes_ano, 0.0)
            print(f"  [VENDA] Data: {data_atual.date()} | Venda: R$ {valor_bruto_venda:.2f} | "
                  f"Vendas Mês {mes_ano}: R$ {vendas_mes_atual:.2f} | Lucro: R$ {lucro_bruto:.2f}")
            
            if lucro_bruto > 0:
                if is_day_trade:
                    # Day Trade: SEMPRE cobra 20%
                    imposto = lucro_bruto * IR_DAY_TRADE
                    print(f"    → DAY TRADE: IR = R$ {imposto:.2f} (20% sobre lucro)")
                else:
                    # ✅ SWING TRADE: Lógica CORRIGIDA
                    vendas_anteriores = vendas_no_mes.get(mes_ano, 0.0)
                    vendas_totais_mes = vendas_anteriores + valor_bruto_venda
                    
                    if vendas_totais_mes > ISENCAO_VENDA_MENSAL:
                        if vendas_anteriores >= ISENCAO_VENDA_MENSAL:
                            # Já ultrapassou antes: tributa TUDO
                            imposto = lucro_bruto * IR_SWING_TRADE
                            print(f"    → SWING: Mês já ultrapassou isenção | IR = R$ {imposto:.2f}")
                        else:
                            # Primeira vez ultrapassando: tributar proporcionalmente
                            valor_excedente = vendas_totais_mes - ISENCAO_VENDA_MENSAL
                            proporcao_tributavel = valor_excedente / valor_bruto_venda
                            lucro_tributavel = lucro_bruto * proporcao_tributavel
                            imposto = lucro_tributavel * IR_SWING_TRADE
                            print(f"    → SWING: 1ª vez ultrapassando | Excedente: R$ {valor_excedente:.2f} | "
                                  f"Proporção: {proporcao_tributavel:.2%} | IR = R$ {imposto:.2f}")
                    else:
                        print(f"    → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00")
                    
                    # Atualizar contador do mês
                    vendas_no_mes[mes_ano] = vendas_totais_mes
            
            valor_liquido_venda = valor_bruto_venda - custos_venda - imposto
            saldo = valor_liquido_venda
            total_custos_operacionais += custos_venda
            total_impostos += imposto
            
            transacoes.append({
                'Data': data_atual,
                'Acao': 'Venda Day Trade' if is_day_trade else 'Venda',
                'Preco': preco_real,
                'Preco_Executado': preco_com_slippage,
                'Quantidade': quantidade_acoes,
                'Valor_Bruto': valor_bruto_venda,
                'Custos_Operacionais': custos_venda,
                'Lucro_Bruto': lucro_bruto,
                'Imposto': imposto,
                'Valor_Liquido': valor_liquido_venda,
                'Saldo_Restante': saldo,
                'Vendas_Acumuladas_Mes': vendas_no_mes.get(mes_ano, 0.0)  # ✅ NOVO CAMPO
            })
            
            quantidade_acoes = 0
            data_compra = None
        
        patrimonio_atual = saldo + (quantidade_acoes * preco_real if quantidade_acoes > 0 else 0)
        historico_patrimonio.append(patrimonio_atual)
    
    # Venda final (MESMA LÓGICA)
    if quantidade_acoes > 0:
        ultimo_preco = dados.iloc[-1]['Preço Real']
        data_final = dados.iloc[-1]['Data']
        
        if not pd.isna(ultimo_preco) and ultimo_preco > 0:
            preco_com_slippage = ultimo_preco * (1 - SLIPPAGE)
            valor_bruto_venda = quantidade_acoes * preco_com_slippage
            custos_venda = valor_bruto_venda * (TAXA_NEGOCIACAO_LIQUIDACAO + SLIPPAGE)
            
            is_day_trade = (data_final.date() == data_compra.date()) if data_compra else False
            
            custo_aquisicao = quantidade_acoes * preco_compra
            lucro_bruto = valor_bruto_venda - custo_aquisicao - custos_venda
            
            imposto = 0.0
            mes_ano = (data_final.year, data_final.month)
            
            if lucro_bruto > 0:
                if is_day_trade:
                    imposto = lucro_bruto * IR_DAY_TRADE
                else:
                    vendas_anteriores = vendas_no_mes.get(mes_ano, 0.0)
                    vendas_totais_mes = vendas_anteriores + valor_bruto_venda
                    
                    if vendas_totais_mes > ISENCAO_VENDA_MENSAL:
                        if vendas_anteriores >= ISENCAO_VENDA_MENSAL:
                            imposto = lucro_bruto * IR_SWING_TRADE
                        else:
                            valor_excedente = vendas_totais_mes - ISENCAO_VENDA_MENSAL
                            proporcao_tributavel = valor_excedente / valor_bruto_venda
                            lucro_tributavel = lucro_bruto * proporcao_tributavel
                            imposto = lucro_tributavel * IR_SWING_TRADE
                    
                    vendas_no_mes[mes_ano] = vendas_totais_mes
            
            valor_liquido_venda = valor_bruto_venda - custos_venda - imposto
            saldo = valor_liquido_venda
            total_custos_operacionais += custos_venda
            total_impostos += imposto
            
            transacoes.append({
                'Data': data_final,
                'Acao': 'Venda Final',
                'Preco': ultimo_preco,
                'Preco_Executado': preco_com_slippage,
                'Quantidade': quantidade_acoes,
                'Valor_Bruto': valor_bruto_venda,
                'Custos_Operacionais': custos_venda,
                'Lucro_Bruto': lucro_bruto,
                'Imposto': imposto,
                'Valor_Liquido': valor_liquido_venda,
                'Saldo_Restante': saldo,
                'Vendas_Acumuladas_Mes': vendas_no_mes.get(mes_ano, 0.0)
            })
    
    # ✅ RESUMO MENSAL DE IR (DEBUG)
    print(f"\n📊 Resumo de Vendas Mensais:")
    for mes_ano, total_vendas in sorted(vendas_no_mes.items()):
        status = "TRIBUTÁVEL" if total_vendas > ISENCAO_VENDA_MENSAL else "ISENTO"
        print(f"  {mes_ano[1]:02d}/{mes_ano[0]}: R$ {total_vendas:,.2f} [{status}]")
    
    metricas_risco = calcular_metricas_risco(historico_patrimonio, saldo_inicial)
    
    retorno_bruto = ((saldo + total_custos_operacionais + total_impostos - saldo_inicial) / saldo_inicial) * 100
    retorno_liquido = ((saldo - saldo_inicial) / saldo_inicial) * 100
    
    previsoes_razoaveis = not is_extremely_negative
    estrategia_usada = 'Trading Realista (B3)' if len(transacoes) > 0 else 'Sem transações'
    
    diagnostico = {
        'Previsões Razoáveis': previsoes_razoaveis,
        'Estratégia Usada': estrategia_usada,
        'Total de Transações': len(transacoes),
        'Retorno Bruto (%)': retorno_bruto,
        'Retorno Liquido (%)': retorno_liquido,
        'Max Drawdown (%)': metricas_risco['max_drawdown'],
        'Sharpe Ratio': metricas_risco['sharpe_ratio'],
        'Total Custos (R$)': total_custos_operacionais,
        'Total Impostos (R$)': total_impostos,
        'Min Previsto': min_previsto,
        'Max Previsto': max_previsto,
        'Média Previsto': media_previsoes
    }
    
    print(f"Resultado: Retorno Líquido={retorno_liquido:.2f}%, Sharpe={metricas_risco['sharpe_ratio']:.2f}, Total IR={total_impostos:.2f}")
    
    return saldo, transacoes, diagnostico

def processar_previsoes_realista(input_dir, tickers, janelas, saldo_inicial):
    """
    Processa previsões com estrutura FLAT de arquivos.
    Formato esperado: TICKER_JANELA_X_previsoes_teste_final.csv
    """
    resultados = []
    todas_transacoes = {}
    todos_diagnosticos = {}
    
    for ticker in tickers:
        print(f"\n{'='*60}")
        print(f"Processando {ticker}...")
        print(f"{'='*60}")
        
        ticker_resultados = {'Ticker': ticker}
        todas_transacoes[ticker] = {}
        todos_diagnosticos[ticker] = {}
        
        for janela in janelas:
            previsoes_file = os.path.join(input_dir, f"{ticker}_{janela}_previsoes_teste_final.csv")
            
            print(f"\n  Buscando: {janela}")
            print(f"  Caminho: {previsoes_file}")
            
            if os.path.exists(previsoes_file):
                try:
                    dados = pd.read_csv(previsoes_file)
                    print(f"  ✓ Arquivo encontrado! Shape: {dados.shape}")
                    
                    saldo_final, transacoes, diagnostico = estrategia_all_in_realista(dados, saldo_inicial)
                    
                    todas_transacoes[ticker][janela] = transacoes
                    todos_diagnosticos[ticker][janela] = diagnostico
                    
                    ticker_resultados[f"Saldo Final {janela}"] = saldo_final
                    ticker_resultados[f"Retorno Liquido {janela} (%)"] = diagnostico['Retorno Liquido (%)']
                    ticker_resultados[f"Sharpe {janela}"] = diagnostico['Sharpe Ratio']
                    ticker_resultados[f"Drawdown {janela} (%)"] = diagnostico['Max Drawdown (%)']
                    ticker_resultados[f"Custos {janela} (R$)"] = diagnostico['Total Custos (R$)']
                    ticker_resultados[f"Impostos {janela} (R$)"] = diagnostico['Total Impostos (R$)']
                    
                except Exception as e:
                    print(f"  ❌ Erro ao processar {ticker} - {janela}: {str(e)}")
                    import traceback
                    traceback.print_exc()
                    
                    ticker_resultados[f"Saldo Final {janela}"] = saldo_inicial
                    ticker_resultados[f"Retorno Liquido {janela} (%)"] = 0.0
            else:
                print(f"  ❌ Arquivo não encontrado!")
                ticker_resultados[f"Saldo Final {janela}"] = saldo_inicial
                ticker_resultados[f"Retorno Liquido {janela} (%)"] = 0.0
        
        resultados.append(ticker_resultados)
    
    return pd.DataFrame(resultados), todas_transacoes, todos_diagnosticos

# --- CÓDIGO PRINCIPAL ---
saldo_inicial = 10000

print("\n" + "="*80)
print(" "*20 + "SIMULAÇÃO REALISTA DE TRADING - B3 2026")
print("="*80)
print(f"Saldo Inicial: R$ {saldo_inicial:,.2f}")
print(f"Taxa B3: {TAXA_NEGOCIACAO_LIQUIDACAO*100:.3f}% | Slippage: {SLIPPAGE*100:.3f}%")
print(f"IR Swing Trade: {IR_SWING_TRADE*100:.1f}% | IR Day Trade: {IR_DAY_TRADE*100:.1f}%")
print(f"Isenção Mensal: R$ {ISENCAO_VENDA_MENSAL:,.2f}")
print(f"Pasta de Dados: {input_dir}")
print("="*80 + "\n")

df_resultados, todas_transacoes, todos_diagnosticos = processar_previsoes_realista(
    input_dir, tickers, janelas, saldo_inicial
)

# Salvar resultados
resultados_filepath = os.path.join(output_dir, "resultados_trading_realista_transformer.csv")
df_resultados.to_csv(resultados_filepath, index=False)
print(f"\n✓ Resultados salvos em: {resultados_filepath}")

# Salvar diagnósticos
diagnosticos_list = []
for ticker in todos_diagnosticos:
    for janela in todos_diagnosticos.get(ticker, {}):
        if todos_diagnosticos[ticker][janela]:
            diagnostico = todos_diagnosticos[ticker][janela].copy()
            diagnostico['Ticker'] = ticker
            diagnostico['Janela'] = janela
            diagnosticos_list.append(diagnostico)

if diagnosticos_list:
    df_diagnosticos = pd.DataFrame(diagnosticos_list)
    diagnosticos_filepath = os.path.join(output_dir, "diagnosticos_trading_realista_transformer.csv")
    df_diagnosticos.to_csv(diagnosticos_filepath, index=False)
    print(f"✓ Diagnósticos salvos em: {diagnosticos_filepath}")

# Salvar transações
for ticker in tickers:
    ticker_dir = os.path.join(transactions_dir, ticker)
    os.makedirs(ticker_dir, exist_ok=True)
    
    for janela in janelas:
        if janela in todas_transacoes.get(ticker, {}):
            transacoes = todas_transacoes[ticker][janela]
            
            if transacoes:
                df_transacoes = pd.DataFrame(transacoes)
                transacoes_filepath = os.path.join(ticker_dir, f"{ticker}_{janela}_transacoes_realista.csv")
                df_transacoes.to_csv(transacoes_filepath, index=False)

# Identificar melhor janela por Sharpe Ratio
melhores_resultados = []
for _, row in df_resultados.iterrows():
    ticker = row['Ticker']
    melhor_janela = None
    melhor_sharpe = -np.inf
    
    for janela in janelas:
        sharpe = row.get(f"Sharpe {janela}", -np.inf)
        saldo = row.get(f"Saldo Final {janela}", 0)
        
        if sharpe > melhor_sharpe and saldo > saldo_inicial * 0.95:
            melhor_sharpe = sharpe
            melhor_janela = janela
    
    if melhor_janela:
        melhores_resultados.append({
            'Ticker': ticker,
            'Melhor Janela': melhor_janela,
            'Saldo Final': row[f"Saldo Final {melhor_janela}"],
            'Retorno Liquido (%)': row[f"Retorno Liquido {melhor_janela} (%)"],
            'Sharpe Ratio': melhor_sharpe,
            'Drawdown (%)': row[f"Drawdown {melhor_janela} (%)"],
            'Custos (R$)': row[f"Custos {melhor_janela} (R$)"],
            'Impostos (R$)': row[f"Impostos {melhor_janela} (R$)"]
        })

if melhores_resultados:
    df_melhores = pd.DataFrame(melhores_resultados).sort_values(by='Sharpe Ratio', ascending=False)
    
    melhores_filepath = os.path.join(output_dir, "melhores_resultados_realista_transformer.csv")
    df_melhores.to_csv(melhores_filepath, index=False)
    print(f"✓ Melhores resultados salvos em: {melhores_filepath}")
    
    # Gráfico com escala ajustada
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(18, 14))
    
    # Gráfico 1: Retorno Líquido
    colors = ['darkgreen' if r > 10 else 'green' if r > 0 else 'red' for r in df_melhores['Retorno Liquido (%)']]
    bars = ax1.bar(df_melhores['Ticker'], df_melhores['Saldo Final'], 
                   color=colors, edgecolor='black', linewidth=1.5, alpha=0.8)
    ax1.axhline(y=saldo_inicial, color='blue', linestyle='--', linewidth=2.5, 
                label=f'Saldo Inicial: R$ {saldo_inicial:,.2f}')
    
    max_saldo = df_melhores['Saldo Final'].max()
    ax1.set_ylim(0, max_saldo * 1.25)
    
    for i, bar in enumerate(bars):
        row = df_melhores.iloc[i]
        saldo = row['Saldo Final']
        retorno = row['Retorno Liquido (%)']
        janela = row['Melhor Janela']
        custos = row['Custos (R$)']
        impostos = row['Impostos (R$)']
        
        offset = max_saldo * 0.03
        ax1.text(i, saldo + offset, 
                f"R$ {saldo:,.0f}\n{retorno:+.1f}%\n{janela}\nC: R${custos:.0f} | I: R${impostos:.0f}",
                ha='center', va='bottom', fontsize=10, fontweight='bold')
    
    ax1.set_title('🤖 Transformers - Trading Realista 2023 (Retorno Líquido)', 
                  fontsize=16, fontweight='bold', pad=20)
    ax1.set_ylabel('Saldo Final (R$)', fontsize=13, fontweight='bold')
    ax1.legend(fontsize=11, loc='upper left')
    ax1.grid(axis='y', alpha=0.4, linestyle='--')
    ax1.set_axisbelow(True)
    
    # Gráfico 2: Sharpe Ratio
    colors2 = ['darkgreen' if s > 1.5 else 'green' if s > 0.5 else 'orange' if s > 0 else 'darkred' 
               for s in df_melhores['Sharpe Ratio']]
    ax2.bar(df_melhores['Ticker'], df_melhores['Sharpe Ratio'], 
            color=colors2, edgecolor='black', linewidth=1.5, alpha=0.8)
    ax2.axhline(y=0, color='black', linestyle='-', linewidth=1.5)
    ax2.axhline(y=1, color='green', linestyle='--', linewidth=2, 
                label='Sharpe > 1 (Bom)', alpha=0.7)
    
    max_sharpe = df_melhores['Sharpe Ratio'].max()
    min_sharpe = df_melhores['Sharpe Ratio'].min()
    sharpe_range = max_sharpe - min_sharpe
    ax2.set_ylim(min_sharpe - sharpe_range * 0.2, max_sharpe + sharpe_range * 0.3)
    
    for i, (idx, row) in enumerate(df_melhores.iterrows()):
        sharpe = row['Sharpe Ratio']
        drawdown = row['Drawdown (%)']
        
        offset = sharpe_range * 0.08 if sharpe > 0 else -sharpe_range * 0.08
        ax2.text(i, sharpe + offset, 
                f"{sharpe:.2f}\nDD: {drawdown:.1f}%", 
                ha='center', va='bottom' if sharpe > 0 else 'top', 
                fontsize=10, fontweight='bold')
    
    ax2.set_title('📊 Sharpe Ratio e Maximum Drawdown', 
                  fontsize=16, fontweight='bold', pad=20)
    ax2.set_xlabel('Ticker', fontsize=13, fontweight='bold')
    ax2.set_ylabel('Sharpe Ratio', fontsize=13, fontweight='bold')
    ax2.legend(fontsize=11, loc='upper left')
    ax2.grid(axis='y', alpha=0.4, linestyle='--')
    ax2.set_axisbelow(True)
    
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    
    grafico_filepath = os.path.join(output_dir, "trading_realista_transformer_completo.png")
    plt.savefig(grafico_filepath, dpi=300, bbox_inches='tight')
    print(f"✓ Gráfico salvo em: {grafico_filepath}")
    plt.show()

print("\n" + "="*80)
print(" "*30 + "✅ EXECUÇÃO CONCLUÍDA")
print("="*80)
# Out:
# ================================================================================
#                     SIMULAÇÃO REALISTA DE TRADING - B3 2026
# ================================================================================
# Saldo Inicial: R$ 10,000.00
# Taxa B3: 0.030% | Slippage: 0.010%
# IR Swing Trade: 15.0% | IR Day Trade: 20.0%
# Isenção Mensal: R$ 20,000.00
# Pasta de Dados: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro
# ================================================================================
#
#
# ============================================================
# Processando BEEF3.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\BEEF3.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (360, 3)
#
# --- Simulação para 2023-01-06 ---
# Min: 9.487581, Max: 10.691312, Média: 9.948446715277777
#   [VENDA] Data: 2023-05-19 | Venda: R$ 10065.65 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 65.63
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-31 | Venda: R$ 10114.97 | Vendas Mês (2023, 5): R$ 10065.65 | Lucro: R$ 53.33
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 180.63 | Proporção: 1.79% | IR = R$ 0.14
#   [VENDA] Data: 2023-06-02 | Venda: R$ 10323.95 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ 213.08
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-06-27 | Venda: R$ 10586.91 | Vendas Mês (2023, 6): R$ 10323.95 | Lucro: R$ 266.98
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 910.87 | Proporção: 8.60% | IR = R$ 3.45
#   [VENDA] Data: 2023-06-29 | Venda: R$ 10844.52 | Vendas Mês (2023, 6): R$ 20910.87 | Lucro: R$ 265.18
#     → SWING: Mês já ultrapassou isenção | IR = R$ 39.78
#   [VENDA] Data: 2023-07-05 | Venda: R$ 11057.19 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ 256.68
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-08-01 | Venda: R$ 11089.54 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ 36.76
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#
# 📊 Resumo de Vendas Mensais:
#   05/2023: R$ 20,180.63 [TRIBUTÁVEL]
#   06/2023: R$ 31,755.39 [TRIBUTÁVEL]
#   07/2023: R$ 11,057.19 [ISENTO]
#   08/2023: R$ 11,089.54 [ISENTO]
# Resultado: Retorno Líquido=-7.16%, Sharpe=-0.09, Total IR=43.37
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\BEEF3.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 11.053867, Max: 11.868601, Média: 11.405390756338027
#   [VENDA] Data: 2023-02-17 | Venda: R$ 10002.08 | Vendas Mês (2023, 2): R$ 0.00 | Lucro: R$ 2.08
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#
# 📊 Resumo de Vendas Mensais:
#   02/2023: R$ 10,002.08 [ISENTO]
# Resultado: Retorno Líquido=-30.60%, Sharpe=-0.60, Total IR=0.00
#
#   Buscando: Janela_15
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\BEEF3.SA_Janela_15_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (350, 3)
#
# --- Simulação para 2023-01-16 ---
# Min: 10.7177, Max: 11.50964, Média: 11.08170108
#
# 📊 Resumo de Vendas Mensais:
# Resultado: Retorno Líquido=-30.59%, Sharpe=-0.61, Total IR=0.00
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\BEEF3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 8.464434, Max: 8.918799, Média: 8.601914442028987
#   [VENDA] Data: 2023-04-20 | Venda: R$ 10258.82 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ 258.71
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-05 | Venda: R$ 10547.88 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 293.05
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-09-04 | Venda: R$ 10966.18 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ 422.35
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-09-12 | Venda: R$ 11006.41 | Vendas Mês (2023, 9): R$ 10966.18 | Lucro: R$ 44.60
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 1972.59 | Proporção: 17.92% | IR = R$ 1.20
#
# 📊 Resumo de Vendas Mensais:
#   04/2023: R$ 10,258.82 [ISENTO]
#   05/2023: R$ 10,547.88 [ISENTO]
#   09/2023: R$ 21,972.59 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=-0.73%, Sharpe=0.06, Total IR=1.20
#
# ============================================================
# Processando BRFS3.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\BRFS3.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (360, 3)
#
# --- Simulação para 2023-01-06 ---
# Min: 9.867521, Max: 11.678387, Média: 10.266703744444444
#   [VENDA] Data: 2023-08-15 | Venda: R$ 12180.19 | Vendas Mês (2023, 8): R$ 0.00 | Lucro: R$ 2179.32
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-06 | Venda: R$ 12616.93 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ 441.44
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-09 | Venda: R$ 12793.15 | Vendas Mês (2023, 10): R$ 12616.93 | Lucro: R$ 181.19
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 5410.08 | Proporção: 42.29% | IR = R$ 11.49
#   [VENDA] Data: 2023-10-20 | Venda: R$ 12985.50 | Vendas Mês (2023, 10): R$ 25410.08 | Lucro: R$ 208.88
#     → SWING: Mês já ultrapassou isenção | IR = R$ 31.33
#   [VENDA] Data: 2023-10-31 | Venda: R$ 13125.73 | Vendas Mês (2023, 10): R$ 38395.57 | Lucro: R$ 176.68
#     → SWING: Mês já ultrapassou isenção | IR = R$ 26.50
#
# 📊 Resumo de Vendas Mensais:
#   08/2023: R$ 12,180.19 [ISENTO]
#   10/2023: R$ 51,521.30 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=30.94%, Sharpe=0.64, Total IR=69.33
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\BRFS3.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 11.163015, Max: 16.569256, Média: 13.052041230985914
#
# 📊 Resumo de Vendas Mensais:
#   12/2023: R$ 16,314.08 [ISENTO]
# Resultado: Retorno Líquido=63.08%, Sharpe=0.95, Total IR=0.00
#
#   Buscando: Janela_15
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\BRFS3.SA_Janela_15_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (350, 3)
#
# --- Simulação para 2023-01-16 ---
# Min: 12.02438, Max: 15.6506405, Média: 13.037280158571429
#
# 📊 Resumo de Vendas Mensais:
#   12/2023: R$ 18,232.12 [ISENTO]
# Resultado: Retorno Líquido=82.25%, Sharpe=1.12, Total IR=0.00
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\BRFS3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 11.33619, Max: 14.416176, Média: 12.137900686956522
#   [VENDA] Data: 2023-11-16 | Venda: R$ 17533.78 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 7530.77
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-27 | Venda: R$ 17873.73 | Vendas Mês (2023, 11): R$ 17533.78 | Lucro: R$ 346.82
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 15407.50 | Proporção: 86.20% | IR = R$ 44.85
#   [VENDA] Data: 2023-12-01 | Venda: R$ 18442.81 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ 620.83
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12-26 | Venda: R$ 9319.27 | Vendas Mês (2023, 12): R$ 18300.96 | Lucro: R$ 27.24
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 7620.23 | Proporção: 81.77% | IR = R$ 3.34
#
# 📊 Resumo de Vendas Mensais:
#   05/2023: R$ 9,642.40 [ISENTO]
#   06/2023: R$ 18,951.79 [ISENTO]
#   07/2023: R$ 19,343.86 [ISENTO]
#   08/2023: R$ 28,431.74 [TRIBUTÁVEL]
#   09/2023: R$ 18,419.17 [ISENTO]
#   10/2023: R$ 17,941.18 [ISENTO]
#   11/2023: R$ 18,162.79 [ISENTO]
#   12/2023: R$ 27,620.23 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=-6.88%, Sharpe=-0.40, Total IR=17.85
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\VALE3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 58.744743, Max: 78.60401, Média: 67.22539625507247
#   [VENDA] Data: 2023-03-01 | Venda: R$ 9538.46 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ -461.35
#
# 📊 Resumo de Vendas Mensais:
# Resultado: Retorno Líquido=-12.15%, Sharpe=-0.32, Total IR=0.00
#
# ============================================================
# Processando JBSS3.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\JBSS3.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (360, 3)
#
# --- Simulação para 2023-01-06 ---
# Min: 18.197495, Max: 22.89239, Média: 19.928484966666666
#   [VENDA] Data: 2023-12-13 | Venda: R$ 11573.20 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ 1572.58
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12-19 | Venda: R$ 11682.22 | Vendas Mês (2023, 12): R$ 11573.20 | Lucro: R$ 113.60
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 3255.42 | Proporção: 27.87% | IR = R$ 4.75
#
# 📊 Resumo de Vendas Mensais:
#   12/2023: R$ 23,255.42 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=16.73%, Sharpe=0.54, Total IR=4.75
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\JBSS3.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 21.128397, Max: 25.63632, Média: 23.613916478873243
#
# 📊 Resumo de Vendas Mensais:
#   12/2023: R$ 11,733.70 [ISENTO]
# Resultado: Retorno Líquido=17.29%, Sharpe=0.56, Total IR=0.00
#
#   Buscando: Janela_15
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\JBSS3.SA_Janela_15_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (350, 3)
#
# --- Simulação para 2023-01-16 ---
# Min: 18.296839, Max: 22.29345, Média: 19.40379088
#   [VENDA] Data: 2023-11-16 | Venda: R$ 10699.34 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 699.06
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-22 | Venda: R$ 10950.43 | Vendas Mês (2023, 11): R$ 10699.34 | Lucro: R$ 255.27
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 1649.78 | Proporção: 15.07% | IR = R$ 5.77
#   [VENDA] Data: 2023-11-30 | Venda: R$ 10933.72 | Vendas Mês (2023, 11): R$ 21649.78 | Lucro: R$ -6.56
#   [VENDA] Data: 2023-12-05 | Venda: R$ 11038.45 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ 109.06
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12-07 | Venda: R$ 11069.63 | Vendas Mês (2023, 12): R$ 11038.45 | Lucro: R$ 35.58
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 2108.08 | Proporção: 19.04% | IR = R$ 1.02
#
# 📊 Resumo de Vendas Mensais:
#   11/2023: R$ 21,649.78 [TRIBUTÁVEL]
#   12/2023: R$ 22,108.08 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=10.64%, Sharpe=0.41, Total IR=6.79
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\JBSS3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 14.622646, Max: 17.861149, Média: 15.647093207246376
#   [VENDA] Data: 2023-02-23 | Venda: R$ 10546.43 | Vendas Mês (2023, 2): R$ 0.00 | Lucro: R$ 546.21
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-04-11 | Venda: R$ 10657.69 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ 115.43
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-04-18 | Venda: R$ 10911.48 | Vendas Mês (2023, 4): R$ 10657.69 | Lucro: R$ 257.95
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 1569.17 | Proporção: 14.38% | IR = R$ 5.56
#   [VENDA] Data: 2023-04-28 | Venda: R$ 11444.88 | Vendas Mês (2023, 4): R$ 21569.17 | Lucro: R$ 543.11
#     → SWING: Mês já ultrapassou isenção | IR = R$ 81.47
#   [VENDA] Data: 2023-05-19 | Venda: R$ 11956.90 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 597.83
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-31 | Venda: R$ 11818.32 | Vendas Mês (2023, 5): R$ 11956.90 | Lucro: R$ -133.74
#   [VENDA] Data: 2023-06-02 | Venda: R$ 12065.52 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 50.55 | Proporção: 0.49% | IR = R$ 0.33
#   [VENDA] Data: 2023-05-11 | Venda: R$ 10132.14 | Vendas Mês (2023, 5): R$ 20050.55 | Lucro: R$ -111.12
#   [VENDA] Data: 2023-05-17 | Venda: R$ 10455.80 | Vendas Mês (2023, 5): R$ 20050.55 | Lucro: R$ 327.58
#     → SWING: Mês já ultrapassou isenção | IR = R$ 49.14
#   [VENDA] Data: 2023-10-16 | Venda: R$ 10405.47 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ 2.99
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-21 | Venda: R$ 9985.41 | Vendas Mês (2023, 10): R$ 10405.47 | Lucro: R$ -415.73
#   [VENDA] Data: 2023-10-26 | Venda: R$ 10095.78 | Vendas Mês (2023, 10): R$ 10405.47 | Lucro: R$ 114.32
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 501.26 | Proporção: 4.97% | IR = R$ 0.85
#   [VENDA] Data: 2023-11-01 | Venda: R$ 10241.84 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 150.88
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-03 | Venda: R$ 10540.67 | Vendas Mês (2023, 11): R$ 10241.84 | Lucro: R$ 302.81
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 782.51 | Proporção: 7.42% | IR = R$ 3.37
#   [VENDA] Data: 2023-11-06 | Venda: R$ 10651.15 | Vendas Mês (2023, 11): R$ 20782.51 | Lucro: R$ 118.02
#     → SWING: Mês já ultrapassou isenção | IR = R$ 17.70
#   [VENDA] Data: 2023-11-10 | Venda: R$ 11070.08 | Vendas Mês (2023, 11): R$ 31433.66 | Lucro: R$ 440.72
#     → SWING: Mês já ultrapassou isenção | IR = R$ 66.11
#   [VENDA] Data: 2023-11-21 | Venda: R$ 11174.57 | Vendas Mês (2023, 11): R$ 42503.74 | Lucro: R$ 174.95
#     → SWING: Mês já ultrapassou isenção | IR = R$ 26.24
#   [VENDA] Data: 2023-12-12 | Venda: R$ 11326.78 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ 182.85
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12-16 | Venda: R$ 11315.46 | Vendas Mês (2023, 12): R$ 11326.78 | Lucro: R$ -6.79
#   [VENDA] Data: 2023-12-21 | Venda: R$ 11520.78 | Vendas Mês (2023, 12): R$ 11326.78 | Lucro: R$ 209.76
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 2847.57 | Proporção: 24.72% | IR = R$ 7.78
#
# 📊 Resumo de Vendas Mensais:
#   03/2023: R$ 10,099.41 [ISENTO]
#   05/2023: R$ 30,506.34 [TRIBUTÁVEL]
#   10/2023: R$ 20,501.26 [TRIBUTÁVEL]
#   11/2023: R$ 53,678.31 [TRIBUTÁVEL]
#   12/2023: R$ 22,847.57 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=15.08%, Sharpe=1.21, Total IR=171.52
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\GGBR3.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 17.351116, Max: 20.249035, Média: 18.955575112676055
#   [VENDA] Data: 2023-03-10 | Venda: R$ 9851.65 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ -148.29
#   [VENDA] Data: 2023-03-14 | Venda: R$ 9970.81 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ 123.06
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-03-30 | Venda: R$ 10418.03 | Vendas Mês (2023, 3): R$ 9970.81 | Lucro: R$ 451.03
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 388.84 | Proporção: 3.73% | IR = R$ 2.53
#   [VENDA] Data: 2023-04-10 | Venda: R$ 10125.32 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -285.91
#   [VENDA] Data: 2023-04-20 | Venda: R$ 10241.79 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ 120.47
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-04-28 | Venda: R$ 10247.83 | Vendas Mês (2023, 4): R$ 10241.79 | Lucro: R$ 10.13
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 489.61 | Proporção: 4.78% | IR = R$ 0.07
#   [VENDA] Data: 2023-05-05 | Venda: R$ 10388.37 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 144.66
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-08 | Venda: R$ 10474.27 | Vendas Mês (2023, 5): R$ 10388.37 | Lucro: R$ 90.02
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 862.65 | Proporção: 8.24% | IR = R$ 1.11
#   [VENDA] Data: 2023-05-17 | Venda: R$ 10576.24 | Vendas Mês (2023, 5): R$ 20862.65 | Lucro: R$ 107.23
#     → SWING: Mês já ultrapassou isenção | IR = R$ 16.08
#   [VENDA] Data: 2023-05-22 | Venda: R$ 10992.08 | Vendas Mês (2023, 5): R$ 31438.89 | Lucro: R$ 435.98
#     → SWING: Mês já ultrapassou isenção | IR = R$ 65.40
#   [VENDA] Data: 2023-05-26 | Venda: R$ 11138.87 | Vendas Mês (2023, 5): R$ 42430.97 | Lucro: R$ 216.49
#     → SWING: Mês já ultrapassou isenção | IR = R$ 32.47
#   [VENDA] Data: 2023-06-01 | Venda: R$ 11081.59 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ -20.34
#   [VENDA] Data: 2023-11-10 | Venda: R$ 11061.20 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ -15.95
#   [VENDA] Data: 2023-11-14 | Venda: R$ 11236.17 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 179.33
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-21 | Venda: R$ 11410.40 | Vendas Mês (2023, 11): R$ 11236.17 | Lucro: R$ 178.65
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 2646.57 | Proporção: 23.19% | IR = R$ 6.22
#   [VENDA] Data: 2023-12-22 | Venda: R$ 11563.92 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ 164.23
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#
# 📊 Resumo de Vendas Mensais:
#   03/2023: R$ 20,388.84 [TRIBUTÁVEL]
#   04/2023: R$ 20,489.61 [TRIBUTÁVEL]
#   05/2023: R$ 53,569.83 [TRIBUTÁVEL]
#   11/2023: R$ 22,646.57 [TRIBUTÁVEL]
#   12/2023: R$ 23,170.00 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=16.00%, Sharpe=0.83, Total IR=125.80
#
#   Buscando: Janela_15
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\GGBR3.SA_Janela_15_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (350, 3)
#
# --- Simulação para 2023-01-16 ---
# Min: 16.274797, Max: 20.132923, Média: 18.28480637142857
#   [VENDA] Data: 2023-04-26 | Venda: R$ 9956.92 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -43.06
#   [VENDA] Data: 2023-05-05 | Venda: R$ 10408.84 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 455.72
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-21 | Venda: R$ 10570.23 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 165.49
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-25 | Venda: R$ 10559.67 | Vendas Mês (2023, 11): R$ 10570.23 | Lucro: R$ -6.34
#
# 📊 Resumo de Vendas Mensais:
#   05/2023: R$ 10,408.84 [ISENTO]
#   11/2023: R$ 10,570.23 [ISENTO]
# Resultado: Retorno Líquido=5.55%, Sharpe=0.96, Total IR=0.00
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\GGBR3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 17.12542, Max: 20.81477, Média: 18.785247426086958
#   [VENDA] Data: 2023-03-10 | Venda: R$ 9851.65 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ -148.29
#   [VENDA] Data: 2023-03-16 | Venda: R$ 9945.60 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ 97.85
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-04-07 | Venda: R$ 9598.86 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -342.63
#   [VENDA] Data: 2023-04-20 | Venda: R$ 9709.27 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ 114.21
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-04-26 | Venda: R$ 9325.31 | Vendas Mês (2023, 4): R$ 9709.27 | Lucro: R$ -379.92
#   [VENDA] Data: 2023-05-03 | Venda: R$ 9422.76 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 101.14
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-05 | Venda: R$ 9850.43 | Vendas Mês (2023, 5): R$ 9422.76 | Lucro: R$ 431.27
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-12 | Venda: R$ 9796.17 | Vendas Mês (2023, 5): R$ 19273.20 | Lucro: R$ -50.30
#   [VENDA] Data: 2023-05-17 | Venda: R$ 10109.10 | Vendas Mês (2023, 5): R$ 19273.20 | Lucro: R$ 316.72
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 9382.29 | Proporção: 92.81% | IR = R$ 44.09
#   [VENDA] Data: 2023-05-25 | Venda: R$ 9952.15 | Vendas Mês (2023, 5): R$ 29382.29 | Lucro: R$ -108.76
#   [VENDA] Data: 2023-06-01 | Venda: R$ 9929.94 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ -18.22
#   [VENDA] Data: 2023-10-06 | Venda: R$ 9920.01 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ -5.95
#   [VENDA] Data: 2023-11-03 | Venda: R$ 10050.85 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 134.75
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-10 | Venda: R$ 10440.68 | Vendas Mês (2023, 11): R$ 10050.85 | Lucro: R$ 393.69
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 491.54 | Proporção: 4.71% | IR = R$ 2.78
#   [VENDA] Data: 2023-11-14 | Venda: R$ 10697.56 | Vendas Mês (2023, 11): R$ 20491.54 | Lucro: R$ 263.73
#     → SWING: Mês já ultrapassou isenção | IR = R$ 39.56
#   [VENDA] Data: 2023-11-21 | Venda: R$ 10823.25 | Vendas Mês (2023, 11): R$ 31189.10 | Lucro: R$ 169.45
#     → SWING: Mês já ultrapassou isenção | IR = R$ 25.42
#   [VENDA] Data: 2023-11-25 | Venda: R$ 10787.02 | Vendas Mês (2023, 11): R$ 42012.34 | Lucro: R$ -6.47
#   [VENDA] Data: 2023-12-01 | Venda: R$ 10924.20 | Vendas Mês (2023, 12): R$ 0.00 | Lucro: R$ 141.43
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-12-05 | Venda: R$ 10967.48 | Vendas Mês (2023, 12): R$ 10924.20 | Lucro: R$ 47.63
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 1891.67 | Proporção: 17.25% | IR = R$ 1.23
#   [VENDA] Data: 2023-12-08 | Venda: R$ 11083.30 | Vendas Mês (2023, 12): R$ 21891.67 | Lucro: R$ 121.39
#     → SWING: Mês já ultrapassou isenção | IR = R$ 18.21
#   [VENDA] Data: 2023-12-11 | Venda: R$ 11068.75 | Vendas Mês (2023, 12): R$ 32974.97 | Lucro: R$ 8.09
#     → SWING: Mês já ultrapassou isenção | IR = R$ 1.21
#   [VENDA] Data: 2023-12-18 | Venda: R$ 11204.02 | Vendas Mês (2023, 12): R$ 44043.72 | Lucro: R$ 140.85
#     → SWING: Mês já ultrapassou isenção | IR = R$ 21.13
#   [VENDA] Data: 2023-12-21 | Venda: R$ 11385.80 | Vendas Mês (2023, 12): R$ 55247.74 | Lucro: R$ 207.31
#     → SWING: Mês já ultrapassou isenção | IR = R$ 31.10
#
# 📊 Resumo de Vendas Mensais:
#   03/2023: R$ 9,945.60 [ISENTO]
#   04/2023: R$ 9,709.27 [ISENTO]
#   05/2023: R$ 29,382.29 [TRIBUTÁVEL]
#   11/2023: R$ 42,012.34 [TRIBUTÁVEL]
#   12/2023: R$ 66,633.54 [TRIBUTÁVEL]
# Resultado: Retorno Líquido=13.50%, Sharpe=0.99, Total IR=184.73
#
# ============================================================
# Processando CSNA3.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\CSNA3.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (360, 3)
#
# --- Simulação para 2023-01-06 ---
# Min: 17.83378, Max: 22.481804, Média: 19.50475071388889
#
# 📊 Resumo de Vendas Mensais:
#   12/2023: R$ 13,198.36 [ISENTO]
# Resultado: Retorno Líquido=31.93%, Sharpe=0.76, Total IR=0.00
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\CSNA3.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 16.670744, Max: 18.95293, Média: 17.32036070422535
#
# 📊 Resumo de Vendas Mensais:
#   12/2023: R$ 12,521.13 [ISENTO]
# Resultado: Retorno Líquido=25.16%, Sharpe=0.65, Total IR=0.00
#
#   Buscando: Janela_15
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\CSNA3.SA_Janela_15_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (350, 3)
#
# --- Simulação para 2023-01-16 ---
# Min: 12.968615, Max: 13.853527, Média: 13.290070242857142
#   [VENDA] Data: 2023-02-27 | Venda: R$ 10121.04 | Vendas Mês (2023, 2): R$ 0.00 | Lucro: R$ 120.99
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-20 | Venda: R$ 10373.70 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 256.60
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#
# 📊 Resumo de Vendas Mensais:
#   02/2023: R$ 10,121.04 [ISENTO]
#   11/2023: R$ 10,373.70 [ISENTO]
# Resultado: Retorno Líquido=3.70%, Sharpe=0.23, Total IR=0.00
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\CSNA3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 7.861909, Max: 12.384524, Média: 9.192888959420289
#
# 📊 Resumo de Vendas Mensais:
# Resultado: Retorno Líquido=0.00%, Sharpe=0.00, Total IR=0.00
#
# ============================================================
# Processando PETR4.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\PETR4.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (360, 3)
#
# --- Simulação para 2023-01-06 ---
# Min: 11.279067, Max: 11.27907, Média: 11.279068699999998
#
# 📊 Resumo de Vendas Mensais:
# Resultado: Retorno Líquido=0.00%, Sharpe=0.00, Total IR=0.00
#
#   Buscando: Janela_10
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\PETR4.SA_Janela_10_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (355, 3)
#
# --- Simulação para 2023-01-11 ---
# Min: 12.446876, Max: 12.4468775, Média: 12.44687713802817
#
# 📊 Resumo de Vendas Mensais:
# Resultado: Retorno Líquido=0.00%, Sharpe=0.00, Total IR=0.00
#
#   Buscando: Janela_15
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\PETR4.SA_Janela_15_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (350, 3)
#
# --- Simulação para 2023-01-16 ---
# Min: 9.959326, Max: 9.959328, Média: 9.959326791428573
#
# 📊 Resumo de Vendas Mensais:
# Resultado: Retorno Líquido=0.00%, Sharpe=0.00, Total IR=0.00
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macromicro\PETR4.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (345, 3)
#
# --- Simulação para 2023-01-21 ---
# Min: 7.5838056, Max: 7.583808, Média: 7.583806438550726
#
# 📊 Resumo de Vendas Mensais:
# Resultado: Retorno Líquido=0.00%, Sharpe=0.00, Total IR=0.00
#
# ✓ Resultados salvos em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\MacroMicroResultados\resultados_trading_realista_transformer.csv
# ✓ Diagnósticos salvos em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\MacroMicroResultados\diagnosticos_trading_realista_transformer.csv
# ✓ Melhores resultados salvos em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\MacroMicroResultados\melhores_resultados_realista_transformer.csv
# C:\Users\leona\AppData\Local\Temp\ipykernel_28168\879020027.py:514: UserWarning: Glyph 129302 (\N{ROBOT FACE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\leona\AppData\Local\Temp\ipykernel_28168\879020027.py:514: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\leona\AppData\Local\Temp\ipykernel_28168\879020027.py:517: UserWarning: Glyph 129302 (\N{ROBOT FACE}) missing from font(s) DejaVu Sans.
#   plt.savefig(grafico_filepath, dpi=300, bbox_inches='tight')
# C:\Users\leona\AppData\Local\Temp\ipykernel_28168\879020027.py:517: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.savefig(grafico_filepath, dpi=300, bbox_inches='tight')
# ✓ Gráfico salvo em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\MacroMicroResultados\trading_realista_transformer_completo.png
# c:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129302 (\N{ROBOT FACE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ================================================================================
#                               ✅ EXECUÇÃO CONCLUÍDA
# ================================================================================
