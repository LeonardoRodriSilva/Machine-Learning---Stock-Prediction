# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from datetime import datetime

# --- Parâmetros Reais de Mercado (B3 2026) ---
TAXA_NEGOCIACAO_LIQUIDACAO = 0.00030  # 0,03%
TAXA_DAY_TRADE = 0.00023              # 0,023%
SLIPPAGE = 0.0001                     # 0,01%
IR_SWING_TRADE = 0.15                 # 15%
IR_DAY_TRADE = 0.20                   # 20%
ISENCAO_VENDA_MENSAL = 20000          # R$ 20k

# Diretório FLAT onde estão os arquivos de previsões (ALTERADO)
input_dir = r"C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_preco"

# Diretório onde os resultados serão salvos
output_dir = r"C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\TransformersPrecoResultados"
os.makedirs(output_dir, exist_ok=True)

transactions_dir = os.path.join(output_dir, "Transacoes")
os.makedirs(transactions_dir, exist_ok=True)

# Lista de tickers
tickers = ["BEEF3.SA", "BRFS3.SA", "VALE3.SA", "JBSS3.SA", "SOJA3.SA", 
           "SUZB3.SA", "GGBR3.SA", "CSNA3.SA"]

# Lista de janelas (AJUSTADO para o formato Transformer)
janelas = ["Janela_5", "Janela_10", "Janela_15", "Janela_20"]

def calcular_metricas_risco(historico_patrimonio, saldo_inicial):
    """Calcula Maximum Drawdown e Sharpe Ratio."""
    if not historico_patrimonio or len(historico_patrimonio) < 2:
        return {'max_drawdown': 0.0, 'sharpe_ratio': 0.0}
    
    patrimonio_array = np.array(historico_patrimonio)
    pico = np.maximum.accumulate(patrimonio_array)
    drawdown = (patrimonio_array - pico) / pico
    max_drawdown = np.min(drawdown) * 100
    
    retornos = np.diff(patrimonio_array) / patrimonio_array[:-1]
    if len(retornos) > 0 and np.std(retornos) != 0:
        sharpe_ratio = np.mean(retornos) / np.std(retornos) * np.sqrt(252)
    else:
        sharpe_ratio = 0.0
    
    return {
        'max_drawdown': max_drawdown,
        'sharpe_ratio': sharpe_ratio
    }

def estrategia_all_in_realista(dados_brutos, saldo_inicial):
    """Estratégia All-In com custos reais da B3 e IR CORRIGIDO."""
    dados = dados_brutos.copy()
    dados['Preço Real'] = pd.to_numeric(dados['Preço Real'], errors='coerce')
    dados['Preço Previsto'] = pd.to_numeric(dados['Preço Previsto'], errors='coerce')
    dados['Data'] = pd.to_datetime(dados['Data'])
    
    previsoes = dados['Preço Previsto'].dropna()
    min_previsto = previsoes.min() if len(previsoes) > 0 else None
    max_previsto = previsoes.max() if len(previsoes) > 0 else None
    media_previsoes = previsoes.mean() if len(previsoes) > 0 else None
    
    identifier = dados_brutos['Data'].iloc[0] if not dados_brutos.empty else "Unknown"
    print(f"\n--- Simulação para {identifier} ---")
    print(f"Min: {min_previsto}, Max: {max_previsto}, Média: {media_previsoes}")
    
    # Bloquear previsões extremas
    is_extremely_negative = False
    if min_previsto is not None and isinstance(min_previsto, (int, float)) and min_previsto < -1000:
        is_extremely_negative = True
        print(f"!!! Previsão mínima ({min_previsto}) < -1000. Bloqueando transações. !!!")
    
    if is_extremely_negative:
        diagnostico = {
            'Previsões Razoáveis': False,
            'Estratégia Usada': 'Sem transações - Previsões Negativas',
            'Total de Transações': 0,
            'Retorno (%)': 0.0,
            'Retorno Liquido (%)': 0.0,
            'Max Drawdown (%)': 0.0,
            'Sharpe Ratio': 0.0,
            'Total Custos (R$)': 0.0,
            'Total Impostos (R$)': 0.0,
            'Min Previsto': min_previsto,
            'Max Previsto': max_previsto,
            'Média Previsto': media_previsoes
        }
        return saldo_inicial, [], diagnostico
    
    # Inicializar variáveis
    saldo = saldo_inicial
    quantidade_acoes = 0
    transacoes = []
    historico_patrimonio = [saldo_inicial]
    
    total_custos_operacionais = 0.0
    total_impostos = 0.0
    vendas_no_mes = {}
    data_compra = None
    preco_compra = 0.0
    
    for i in range(len(dados) - 1):
        data_atual = dados.iloc[i]['Data']
        preco_real = dados.iloc[i]['Preço Real']
        
        if pd.isna(preco_real) or preco_real <= 0:
            continue
        
        preco_previsto = dados.iloc[i + 1]['Preço Previsto']
        if pd.isna(preco_previsto):
            continue
        
        # COMPRA
        if quantidade_acoes == 0 and preco_previsto > preco_real:
            preco_com_slippage = preco_real * (1 + SLIPPAGE)
            custos_compra = saldo * (TAXA_NEGOCIACAO_LIQUIDACAO + SLIPPAGE)
            saldo_pos_custo = saldo - custos_compra
            
            if saldo_pos_custo > 0:
                quantidade_acoes = saldo_pos_custo / preco_com_slippage
                valor_investido = quantidade_acoes * preco_com_slippage
                saldo = 0
                total_custos_operacionais += custos_compra
                
                data_compra = data_atual
                preco_compra = preco_com_slippage
                
                transacoes.append({
                    'Data': data_atual,
                    'Acao': 'Compra',
                    'Preco': preco_real,
                    'Preco_Executado': preco_com_slippage,
                    'Quantidade': quantidade_acoes,
                    'Valor_Total': valor_investido,
                    'Custos_Operacionais': custos_compra,
                    'Saldo_Restante': saldo
                })
        
        # VENDA
        elif quantidade_acoes > 0 and preco_previsto < preco_real and i < len(dados) - 2:
            preco_com_slippage = preco_real * (1 - SLIPPAGE)
            valor_bruto_venda = quantidade_acoes * preco_com_slippage
            custos_venda = valor_bruto_venda * (TAXA_NEGOCIACAO_LIQUIDACAO + SLIPPAGE)
            
            is_day_trade = (data_atual.date() == data_compra.date()) if data_compra else False
            
            custo_aquisicao = quantidade_acoes * preco_compra
            lucro_bruto = valor_bruto_venda - custo_aquisicao - custos_venda
            
            imposto = 0.0
            mes_ano = (data_atual.year, data_atual.month)
            
            vendas_mes_atual = vendas_no_mes.get(mes_ano, 0.0)
            print(f"  [VENDA] Data: {data_atual.date()} | Venda: R$ {valor_bruto_venda:.2f} | "
                  f"Vendas Mês {mes_ano}: R$ {vendas_mes_atual:.2f} | Lucro: R$ {lucro_bruto:.2f}")
            
            if lucro_bruto > 0:
                if is_day_trade:
                    imposto = lucro_bruto * IR_DAY_TRADE
                    print(f"    → DAY TRADE: IR = R$ {imposto:.2f} (20% sobre lucro)")
                else:
                    vendas_anteriores = vendas_no_mes.get(mes_ano, 0.0)
                    vendas_totais_mes = vendas_anteriores + valor_bruto_venda
                    
                    if vendas_totais_mes > ISENCAO_VENDA_MENSAL:
                        if vendas_anteriores >= ISENCAO_VENDA_MENSAL:
                            imposto = lucro_bruto * IR_SWING_TRADE
                            print(f"    → SWING: Mês já ultrapassou isenção | IR = R$ {imposto:.2f}")
                        else:
                            valor_excedente = vendas_totais_mes - ISENCAO_VENDA_MENSAL
                            proporcao_tributavel = valor_excedente / valor_bruto_venda
                            lucro_tributavel = lucro_bruto * proporcao_tributavel
                            imposto = lucro_tributavel * IR_SWING_TRADE
                            print(f"    → SWING: 1ª vez ultrapassando | Excedente: R$ {valor_excedente:.2f} | "
                                  f"Proporção: {proporcao_tributavel:.2%} | IR = R$ {imposto:.2f}")
                    else:
                        print(f"    → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00")
                    
                    vendas_no_mes[mes_ano] = vendas_totais_mes
            
            valor_liquido_venda = valor_bruto_venda - custos_venda - imposto
            saldo = valor_liquido_venda
            total_custos_operacionais += custos_venda
            total_impostos += imposto
            
            transacoes.append({
                'Data': data_atual,
                'Acao': 'Venda Day Trade' if is_day_trade else 'Venda',
                'Preco': preco_real,
                'Preco_Executado': preco_com_slippage,
                'Quantidade': quantidade_acoes,
                'Valor_Bruto': valor_bruto_venda,
                'Custos_Operacionais': custos_venda,
                'Lucro_Bruto': lucro_bruto,
                'Imposto': imposto,
                'Valor_Liquido': valor_liquido_venda,
                'Saldo_Restante': saldo,
                'Vendas_Acumuladas_Mes': vendas_no_mes.get(mes_ano, 0.0)
            })
            
            quantidade_acoes = 0
            data_compra = None
        
        patrimonio_atual = saldo + (quantidade_acoes * preco_real if quantidade_acoes > 0 else 0)
        historico_patrimonio.append(patrimonio_atual)
    
    # Venda final
    if quantidade_acoes > 0:
        ultimo_preco = dados.iloc[-1]['Preço Real']
        data_final = dados.iloc[-1]['Data']
        
        if not pd.isna(ultimo_preco) and ultimo_preco > 0:
            preco_com_slippage = ultimo_preco * (1 - SLIPPAGE)
            valor_bruto_venda = quantidade_acoes * preco_com_slippage
            custos_venda = valor_bruto_venda * (TAXA_NEGOCIACAO_LIQUIDACAO + SLIPPAGE)
            
            is_day_trade = (data_final.date() == data_compra.date()) if data_compra else False
            
            custo_aquisicao = quantidade_acoes * preco_compra
            lucro_bruto = valor_bruto_venda - custo_aquisicao - custos_venda
            
            imposto = 0.0
            mes_ano = (data_final.year, data_final.month)
            
            if lucro_bruto > 0:
                if is_day_trade:
                    imposto = lucro_bruto * IR_DAY_TRADE
                else:
                    vendas_anteriores = vendas_no_mes.get(mes_ano, 0.0)
                    vendas_totais_mes = vendas_anteriores + valor_bruto_venda
                    
                    if vendas_totais_mes > ISENCAO_VENDA_MENSAL:
                        if vendas_anteriores >= ISENCAO_VENDA_MENSAL:
                            imposto = lucro_bruto * IR_SWING_TRADE
                        else:
                            valor_excedente = vendas_totais_mes - ISENCAO_VENDA_MENSAL
                            proporcao_tributavel = valor_excedente / valor_bruto_venda
                            lucro_tributavel = lucro_bruto * proporcao_tributavel
                            imposto = lucro_tributavel * IR_SWING_TRADE
                    
                    vendas_no_mes[mes_ano] = vendas_totais_mes
            
            valor_liquido_venda = valor_bruto_venda - custos_venda - imposto
            saldo = valor_liquido_venda
            total_custos_operacionais += custos_venda
            total_impostos += imposto
            
            transacoes.append({
                'Data': data_final,
                'Acao': 'Venda Final',
                'Preco': ultimo_preco,
                'Preco_Executado': preco_com_slippage,
                'Quantidade': quantidade_acoes,
                'Valor_Bruto': valor_bruto_venda,
                'Custos_Operacionais': custos_venda,
                'Lucro_Bruto': lucro_bruto,
                'Imposto': imposto,
                'Valor_Liquido': valor_liquido_venda,
                'Saldo_Restante': saldo,
                'Vendas_Acumuladas_Mes': vendas_no_mes.get(mes_ano, 0.0)
            })
    
    print(f"\n📊 Resumo de Vendas Mensais:")
    for mes_ano, total_vendas in sorted(vendas_no_mes.items()):
        status = "TRIBUTÁVEL" if total_vendas > ISENCAO_VENDA_MENSAL else "ISENTO"
        print(f"  {mes_ano[1]:02d}/{mes_ano[0]}: R$ {total_vendas:,.2f} [{status}]")
    
    metricas_risco = calcular_metricas_risco(historico_patrimonio, saldo_inicial)
    
    retorno_bruto = ((saldo + total_custos_operacionais + total_impostos - saldo_inicial) / saldo_inicial) * 100
    retorno_liquido = ((saldo - saldo_inicial) / saldo_inicial) * 100
    
    previsoes_razoaveis = not is_extremely_negative
    estrategia_usada = 'Trading Realista (B3)' if len(transacoes) > 0 else 'Sem transações'
    
    diagnostico = {
        'Previsões Razoáveis': previsoes_razoaveis,
        'Estratégia Usada': estrategia_usada,
        'Total de Transações': len(transacoes),
        'Retorno Bruto (%)': retorno_bruto,
        'Retorno Liquido (%)': retorno_liquido,
        'Max Drawdown (%)': metricas_risco['max_drawdown'],
        'Sharpe Ratio': metricas_risco['sharpe_ratio'],
        'Total Custos (R$)': total_custos_operacionais,
        'Total Impostos (R$)': total_impostos,
        'Min Previsto': min_previsto,
        'Max Previsto': max_previsto,
        'Média Previsto': media_previsoes
    }
    
    print(f"Resultado: Retorno Líquido={retorno_liquido:.2f}%, Sharpe={metricas_risco['sharpe_ratio']:.2f}, Total IR={total_impostos:.2f}")
    
    return saldo, transacoes, diagnostico

def processar_previsoes_realista(input_dir, tickers, janelas, saldo_inicial):
    """Processa previsões com estrutura FLAT de arquivos."""
    resultados = []
    todas_transacoes = {}
    todos_diagnosticos = {}
    
    for ticker in tickers:
        print(f"\n{'='*60}")
        print(f"Processando {ticker}...")
        print(f"{'='*60}")
        
        ticker_resultados = {'Ticker': ticker}
        todas_transacoes[ticker] = {}
        todos_diagnosticos[ticker] = {}
        
        for janela in janelas:
            previsoes_file = os.path.join(input_dir, f"{ticker}_{janela}_previsoes_teste_final.csv")
            
            print(f"\n  Buscando: {janela}")
            print(f"  Caminho: {previsoes_file}")
            
            if os.path.exists(previsoes_file):
                try:
                    dados = pd.read_csv(previsoes_file)
                    print(f"  ✓ Arquivo encontrado! Shape: {dados.shape}")
                    
                    saldo_final, transacoes, diagnostico = estrategia_all_in_realista(dados, saldo_inicial)
                    
                    todas_transacoes[ticker][janela] = transacoes
                    todos_diagnosticos[ticker][janela] = diagnostico
                    
                    ticker_resultados[f"Saldo Final {janela}"] = saldo_final
                    ticker_resultados[f"Retorno Liquido {janela} (%)"] = diagnostico['Retorno Liquido (%)']
                    ticker_resultados[f"Sharpe {janela}"] = diagnostico['Sharpe Ratio']
                    ticker_resultados[f"Drawdown {janela} (%)"] = diagnostico['Max Drawdown (%)']
                    ticker_resultados[f"Custos {janela} (R$)"] = diagnostico['Total Custos (R$)']
                    ticker_resultados[f"Impostos {janela} (R$)"] = diagnostico['Total Impostos (R$)']
                    
                except Exception as e:
                    print(f"  ❌ Erro ao processar {ticker} - {janela}: {str(e)}")
                    import traceback
                    traceback.print_exc()
                    
                    ticker_resultados[f"Saldo Final {janela}"] = saldo_inicial
                    ticker_resultados[f"Retorno Liquido {janela} (%)"] = 0.0
            else:
                print(f"  ❌ Arquivo não encontrado!")
                ticker_resultados[f"Saldo Final {janela}"] = saldo_inicial
                ticker_resultados[f"Retorno Liquido {janela} (%)"] = 0.0
        
        resultados.append(ticker_resultados)
    
    return pd.DataFrame(resultados), todas_transacoes, todos_diagnosticos

# =============================================================================
# CÓDIGO PRINCIPAL
# =============================================================================

saldo_inicial = 10000

print("\n" + "="*80)
print(" "*20 + "SIMULAÇÃO REALISTA DE TRADING - B3 2026")
print("="*80)
print(f"Saldo Inicial: R$ {saldo_inicial:,.2f}")
print(f"Taxa B3: {TAXA_NEGOCIACAO_LIQUIDACAO*100:.3f}% | Slippage: {SLIPPAGE*100:.3f}%")
print(f"IR Swing Trade: {IR_SWING_TRADE*100:.1f}% | IR Day Trade: {IR_DAY_TRADE*100:.1f}%")
print(f"Isenção Mensal: R$ {ISENCAO_VENDA_MENSAL:,.2f}")
print(f"Pasta de Dados: {input_dir}")
print("="*80 + "\n")

df_resultados, todas_transacoes, todos_diagnosticos = processar_previsoes_realista(
    input_dir, tickers, janelas, saldo_inicial
)

# Salvar resultados
resultados_filepath = os.path.join(output_dir, "resultados_trading_realista_transformer.csv")
df_resultados.to_csv(resultados_filepath, index=False)
print(f"\n✓ Resultados salvos em: {resultados_filepath}")

# Salvar diagnósticos
diagnosticos_list = []
for ticker in todos_diagnosticos:
    for janela in todos_diagnosticos.get(ticker, {}):
        if todos_diagnosticos[ticker][janela]:
            diagnostico = todos_diagnosticos[ticker][janela].copy()
            diagnostico['Ticker'] = ticker
            diagnostico['Janela'] = janela
            diagnosticos_list.append(diagnostico)

if diagnosticos_list:
    df_diagnosticos = pd.DataFrame(diagnosticos_list)
    diagnosticos_filepath = os.path.join(output_dir, "diagnosticos_trading_realista_transformer.csv")
    df_diagnosticos.to_csv(diagnosticos_filepath, index=False)
    print(f"✓ Diagnósticos salvos em: {diagnosticos_filepath}")

# Salvar transações
for ticker in tickers:
    ticker_dir = os.path.join(transactions_dir, ticker)
    os.makedirs(ticker_dir, exist_ok=True)
    
    for janela in janelas:
        if janela in todas_transacoes.get(ticker, {}):
            transacoes = todas_transacoes[ticker][janela]
            
            if transacoes:
                df_transacoes = pd.DataFrame(transacoes)
                transacoes_filepath = os.path.join(ticker_dir, f"{ticker}_{janela}_transacoes_realista.csv")
                df_transacoes.to_csv(transacoes_filepath, index=False)

# Identificar melhor janela por Sharpe Ratio
melhores_resultados = []
for _, row in df_resultados.iterrows():
    ticker = row['Ticker']
    melhor_janela = None
    melhor_sharpe = -np.inf
    
    for janela in janelas:
        sharpe = row.get(f"Sharpe {janela}", -np.inf)
        saldo = row.get(f"Saldo Final {janela}", 0)
        
        if sharpe > melhor_sharpe and saldo > saldo_inicial * 0.95:
            melhor_sharpe = sharpe
            melhor_janela = janela
    
    if melhor_janela:
        melhores_resultados.append({
            'Ticker': ticker,
            'Melhor Janela': melhor_janela,
            'Saldo Final': row[f"Saldo Final {melhor_janela}"],
            'Retorno Liquido (%)': row[f"Retorno Liquido {melhor_janela} (%)"],
            'Sharpe Ratio': melhor_sharpe,
            'Drawdown (%)': row[f"Drawdown {melhor_janela} (%)"],
            'Custos (R$)': row[f"Custos {melhor_janela} (R$)"],
            'Impostos (R$)': row[f"Impostos {melhor_janela} (R$)"]
        })

# =============================================================================
# ANÁLISE BUY & HOLD
# =============================================================================

print("\n" + "="*80)
print(" "*25 + "ANÁLISE BUY & HOLD")
print("="*80)

resultados_buy_hold = []

for ticker in tickers:
    print(f"\nProcessando Buy & Hold para {ticker}...")
    
    arquivo_encontrado = None
    for janela in janelas:
        previsoes_file = os.path.join(input_dir, f"{ticker}_{janela}_previsoes_teste_final.csv")
        if os.path.exists(previsoes_file):
            arquivo_encontrado = previsoes_file
            break
    
    if arquivo_encontrado:
        try:
            dados = pd.read_csv(arquivo_encontrado)
            dados['Preço Real'] = pd.to_numeric(dados['Preço Real'], errors='coerce')
            dados['Data'] = pd.to_datetime(dados['Data'])
            dados = dados.dropna(subset=['Preço Real'])
            
            if len(dados) > 0:
                preco_inicial = dados.iloc[0]['Preço Real']
                preco_final = dados.iloc[-1]['Preço Real']
                
                # Calcular Buy & Hold com custos
                custos_compra_bh = saldo_inicial * (TAXA_NEGOCIACAO_LIQUIDACAO + SLIPPAGE)
                saldo_pos_custo_bh = saldo_inicial - custos_compra_bh
                
                quantidade_acoes_bh = saldo_pos_custo_bh / (preco_inicial * (1 + SLIPPAGE))
                
                valor_bruto_venda_bh = quantidade_acoes_bh * preco_final * (1 - SLIPPAGE)
                custos_venda_bh = valor_bruto_venda_bh * (TAXA_NEGOCIACAO_LIQUIDACAO + SLIPPAGE)
                
                custo_aquisicao_bh = quantidade_acoes_bh * (preco_inicial * (1 + SLIPPAGE))
                lucro_bruto_bh = valor_bruto_venda_bh - custo_aquisicao_bh - custos_venda_bh
                
                imposto_bh = 0.0
                if lucro_bruto_bh > 0 and valor_bruto_venda_bh > ISENCAO_VENDA_MENSAL:
                    imposto_bh = lucro_bruto_bh * IR_SWING_TRADE
                
                saldo_final_bh = valor_bruto_venda_bh - custos_venda_bh - imposto_bh
                retorno_bh = ((saldo_final_bh - saldo_inicial) / saldo_inicial) * 100
                
                # Métricas de risco Buy & Hold
                precos = dados['Preço Real'].values
                patrimonio_bh = quantidade_acoes_bh * precos
                
                pico_bh = np.maximum.accumulate(patrimonio_bh)
                drawdown_bh = (patrimonio_bh - pico_bh) / pico_bh
                max_drawdown_bh = np.min(drawdown_bh) * 100
                
                retornos_bh = np.diff(precos) / precos[:-1]
                if len(retornos_bh) > 0 and np.std(retornos_bh) != 0:
                    sharpe_bh = np.mean(retornos_bh) / np.std(retornos_bh) * np.sqrt(252)
                else:
                    sharpe_bh = 0.0
                
                resultados_buy_hold.append({
                    'Ticker': ticker,
                    'Saldo Final': saldo_final_bh,
                    'Retorno (%)': retorno_bh,
                    'Sharpe Ratio': sharpe_bh,
                    'Drawdown (%)': max_drawdown_bh,
                    'Custos (R$)': custos_compra_bh + custos_venda_bh,
                    'Impostos (R$)': imposto_bh
                })
                
                print(f"  ✓ Buy & Hold: Retorno={retorno_bh:.2f}%, Sharpe={sharpe_bh:.2f}, DD={max_drawdown_bh:.1f}%")
                
        except Exception as e:
            print(f"  ❌ Erro ao processar Buy & Hold: {str(e)}")
    else:
        print(f"  ❌ Nenhum arquivo encontrado para {ticker}")

if resultados_buy_hold:
    df_buy_hold = pd.DataFrame(resultados_buy_hold)
    
    buy_hold_filepath = os.path.join(output_dir, "resultados_buy_hold.csv")
    df_buy_hold.to_csv(buy_hold_filepath, index=False)
    print(f"\n✓ Resultados Buy & Hold salvos em: {buy_hold_filepath}")

# =============================================================================
# GRÁFICOS E COMPARAÇÕES
# =============================================================================

if melhores_resultados:
    df_melhores = pd.DataFrame(melhores_resultados).sort_values(by='Sharpe Ratio', ascending=False)
    
    melhores_filepath = os.path.join(output_dir, "melhores_resultados_realista_transformer.csv")
    df_melhores.to_csv(melhores_filepath, index=False)
    print(f"✓ Melhores resultados salvos em: {melhores_filepath}")
    
    # ========== GRÁFICO 1: Retorno Líquido (Trading Realista) ==========
    fig1, ax1 = plt.subplots(figsize=(18, 10))
    
    colors = ['darkgreen' if r > 10 else 'green' if r > 0 else 'red' for r in df_melhores['Retorno Liquido (%)']]
    bars = ax1.bar(df_melhores['Ticker'], df_melhores['Saldo Final'], 
                   color=colors, edgecolor='black', linewidth=1.5, alpha=0.8)
    ax1.axhline(y=saldo_inicial, color='blue', linestyle='--', linewidth=2.5, 
                label=f'Saldo Inicial: R$ {saldo_inicial:,.2f}')
    
    max_saldo = df_melhores['Saldo Final'].max()
    ax1.set_ylim(0, max_saldo * 1.25)
    
    for i, bar in enumerate(bars):
        row = df_melhores.iloc[i]
        saldo = row['Saldo Final']
        retorno = row['Retorno Liquido (%)']
        janela = row['Melhor Janela']
        custos = row['Custos (R$)']
        impostos = row['Impostos (R$)']
        
        offset = max_saldo * 0.03
        ax1.text(i, saldo + offset, 
                f"R$ {saldo:,.0f}\n{retorno:+.1f}%\n{janela}\nC: R${custos:.0f} | I: R${impostos:.0f}",
                ha='center', va='bottom', fontsize=10, fontweight='bold')
    
    ax1.set_title('🤖 Transformers - Trading Realista 2023 (Retorno Líquido)', 
                  fontsize=16, fontweight='bold', pad=20)
    ax1.set_xlabel('Ticker', fontsize=13, fontweight='bold')
    ax1.set_ylabel('Saldo Final (R$)', fontsize=13, fontweight='bold')
    ax1.legend(fontsize=11, loc='upper left')
    ax1.grid(axis='y', alpha=0.4, linestyle='--')
    ax1.set_axisbelow(True)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    
    grafico1_filepath = os.path.join(output_dir, "trading_realista_transformer_retorno.png")
    plt.savefig(grafico1_filepath, dpi=300, bbox_inches='tight')
    print(f"✓ Gráfico 1 (Retorno) salvo em: {grafico1_filepath}")
    plt.show()
    
    # ========== GRÁFICO 2: Sharpe Ratio ==========
    fig2, ax2 = plt.subplots(figsize=(18, 10))
    
    colors2 = ['darkgreen' if s > 1.5 else 'green' if s > 0.5 else 'orange' if s > 0 else 'darkred' 
               for s in df_melhores['Sharpe Ratio']]
    ax2.bar(df_melhores['Ticker'], df_melhores['Sharpe Ratio'], 
            color=colors2, edgecolor='black', linewidth=1.5, alpha=0.8)
    ax2.axhline(y=0, color='black', linestyle='-', linewidth=1.5)
    ax2.axhline(y=1, color='green', linestyle='--', linewidth=2, 
                label='Sharpe > 1 (Bom)', alpha=0.7)
    
    max_sharpe = df_melhores['Sharpe Ratio'].max()
    min_sharpe = df_melhores['Sharpe Ratio'].min()
    sharpe_range = max_sharpe - min_sharpe
    ax2.set_ylim(min_sharpe - sharpe_range * 0.2, max_sharpe + sharpe_range * 0.3)
    
    for i, (idx, row) in enumerate(df_melhores.iterrows()):
        sharpe = row['Sharpe Ratio']
        drawdown = row['Drawdown (%)']
        
        offset = sharpe_range * 0.08 if sharpe > 0 else -sharpe_range * 0.08
        ax2.text(i, sharpe + offset, 
                f"{sharpe:.2f}\nDD: {drawdown:.1f}%", 
                ha='center', va='bottom' if sharpe > 0 else 'top', 
                fontsize=10, fontweight='bold')
    
    ax2.set_title('📊 Sharpe Ratio e Maximum Drawdown', 
                  fontsize=16, fontweight='bold', pad=20)
    ax2.set_xlabel('Ticker', fontsize=13, fontweight='bold')
    ax2.set_ylabel('Sharpe Ratio', fontsize=13, fontweight='bold')
    ax2.legend(fontsize=11, loc='upper left')
    ax2.grid(axis='y', alpha=0.4, linestyle='--')
    ax2.set_axisbelow(True)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    
    grafico2_filepath = os.path.join(output_dir, "trading_realista_transformer_sharpe.png")
    plt.savefig(grafico2_filepath, dpi=300, bbox_inches='tight')
    print(f"✓ Gráfico 2 (Sharpe) salvo em: {grafico2_filepath}")
    plt.show()
    
    # ========== COMPARAÇÃO: ESTRATÉGIA vs BUY & HOLD ==========
    if resultados_buy_hold:
        print("\n" + "="*80)
        print(" "*20 + "COMPARAÇÃO: ESTRATÉGIA vs BUY & HOLD")
        print("="*80)
        
        comparacao = []
        for _, row_estrategia in df_melhores.iterrows():
            ticker = row_estrategia['Ticker']
            row_bh = df_buy_hold[df_buy_hold['Ticker'] == ticker]
            
            if not row_bh.empty:
                row_bh = row_bh.iloc[0]
                
                diferenca_retorno = row_estrategia['Retorno Liquido (%)'] - row_bh['Retorno (%)']
                diferenca_sharpe = row_estrategia['Sharpe Ratio'] - row_bh['Sharpe Ratio']
                
                comparacao.append({
                    'Ticker': ticker,
                    'Estrategia_Retorno (%)': row_estrategia['Retorno Liquido (%)'],
                    'BuyHold_Retorno (%)': row_bh['Retorno (%)'],
                    'Diferenca_Retorno (%)': diferenca_retorno,
                    'Estrategia_Sharpe': row_estrategia['Sharpe Ratio'],
                    'BuyHold_Sharpe': row_bh['Sharpe Ratio'],
                    'Diferenca_Sharpe': diferenca_sharpe,
                    'Estrategia_Saldo': row_estrategia['Saldo Final'],
                    'BuyHold_Saldo': row_bh['Saldo Final'],
                    'Melhor': 'Estratégia' if diferenca_retorno > 0 else 'Buy & Hold'
                })
        
        df_comparacao = pd.DataFrame(comparacao)
        
        comparacao_filepath = os.path.join(output_dir, "comparacao_estrategia_vs_buyhold.csv")
        df_comparacao.to_csv(comparacao_filepath, index=False)
        print(f"✓ Comparação salva em: {comparacao_filepath}")
        
        # ========== GRÁFICO 3: COMPARAÇÃO RETORNOS ==========
        fig3, ax3 = plt.subplots(figsize=(18, 10))
        
        x = np.arange(len(df_comparacao))
        width = 0.35
        
        bars1 = ax3.bar(x - width/2, df_comparacao['Estrategia_Retorno (%)'], width,
                       label='Estratégia (Melhor Janela)', 
                       color=['darkgreen' if r > 0 else 'red' for r in df_comparacao['Estrategia_Retorno (%)']],
                       edgecolor='black', linewidth=1.5, alpha=0.8)
        
        bars2 = ax3.bar(x + width/2, df_comparacao['BuyHold_Retorno (%)'], width,
                       label='Buy & Hold',
                       color=['darkblue' if r > 0 else 'darkred' for r in df_comparacao['BuyHold_Retorno (%)']],
                       edgecolor='black', linewidth=1.5, alpha=0.8)
        
        ax3.axhline(y=0, color='black', linestyle='-', linewidth=1.5)
        
        for i, (bar1, bar2) in enumerate(zip(bars1, bars2)):
            height1 = bar1.get_height()
            height2 = bar2.get_height()
            
            ax3.text(bar1.get_x() + bar1.get_width()/2., height1,
                    f'{height1:.1f}%',
                    ha='center', va='bottom' if height1 > 0 else 'top',
                    fontsize=9, fontweight='bold')
            
            ax3.text(bar2.get_x() + bar2.get_width()/2., height2,
                    f'{height2:.1f}%',
                    ha='center', va='bottom' if height2 > 0 else 'top',
                    fontsize=9, fontweight='bold')
        
        ax3.set_title('📊 Comparação: Estratégia Trading vs Buy & Hold (Retorno Líquido)',
                     fontsize=16, fontweight='bold', pad=20)
        ax3.set_xlabel('Ticker', fontsize=13, fontweight='bold')
        ax3.set_ylabel('Retorno (%)', fontsize=13, fontweight='bold')
        ax3.set_xticks(x)
        ax3.set_xticklabels(df_comparacao['Ticker'], rotation=45, ha='right')
        ax3.legend(fontsize=12, loc='upper left')
        ax3.grid(axis='y', alpha=0.4, linestyle='--')
        ax3.set_axisbelow(True)
        plt.tight_layout()
        
        grafico3_filepath = os.path.join(output_dir, "comparacao_retornos_estrategia_vs_buyhold.png")
        plt.savefig(grafico3_filepath, dpi=300, bbox_inches='tight')
        print(f"✓ Gráfico 3 (Comparação Retornos) salvo em: {grafico3_filepath}")
        plt.show()
        
        # ========== GRÁFICO 4: COMPARAÇÃO SHARPE RATIO ==========
        fig4, ax4 = plt.subplots(figsize=(18, 10))
        
        bars3 = ax4.bar(x - width/2, df_comparacao['Estrategia_Sharpe'], width,
                       label='Estratégia (Melhor Janela)',
                       color=['darkgreen' if s > 0 else 'red' for s in df_comparacao['Estrategia_Sharpe']],
                       edgecolor='black', linewidth=1.5, alpha=0.8)
        
        bars4 = ax4.bar(x + width/2, df_comparacao['BuyHold_Sharpe'], width,
                       label='Buy & Hold',
                       color=['darkblue' if s > 0 else 'darkred' for s in df_comparacao['BuyHold_Sharpe']],
                       edgecolor='black', linewidth=1.5, alpha=0.8)
        
        ax4.axhline(y=0, color='black', linestyle='-', linewidth=1.5)
        ax4.axhline(y=1, color='green', linestyle='--', linewidth=2,
                   label='Sharpe > 1 (Bom)', alpha=0.7)
        
        for i, (bar3, bar4) in enumerate(zip(bars3, bars4)):
            height3 = bar3.get_height()
            height4 = bar4.get_height()
            
            ax4.text(bar3.get_x() + bar3.get_width()/2., height3,
                    f'{height3:.2f}',
                    ha='center', va='bottom' if height3 > 0 else 'top',
                    fontsize=9, fontweight='bold')
            
            ax4.text(bar4.get_x() + bar4.get_width()/2., height4,
                    f'{height4:.2f}',
                    ha='center', va='bottom' if height4 > 0 else 'top',
                    fontsize=9, fontweight='bold')
        
        ax4.set_title('📊 Comparação: Estratégia Trading vs Buy & Hold (Sharpe Ratio)',
                     fontsize=16, fontweight='bold', pad=20)
        ax4.set_xlabel('Ticker', fontsize=13, fontweight='bold')
        ax4.set_ylabel('Sharpe Ratio', fontsize=13, fontweight='bold')
        ax4.set_xticks(x)
        ax4.set_xticklabels(df_comparacao['Ticker'], rotation=45, ha='right')
        ax4.legend(fontsize=12, loc='upper left')
        ax4.grid(axis='y', alpha=0.4, linestyle='--')
        ax4.set_axisbelow(True)
        plt.tight_layout()
        
        grafico4_filepath = os.path.join(output_dir, "comparacao_sharpe_estrategia_vs_buyhold.png")
        plt.savefig(grafico4_filepath, dpi=300, bbox_inches='tight')
        print(f"✓ Gráfico 4 (Comparação Sharpe) salvo em: {grafico4_filepath}")
        plt.show()
        
        # ========== RESUMO ESTATÍSTICO ==========
        print("\n" + "="*80)
        print(" "*25 + "RESUMO ESTATÍSTICO")
        print("="*80)
        
        estrategia_vence = (df_comparacao['Diferenca_Retorno (%)'] > 0).sum()
        buyhold_vence = (df_comparacao['Diferenca_Retorno (%)'] <= 0).sum()
        
        media_retorno_estrategia = df_comparacao['Estrategia_Retorno (%)'].mean()
        media_retorno_buyhold = df_comparacao['BuyHold_Retorno (%)'].mean()
        
        media_sharpe_estrategia = df_comparacao['Estrategia_Sharpe'].mean()
        media_sharpe_buyhold = df_comparacao['BuyHold_Sharpe'].mean()
        
        print(f"\n📈 VITÓRIAS:")
        print(f"   Estratégia: {estrategia_vence} tickers ({estrategia_vence/len(df_comparacao)*100:.1f}%)")
        print(f"   Buy & Hold: {buyhold_vence} tickers ({buyhold_vence/len(df_comparacao)*100:.1f}%)")
        
        print(f"\n💰 RETORNO MÉDIO:")
        print(f"   Estratégia: {media_retorno_estrategia:+.2f}%")
        print(f"   Buy & Hold: {media_retorno_buyhold:+.2f}%")
        print(f"   Diferença:  {media_retorno_estrategia - media_retorno_buyhold:+.2f}%")
        
        print(f"\n📊 SHARPE RATIO MÉDIO:")
        print(f"   Estratégia: {media_sharpe_estrategia:.2f}")
        print(f"   Buy & Hold: {media_sharpe_buyhold:.2f}")
        print(f"   Diferença:  {media_sharpe_estrategia - media_sharpe_buyhold:+.2f}")

print("\n" + "="*80)
print(" "*30 + "✅ EXECUÇÃO CONCLUÍDA")
print("="*80)
# Out:
# ================================================================================
#                     SIMULAÇÃO REALISTA DE TRADING - B3 2026
# ================================================================================
# Saldo Inicial: R$ 10,000.00
# Taxa B3: 0.030% | Slippage: 0.010%
# IR Swing Trade: 15.0% | IR Day Trade: 20.0%
# Isenção Mensal: R$ 20,000.00
# Pasta de Dados: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_pre
| Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ -734.71
#   [VENDA] Data: 2023-11-16 | Venda: R$ 10326.63 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 552.50
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-11-23 | Venda: R$ 10272.90 | Vendas Mês (2023, 11): R$ 10326.63 | Lucro: R$ -49.58
#   [VENDA] Data: 2024-08-28 | Venda: R$ 10799.79 | Vendas Mês (2024, 8): R$ 0.00 | Lucro: R$ 530.79
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2024-09-04 | Venda: R$ 11042.32 | Vendas Mês (2024, 9): R$ 0.00 | Lucro: R$ 246.76
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2024-09-09 | Venda: R$ 10724.86 | Vendas Mês (2024, 9): R$ 11042.32 | Lucro: R$ -312.92
#
# 📊 Resumo de Vendas Mensais:
#   02/2023: R$ 9,367.94 [ISENTO]
#   03/2023: R$ 28,332.25 [TRIBUTÁVEL]
#   04/2023: R$ 26,647.99 [TRIBUTÁVEL]
#   05/2023: R$ 19,249.04 [ISENTO]
#   06/2023: R$ 19,751.32 [ISENTO]
#   07/2023: R$ 30,809.38 [TRIBUTÁVEL]
#   08/2023: R$ 10,529.19 [ISENTO]
#   09/2023: R$ 10,565.88 [ISENTO]
#   11/2023: R$ 10,326.63 [ISENTO]
#   08/2024: R$ 10,799.79 [ISENTO]
#   09/2024: R$ 11,042.32 [ISENTO]
# Resultado: Retorno Líquido=-21.90%, Sharpe=-0.23, Total IR=53.97
#
# ============================================================
# Processando BRFS3.SA...
# ============================================================
#
#   Buscando: Janela_5
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_preco\BRFS3.SA_Janela_5_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (496, 3)
#
# --- Simulação para 2023-01-10 ---
# Min: 11.514506, Max: 14.748792, Média: 13.311959569556452
#   [VENDA] Data: 2023-01-11 | Venda: R$ 10215.14 | Vendas Mês (2023, 1): R$ 0.00 | Lucro: R$ 215.05
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-01-25 | Venda: R$ 10578.37 | Vendas Mês (2023, 1): R$ 10215.14 | Lucro: R$ 367.17
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 793.50 | Proporção: 7.50% | IR = R$ 4.13
#   [VENDA] Data: 2023-01-31 | Venda: R$ 10722.52 | Vendas Mês (2023, 1): R$ 20793.50 | Lucro: R$ 152.45
#     → SWING: Mês já ultrapassou isenção | IR = R$ 22.87
#   [VENDA] Data: 2023-04-12 | Venda: R$ 10370.52 | Vendas Mês (2023, 4): R$ 0.00 | Lucro: R$ -324.71
#   [VENDA] Data: 2023-05-05 | Venda: R$ 10555.22 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 188.77
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-17 | Venda: R$ 10945.63 | Vendas Mês (2023, 5): R$ 10555.22 | Lucro: R$ 394.48
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 1500.84 | Proporção: 13.71% | IR = R$ 8.11
#   [VENDA] Data: 2023-10-04 | Venda: R$ 11012.28 | Vendas Mês (2023, 10): R$ 0.00 | Lucro: R$ 79.11
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-10-16 | Venda: R$ 11281.69 | Vendas Mês (2023, 10): R$ 11012.28 | Lucro: R$ 273.71
#     → SWING: 1ª vez ultrapassando | Excedente: R$ 2293.97 | Proporção: 20.33% | IR = R$ 8.35
#   [VENDA] Data: 2023-10-23 | Venda: R$ 11457.80 | Vendas Mês (2023, 10): R$ 22293.97 | Lucro: R$ 188.89
#     → SWING: Mês já ultrapassou isenção | IR = R$ 28.33
#   [VENDA] Data: 2023-11-01 | Venda: R$ 11539.34 | Vendas Mês (2023, 11): R$ 0.00 | Lucro: R$ 114.41
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2024-04-17 | Venda: R$ 11473.32 | Vendas Mês (2024, 4): R$ 0.00 | Lucro: R$ -61.38
#   [VENDA] Data: 2024-06-03 | Venda: R$ 11541.22 | Vendas Mês (2024, 6): R$ 0.00 | Lucro: R$ 72.47
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2024-06-06 | Venda: R$ 11805.55 | Vendas Mês (2024, 6): R$ 11541.22 | Lucro: R$ 268.84
#     → SWING: 1ª vez ultrapassando | Excedente: R$
| Vendas Mês (2024, 6): R$ 0.00 | Lucro: R$ -72.36
#   [VENDA] Data: 2024-07-31 | Venda: R$ 9007.63 | Vendas Mês (2024, 7): R$ 0.00 | Lucro: R$ -597.93
#   [VENDA] Data: 2024-08-08 | Venda: R$ 8967.16 | Vendas Mês (2024, 8): R$ 0.00 | Lucro: R$ -36.85
#   [VENDA] Data: 2024-08-19 | Venda: R$ 9512.64 | Vendas Mês (2024, 8): R$ 0.00 | Lucro: R$ 548.85
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2024-09-11 | Venda: R$ 9247.80 | Vendas Mês (2024, 9): R$ 0.00 | Lucro: R$ -260.93
#   [VENDA] Data: 2024-09-24 | Venda: R$ 10060.31 | Vendas Mês (2024, 9): R$ 0.00 | Lucro: R$ 815.89
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2024-10-16 | Venda: R$ 9868.43 | Vendas Mês (2024, 10): R$ 0.00 | Lucro: R$ -187.79
#   [VENDA] Data: 2024-10-21 | Venda: R$ 9867.01 | Vendas Mês (2024, 10): R$ 0.00 | Lucro: R$ 2.53
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2024-10-23 | Venda: R$ 9831.41 | Vendas Mês (2024, 10): R$ 9867.01 | Lucro: R$ -31.64
#   [VENDA] Data: 2024-11-18 | Venda: R$ 9712.92 | Vendas Mês (2024, 11): R$ 0.00 | Lucro: R$ -114.51
#   [VENDA] Data: 2024-12-09 | Venda: R$ 10129.24 | Vendas Mês (2024, 12): R$ 0.00 | Lucro: R$ 420.04
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#
# 📊 Resumo de Vendas Mensais:
#   02/2023: R$ 10,091.09 [ISENTO]
#   03/2023: R$ 10,947.52 [ISENTO]
#   05/2023: R$ 28,852.76 [TRIBUTÁVEL]
#   06/2023: R$ 20,491.32 [TRIBUTÁVEL]
#   07/2023: R$ 10,293.49 [ISENTO]
#   09/2023: R$ 29,391.47 [TRIBUTÁVEL]
#   02/2024: R$ 9,451.66 [ISENTO]
#   03/2024: R$ 27,962.45 [TRIBUTÁVEL]
#   04/2024: R$ 9,359.65 [ISENTO]
#   05/2024: R$ 19,228.30 [ISENTO]
#   08/2024: R$ 9,512.64 [ISENTO]
#   09/2024: R$ 10,060.31 [ISENTO]
#   10/2024: R$ 9,867.01 [ISENTO]
#   12/2024: R$ 10,129.24 [ISENTO]
# Resultado: Retorno Líquido=-19.84%, Sharpe=-0.39, Total IR=61.90
#
#   Buscando: Janela_20
#   Caminho: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_preco\CSNA3.SA_Janela_20_previsoes_teste_final.csv
#   ✓ Arquivo encontrado! Shape: (479, 3)
#
# --- Simulação para 2023-01-30 ---
# Min: 9.388316, Max: 16.223368, Média: 11.853292373695199
#   [VENDA] Data: 2023-02-14 | Venda: R$ 10023.41 | Vendas Mês (2023, 2): R$ 0.00 | Lucro: R$ 23.40
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-03-30 | Venda: R$ 9886.00 | Vendas Mês (2023, 3): R$ 0.00 | Lucro: R$ -133.35
#   [VENDA] Data: 2023-05-08 | Venda: R$ 10178.55 | Vendas Mês (2023, 5): R$ 0.00 | Lucro: R$ 296.39
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-05-12 | Venda: R$ 9784.95 | Vendas Mês (2023, 5): R$ 10178.55 | Lucro: R$ -389.37
#   [VENDA] Data: 2023-06-06 | Venda: R$ 10481.33 | Vendas Mês (2023, 6): R$ 0.00 | Lucro: R$ 700.01
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-07-13 | Venda: R$ 11195.96 | Vendas Mês (2023, 7): R$ 0.00 | Lucro: R$ 718.53
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 2023-09-01 | Venda: R$ 10807.26 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ -384.07
#   [VENDA] Data: 2023-09-11 | Venda: R$ 10977.45 | Vendas Mês (2023, 9): R$ 0.00 | Lucro: R$ 174.45
#     → SWING: Dentro da isenção (R$ 20k/mês) | IR = R$ 0.00
#   [VENDA] Data: 
: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\TransformersPrecoResultados\resultados_trading_realista_transformer.csv
# ✓ Diagnósticos salvos em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\TransformersPrecoResultados\diagnosticos_trading_realista_transformer.csv
#
# ================================================================================
#                          ANÁLISE BUY & HOLD
# ================================================================================
#
# Processando Buy & Hold para BEEF3.SA...
#   ✓ Buy & Hold: Retorno=-59.88%, Sharpe=-0.95, DD=-65.4%
#
# Processando Buy & Hold para BRFS3.SA...
#   ✓ Buy & Hold: Retorno=-14.44%, Sharpe=-0.14, DD=-37.5%
#
# Processando Buy & Hold para VALE3.SA...
#   ✓ Buy & Hold: Retorno=-30.10%, Sharpe=-0.61, DD=-34.9%
#
# Processando Buy & Hold para JBSS3.SA...
#   ✓ Buy & Hold: Retorno=18.35%, Sharpe=0.58, DD=-29.5%
#
# Processando Buy & Hold para SOJA3.SA...
#   ✓ Buy & Hold: Retorno=6.95%, Sharpe=0.28, DD=-45.5%
#
# Processando Buy & Hold para SUZB3.SA...
#   ✓ Buy & Hold: Retorno=28.87%, Sharpe=0.62, DD=-28.5%
#
# Processando Buy & Hold para GGBR3.SA...
#   ✓ Buy & Hold: Retorno=-5.51%, Sharpe=0.02, DD=-27.0%
#
# Processando Buy & Hold para CSNA3.SA...
#   ✓ Buy & Hold: Retorno=-31.25%, Sharpe=-0.30, DD=-51.1%
#
# ✓ Resultados Buy & Hold salvos em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\TransformersPrecoResultados\resultados_buy_hold.csv
# ✓ Melhores resultados salvos em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\TransformersPrecoResultados\melhores_resultados_realista_transformer.csv
# C:\Users\leona\AppData\Local\Temp\ipykernel_25636\2124626228.py:566: UserWarning: Glyph 129302 (\N{ROBOT FACE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\leona\AppData\Local\Temp\ipykernel_25636\2124626228.py:569: UserWarning: Glyph 129302 (\N{ROBOT FACE}) missing from font(s) DejaVu Sans.
#   plt.savefig(grafico1_filepath, dpi=300, bbox_inches='tight')
# ✓ Gráfico 1 (Retorno) salvo em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\TransformersPrecoResultados\trading_realista_transformer_retorno.png
# c:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129302 (\N{ROBOT FACE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\leona\AppData\Local\Temp\ipykernel_25636\2124626228.py:607: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\leona\AppData\Local\Temp\ipykernel_25636\2124626228.py:610: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.savefig(grafico2_filepath, dpi=300, bbox_inches='tight')
# ✓ Gráfico 2 (Sharpe) salvo em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\TransformersPrecoResultados\trading_realista_transformer_sharpe.png
# c:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ================================================================================
#                     COMPARAÇÃO: ESTRATÉGIA vs BUY & HOLD
# ================================================================================
# ✓ Comparação salva em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\TransformersPrecoResultados\comparacao_estrategia_vs_buyhold.csv
# C:\Users\leona\AppData\Local\Temp\ipykernel_25636\2124626228.py:691: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\leona\AppData\Local\Temp\ipykernel_25636\2124626228.py:694: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.savefig(grafico3_filepath, dpi=300, bbox_inches='tight')
# ✓ Gráfico 3 (Comparação Retornos) salvo em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\TransformersPrecoResultados\comparacao_retornos_estrategia_vs_buyhold.png
# c:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\leona\AppData\Local\Temp\ipykernel_25636\2124626228.py:738: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\leona\AppData\Local\Temp\ipykernel_25636\2124626228.py:741: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.savefig(grafico4_filepath, dpi=300, bbox_inches='tight')
# ✓ Gráfico 4 (Comparação Sharpe) salvo em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTrade\TransformersPrecoResultados\comparacao_sharpe_estrategia_vs_buyhold.png
# c:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ================================================================================
#                          RESUMO ESTATÍSTICO
# ================================================================================
#
# 📈 VITÓRIAS:
#    Estratégia: 5 tickers (71.4%)
#    Buy & Hold: 2 tickers (28.6%)
#
# 💰 RETORNO MÉDIO:
#    Estratégia: +9.36%
#    Buy & Hold: -3.88%
#    Diferença:  +13.24%
#
# 📊 SHARPE RATIO MÉDIO:
#    Estratégia: 0.34
#    Buy & Hold: 0.06
#    Diferença:  +0.28
#
# ================================================================================
#                               ✅ EXECUÇÃO CONCLUÍDA
# ================================================================================
