# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler  
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import traceback

# Configurar o TensorFlow para usar menos memória
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# --- Função para carregar dados ---
def carregar_dados_ticker(ticker, pasta_dados_tratados):
    """Carrega dados pré-processados APENAS COM FEATURES MACRO."""
    nome_arquivo = f"{ticker}_MacroData_Tratado.csv"
    caminho_arquivo = os.path.join(pasta_dados_tratados, nome_arquivo)

    if not os.path.exists(caminho_arquivo):
        print(f"Erro: Arquivo não encontrado para {ticker} em {caminho_arquivo}")
        return None, None, None

    try:
        print(f"Carregando dados tratados de: {caminho_arquivo}")
        df = pd.read_csv(caminho_arquivo, index_col=0)
        df.index = pd.to_datetime(df.index)

        print("Colunas originais:", df.columns.tolist())

        # Identificar colunas de preço alvo
        target_col = None
        if 'Close_Target' in df.columns:
            target_col = 'Close_Target'
        elif 'Preço' in df.columns:
            target_col = 'Preço'
        else:
            print(f"Erro: Nenhuma coluna de preço alvo encontrada para {ticker}")
            return None, None, None

        # Identificar a coluna de feature de preço
        feature_cols = []
        price_feature_col = None
        
        if 'Close_Feature' in df.columns:
            price_feature_col = 'Close_Feature'
        elif 'Preço_anterior' in df.columns:
            price_feature_col = 'Preço_anterior'
        else:
            print(f"Aviso: Nenhuma coluna de preço anterior encontrada para {ticker}")
        
        if price_feature_col:
            feature_cols.append(price_feature_col)

        # APENAS features macro
        macro_cols = ['TaxaCambio', 'Selic', 'PIB', 'IPCA']

        # Adicionar features disponíveis
        for col in macro_cols:
            if col in df.columns:
                feature_cols.append(col)

        if len(feature_cols) < 2:
            print(f"Aviso: Poucas features encontradas para {ticker}: {feature_cols}")

        print(f"Features identificadas para {ticker}: {feature_cols}")
        print(f"Target identificado para {ticker}: {target_col}")

        # Tratar NaNs
        df = df[feature_cols + [target_col]].copy()
        df.dropna(subset=[target_col], inplace=True)
        
        for col in feature_cols:
            df[col] = pd.to_numeric(df[col], errors='coerce')
        
        df[feature_cols] = df[feature_cols].fillna(method='ffill')
        if df[feature_cols].isnull().any().any():
            df[feature_cols] = df[feature_cols].fillna(method='bfill')
        
        if df[feature_cols + [target_col]].isnull().any().any():
            print(f"Aviso: Ainda existem NaNs para {ticker}. Removendo linhas afetadas...")
            df.dropna(inplace=True)

        print(f"Dimensões finais do DataFrame para {ticker}: {df.shape}")
        if df.empty:
            print(f"Erro: DataFrame ficou vazio para {ticker} após limpeza.")
            return None, None, None

        return df, feature_cols, target_col

    except Exception as e:
        print(f"Erro CRÍTICO ao carregar/processar {caminho_arquivo}: {e}")
        traceback.print_exc()
        return None, None, None

# --- Função para criar janelas ---
def criar_janelas_multivariadas_transformer(features_array, target_array, janela):
    """Cria janelas para Transformers SEM diferenciação."""
    X, y = [], []
    
    if len(features_array) <= janela:
        print(f"Aviso: dados insuficientes ({len(features_array)}) para janela ({janela}).")
        return np.array(X), np.array(y)
    
    for i in range(len(features_array) - janela):
        X.append(features_array[i:(i + janela), :])
        y.append(target_array[i + janela])
    
    return np.array(X), np.array(y)

# --- Positional Encoding ---
def positional_encoding(length, depth):
    """Cria positional encoding para capturar ordem temporal."""
    depth = depth / 2
    positions = np.arange(length)[:, np.newaxis]
    depths = np.arange(depth)[np.newaxis, :] / depth
    
    angle_rates = 1 / (10000**depths)
    angle_rads = positions * angle_rates
    
    pos_encoding = np.concatenate([
        np.sin(angle_rads),
        np.cos(angle_rads)
    ], axis=-1)
    
    return tf.cast(pos_encoding, dtype=tf.float32)

# --- Temporal Fusion Transformer Model ---
def build_temporal_fusion_transformer(input_shape, num_heads=4, ff_dim=128, num_transformer_blocks=2, dropout_rate=0.1):
    """Temporal Fusion Transformer."""
    inputs = layers.Input(shape=input_shape)
    
    x = layers.Dense(ff_dim)(inputs)
    positions = positional_encoding(input_shape[0], ff_dim)
    x = x + positions
    
    for _ in range(num_transformer_blocks):
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads,
            key_dim=ff_dim // num_heads,
            dropout=dropout_rate
        )(x, x)
        attention_output = layers.Dropout(dropout_rate)(attention_output)
        x1 = layers.LayerNormalization(epsilon=1e-6)(x + attention_output)
        
        ffn_output = layers.Dense(ff_dim * 2, activation='relu')(x1)
        ffn_output = layers.Dropout(dropout_rate)(ffn_output)
        ffn_output = layers.Dense(ff_dim)(ffn_output)
        ffn_output = layers.Dropout(dropout_rate)(ffn_output)
        x = layers.LayerNormalization(epsilon=1e-6)(x1 + ffn_output)
    
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(dropout_rate)(x)
    x = layers.Dense(32, activation='relu')(x)
    x = layers.Dropout(dropout_rate / 2)(x)
    outputs = layers.Dense(1)(x)
    
    model = keras.Model(inputs=inputs, outputs=outputs, name="TemporalFusionTransformer")
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.0005),
        loss='mse',
        metrics=['mae']
    )
    
    return model

# --- Função principal para treinar e avaliar ---
def treinar_avaliar_transformer(ticker, janela, df_full, feature_cols, target_col, 
                                resultados_dir="resultados_transformer_macro"):
    """Treina e avalia o Transformer para um ticker e janela."""
    print(f"\n{'='*60}")
    print(f"TRANSFORMER MACRO - {ticker}, Janela {janela}")
    print(f"{'='*60}")
    
    os.makedirs(resultados_dir, exist_ok=True)
    base_filename = f"{resultados_dir}/{ticker}_Janela_{janela}"
    metrics_path = f"{base_filename}_metrics.csv"
    grafico_path = f"{base_filename}_grafico_teste_final.png"
    previsoes_path = f"{base_filename}_previsoes_teste_final.csv"
    model_path = f"{base_filename}_model.keras"
    
    if os.path.exists(metrics_path):
        print(f"✓ Resultados já existem. Pulando...")
        return
    
    start_date_val = "2020-01-01"
    end_date_val = "2022-12-31"
    start_date_test = "2023-01-01"
    end_date_test = "2023-12-31"
    
    try:
        df_val_train = df_full.loc[start_date_val:end_date_val].copy()
        df_test_final = df_full.loc[start_date_test:end_date_test].copy()
    except KeyError as e:
        print(f"❌ Erro ao dividir dados por data: {e}")
        if not df_full.empty: 
            print(f"Datas disponíveis: {df_full.index.min()} a {df_full.index.max()}")
        return
    
    if df_val_train.empty or df_test_final.empty:
        print(f"❌ Erro: Período treino/val ou teste vazio.")
        return
    
    features_val_train = df_val_train[feature_cols].values
    target_val_train = df_val_train[target_col].values
    
    features_test = df_test_final[feature_cols].values
    target_test = df_test_final[target_col].values
    
    scaler_features = StandardScaler()
    scaler_target = StandardScaler()
    
    scaled_features_val_train = scaler_features.fit_transform(features_val_train)
    target_val_train_reshaped = target_val_train.reshape(-1, 1)
    scaled_target_val_train = scaler_target.fit_transform(target_val_train_reshaped).flatten()
    
    scaled_features_test = scaler_features.transform(features_test)
    target_test_reshaped = target_test.reshape(-1, 1)
    scaled_target_test = scaler_target.transform(target_test_reshaped).flatten()
    
    X_train, y_train = criar_janelas_multivariadas_transformer(
        scaled_features_val_train, 
        scaled_target_val_train, 
        janela
    )
    
    X_test, y_test = criar_janelas_multivariadas_transformer(
        scaled_features_test, 
        scaled_target_test, 
        janela
    )
    
    if len(X_train) == 0 or len(X_test) == 0:
        print(f"❌ Erro: Não foi possível criar janelas.")
        return
    
    print(f"✓ Shape X_train: {X_train.shape}, y_train: {y_train.shape}")
    print(f"✓ Shape X_test: {X_test.shape}, y_test: {y_test.shape}")
    
    val_split_idx = int(0.8 * len(X_train))
    X_train_final, y_train_final = X_train[:val_split_idx], y_train[:val_split_idx]
    X_val, y_val = X_train[val_split_idx:], y_train[val_split_idx:]
    
    input_shape = (janela, X_train.shape[2])
    print(f"✓ Input shape: {input_shape}")
    
    model = build_temporal_fusion_transformer(
        input_shape=input_shape,
        num_heads=4,
        ff_dim=128,
        num_transformer_blocks=2,
        dropout_rate=0.1
    )
    
    print(model.summary())
    
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=30,
        restore_best_weights=True,
        verbose=1
    )
    
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=15,
        min_lr=1e-6,
        verbose=1
    )
    
    print(f"\n🚀 Iniciando treinamento...")
    history = model.fit(
        X_train_final, y_train_final,
        validation_data=(X_val, y_val),
        epochs=300,
        batch_size=16,
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )
    
    model.save(model_path)
    print(f"✓ Modelo salvo em: {model_path}")
    
    predictions_scaled = model.predict(X_test, verbose=0)
    predictions = scaler_target.inverse_transform(predictions_scaled).flatten()
    actual = scaler_target.inverse_transform(y_test.reshape(-1, 1)).flatten()
    
    mae = mean_absolute_error(actual, predictions)
    mse = mean_squared_error(actual, predictions)
    rmse = np.sqrt(mse)
    r2 = r2_score(actual, predictions)
    
    var_real = np.std(actual) / np.mean(actual) if np.mean(actual) != 0 else 0
    var_pred = np.std(predictions) / np.mean(predictions) if np.mean(predictions) != 0 else 0
    prop_var = var_pred / var_real if var_real != 0 else 0
    travado = "Sim" if prop_var < 0.3 else "Não"
    
    print("\n📊 RESULTADOS:")
    print(f"MAE: {mae:.4f} | MSE: {mse:.4f} | RMSE: {rmse:.4f} | R²: {r2:.4f}")
    print(f"Variação Real: {var_real:.4f} | Variação Prevista: {var_pred:.4f}")
    print(f"Previsões travadas? {travado}")
    
    metrics_df = pd.DataFrame([{
        'Ticker': ticker,
        'Janela': janela,
        'Modelo': 'Transformer',
        'MAE': mae,
        'MSE': mse,
        'RMSE': rmse,
        'R2': r2,
        'Var_Real': var_real,
        'Var_Pred': var_pred,
        'Prop_Var': prop_var,
        'Travado': travado,
        'Num_Heads': 4,
        'FF_Dim': 128,
        'Transformer_Blocks': 2
    }])
    metrics_df.to_csv(metrics_path, index=False)
    
    datas_teste = df_test_final.index[janela:janela+len(actual)]
    
    if len(datas_teste) == len(actual):
        previsoes_df = pd.DataFrame({
            'Data': datas_teste,
            'Preço Real': actual,
            'Preço Previsto': predictions
        })
        previsoes_df.to_csv(previsoes_path, index=False)
        
        plt.figure(figsize=(14, 7))
        plt.plot(previsoes_df['Data'], previsoes_df['Preço Real'], 
                label='Real', color='blue', linewidth=2, alpha=0.7)
        plt.plot(previsoes_df['Data'], previsoes_df['Preço Previsto'], 
                label='Previsto (Transformer)', color='red', linestyle='--', linewidth=2, alpha=0.7)
        plt.title(f'Transformer MACRO - {ticker} (Janela {janela})', fontsize=14, fontweight='bold')
        plt.xlabel('Data', fontsize=12)
        plt.ylabel('Preço', fontsize=12)
        plt.legend(fontsize=11)
        plt.grid(alpha=0.3)
        plt.tight_layout()
        plt.savefig(grafico_path, dpi=150)
        plt.close()
    
    print(f"✓ Experimento concluído!\n")
    return metrics_df

# --- Função para rodar experimentos ---
def rodar_experimentos_transformer():
    pasta_dados = r"C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoExperimentos\ExperimentoFeatures\dados_macro_csv_processados_tratados"
    resultados_dir = r"C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro"
    os.makedirs(resultados_dir, exist_ok=True)
    
    tickers = ["BEEF3.SA", "PETR4.SA", "SOJA3.SA", "GGBR3.SA", "CSNA3.SA", 
               "VALE3.SA", "JBSS3.SA", "BRFS3.SA", "SUZB3.SA"]
    
    janelas = [5, 10, 15, 20]
    
    resultados_consolidados = []
    
    for ticker in tickers:
        df_ticker_full, feature_cols, target_col = carregar_dados_ticker(ticker, pasta_dados)
        
        if df_ticker_full is None:
            print(f"⚠️  Pulando ticker {ticker} devido a erro no carregamento.")
            continue
        
        for janela in janelas:
            try:
                metrics = treinar_avaliar_transformer(
                    ticker, janela, df_ticker_full, 
                    feature_cols, target_col, resultados_dir
                )
                if metrics is not None:
                    resultados_consolidados.append(metrics)
            except Exception as e:
                print(f"❌ Erro ao processar {ticker}, Janela {janela}: {e}")
                traceback.print_exc()
    
    if resultados_consolidados:
        df_resultados = pd.concat(resultados_consolidados, ignore_index=True)
        df_resultados.to_csv(f"{resultados_dir}/resultados_consolidados_transformer.csv", index=False)
        
        print("\n" + "="*60)
        print("📈 RESUMO DOS RESULTADOS")
        print("="*60)
        print(df_resultados.groupby('Ticker')[['MAE', 'RMSE', 'R2']].mean())
        print(f"\n✓ Resultados salvos em: {resultados_dir}/resultados_consolidados_transformer.csv")

if __name__ == "__main__":
    tf.get_logger().setLevel('ERROR')
    
    print("\n" + "="*60)
    print("🚀 TRANSFORMER - EXPERIMENTOS MACRO")
    print("="*60)
    print("\nModelo: Temporal Fusion Transformer")
    print("Features: APENAS MACRO")
    print("Período Treino: 2020-2022")
    print("Período Teste: 2023")
    print("="*60 + "\n")
    
    rodar_experimentos_transformer()
    
    print("\n" + "="*60)
    print("✅ TODOS EXPERIMENTOS CONCLUÍDOS!")
    print("="*60 + "\n")
# Out:
# c:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\.venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# C:\Users\leona\AppData\Local\Temp\ipykernel_32400\2235400380.py:84: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[feature_cols] = df[feature_cols].fillna(method='ffill')
# ============================================================
# 🚀 TRANSFORMER - EXPERIMENTOS MACRO
# ============================================================
#
# Modelo: Temporal Fusion Transformer
# Features: APENAS MACRO
# Período Treino: 2020-2022
# Período Teste: 2023
# ============================================================
#
# Carregando dados tratados de: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoExperimentos\ExperimentoFeatures\dados_macro_csv_processados_tratados\BEEF3.SA_MacroData_Tratado.csv
# Colunas originais: ['TaxaCambio', 'Selic', 'PIB', 'IPCA', "('BEEF3.SA_Close', 'BEEF3.SA')", 'Close_Feature', 'Close_Target']
# Features identificadas para BEEF3.SA: ['Close_Feature', 'TaxaCambio', 'Selic', 'PIB', 'IPCA']
# Target identificado para BEEF3.SA: Close_Target
# Dimensões finais do DataFrame para BEEF3.SA: (1461, 6)
#
# ============================================================
# TRANSFORMER MACRO - BEEF3.SA, Janela 5
# ============================================================
# ✓ Shape X_train: (1091, 5, 5), y_train: (1091,)
# ✓ Shape X_test: (360, 5, 5), y_test: (360,)
# ✓ Input shape: (5, 5)
# Model: "TemporalFusionTransformer"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 5, 5)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 5, 128)    │        768 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 5, 128)    │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 128)    │     66,048 │ add[0][0],        │
# │ (MultiHeadAttentio… │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 5, 128)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 5, 128)    │          0 │ add[0][0],        │
# │                     │                   │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 5, 128)    │        256 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 5, 256)    │     33,024 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 5, 256)    │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 5, 128)    │     32,896 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 5, 128)    │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 5, 128)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 128)    │        256 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 128)    │     66,048 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 5, 128)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 5, 128)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 128)    │        256 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 5, 256)    │     33,024 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 5, 256)    │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 5, 128)    │     32,896 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 5, 128)    │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 5, 128)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 128)    │        256 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 64)        │      8,256 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 64)        │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 32)        │      2,080 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 32)        │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 1)         │         33 │ dropout_9[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 276,097 (1.05 MB)
#  Trainable params: 276,097 (1.05 MB)
#  Non-trainable params: 0 (0.00 B)
# None
#
# 🚀 Iniciando treinamento...
# Epoch 1/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - loss: 0.2374 - mae: 0.3525 - val_loss: 0.2672 - val_mae: 0.4417 - learning_rate: 5.0000e-04
# Epoch 2/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0871 - mae: 0.2279 - val_loss: 0.2024 - val_mae: 0.3751 - learning_rate: 5.0000e-04
# Epoch 3/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0792 - mae: 0.2121 - val_loss: 0.1039 - val_mae: 0.2456 - learning_rate: 5.0000e-04
# Epoch 4/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0597 - mae: 0.1857 - val_loss: 0.1148 - val_mae: 0.2504 - learning_rate: 5.0000e-04
# Epoch 5/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0530 - mae: 0.1766 - val_loss: 0.1098 - val_mae: 0.2461 - learning_rate: 5.0000e-04
# Epoch 6/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0484 - mae: 0.1688 - val_loss: 0.1227 - val_mae: 0.2592 - learning_rate: 5.0000e-04
# Epoch 7/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0437 - mae: 0.1594 - val_loss: 0.1697 - val_mae: 0.3275 - learning_rate: 5.0000e-04
# Epoch 8/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0410 - mae: 0.1531 - val_loss: 0.1943 - val_mae: 0.3521 - learning_rate: 5.0000e-04
# Epoch 9/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0386 - mae: 0.1475 - val_loss: 0.1355 - val_mae: 0.2778 - learning_rate: 5.0000e-04
# Epoch 10/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0414 - mae: 0.1547 - val_loss: 0.0904 - val_mae: 0.2213 - learning_rate: 5.0000e-04
# Epoch 11/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0349 - mae: 0.1419 - val_loss: 0.1203 - val_mae: 0.2563 - learning_rate: 5.0000e-04
# Epoch 12/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0344 - mae: 0.1414 - val_loss: 0.1247 - val_mae: 0.2616 - learning_rate: 5.0000e-04
# Epoch 13/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0351 - mae: 0.1441 - val_loss: 0.1795 - val_mae: 0.3352 - learning_rate: 5.0000e-04
# Epoch 14/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0324 - mae: 0.1375 - val_loss: 0.1150 - val_mae: 0.2499 - learning_rate: 5.0000e-04
# Epoch 15/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0334 - mae: 0.1396 - val_loss: 0.1170 - val_mae: 0.2538 - learning_rate: 5.0000e-04
# Epoch 16/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0384 - mae: 0.1479 - val_loss: 0.2687 - val_mae: 0.4385 - learning_rate: 5.0000e-04
# Epoch 17/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0351 - mae: 0.1410 - val_loss: 0.2330 - val_mae: 0.3971 - learning_rate: 5.0000e-04
# Epoch 18/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0362 - mae: 0.1446 - val_loss: 0.2515 - val_mae: 0.3978 - learning_rate: 5.0000e-04
# Epoch 19/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0332 - mae: 0.1385 - val_loss: 0.1263 - val_mae: 0.2640 - learning_rate: 5.0000e-04
# Epoch 20/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0309 - mae: 0.1356 - val_loss: 0.3325 - val_mae: 0.4935 - learning_rate: 5.0000e-04
# Epoch 21/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0314 - mae: 0.1348 - val_loss: 0.1579 - val_mae: 0.2963 - learning_rate: 5.0000e-04
# Epoch 22/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0336 - mae: 0.1382 - val_loss: 0.0845 - val_mae: 0.2215 - learning_rate: 5.0000e-04
# Epoch 23/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0313 - mae: 0.1335 - val_loss: 0.2533 - val_mae: 0.4056 - learning_rate: 5.0000e-04
# Epoch 24/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0307 - mae: 0.1308 - val_loss: 0.2045 - val_mae: 0.3545 - learning_rate: 5.0000e-04
# Epoch 25/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0302 - mae: 0.1317 - val_loss: 0.1407 - val_mae: 0.2746 - learning_rate: 5.0000e-04
# Epoch 26/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0294 - mae: 0.1282 - val_loss: 0.1733 - val_mae: 0.3164 - learning_rate: 5.0000e-04
# Epoch 27/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0298 - mae: 0.1311 - val_loss: 0.1844 - val_mae: 0.3320 - learning_rate: 5.0000e-04
# Epoch 28/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0269 - mae: 0.1251 - val_loss: 0.2322 - val_mae: 0.3778 - learning_rate: 5.0000e-04
# Epoch 29/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0288 - mae: 0.1258 - val_loss: 0.1039 - val_mae: 0.2424 - learning_rate: 5.0000e-04
# Epoch 30/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0281 - mae: 0.1264 - val_loss: 0.3130 - val_mae: 0.4694 - learning_rate: 5.0000e-04
# Epoch 31/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0309 - mae: 0.1335 - val_loss: 0.1498 - val_mae: 0.2854 - learning_rate: 5.0000e-04
# Epoch 32/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0255 - mae: 0.1215 - val_loss: 0.1737 - val_mae: 0.3133 - learning_rate: 5.0000e-04
# Epoch 33/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0285 - mae: 0.1289 - val_loss: 0.1267 - val_mae: 0.2607 - learning_rate: 5.0000e-04
# Epoch 34/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0328 - mae: 0.1355 - val_loss: 0.2062 - val_mae: 0.3472 - learning_rate: 5.0000e-04
# Epoch 35/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0293 - mae: 0.1284 - val_loss: 0.1420 - val_mae: 0.2751 - learning_rate: 5.0000e-04
# Epoch 36/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0311 - mae: 0.1325 - val_loss: 0.2755 - val_mae: 0.4271 - learning_rate: 5.0000e-04
# Epoch 37/300
# 54/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0274 - mae: 0.1266
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0260 - mae: 0.1201 - val_loss: 0.1652 - val_mae: 0.3021 - learning_rate: 5.0000e-04
# Epoch 38/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0261 - mae: 0.1193 - val_loss: 0.1822 - val_mae: 0.3215 - learning_rate: 2.5000e-04
# Epoch 39/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0234 - mae: 0.1138 - val_loss: 0.1942 - val_mae: 0.3350 - learning_rate: 2.5000e-04
# Epoch 40/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0237 - mae: 0.1148 - val_loss: 0.1830 - val_mae: 0.3196 - learning_rate: 2.5000e-04
# Epoch 41/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0254 - mae: 0.1188 - val_loss: 0.1646 - val_mae: 0.2991 - learning_rate: 2.5000e-04
# Epoch 42/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0254 - mae: 0.1187 - val_loss: 0.2801 - val_mae: 0.4218 - learning_rate: 2.5000e-04
# Epoch 43/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0249 - mae: 0.1189 - val_loss: 0.1963 - val_mae: 0.3391 - learning_rate: 2.5000e-04
# Epoch 44/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0243 - mae: 0.1201 - val_loss: 0.1970 - val_mae: 0.3390 - learning_rate: 2.5000e-04
# Epoch 45/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0222 - mae: 0.1136 - val_loss: 0.2850 - val_mae: 0.4361 - learning_rate: 2.5000e-04
# Epoch 46/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0234 - mae: 0.1155 - val_loss: 0.1985 - val_mae: 0.3379 - learning_rate: 2.5000e-04
# Epoch 47/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0240 - mae: 0.1155 - val_loss: 0.2734 - val_mae: 0.4212 - learning_rate: 2.5000e-04
# Epoch 48/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0220 - mae: 0.1134 - val_loss: 0.1727 - val_mae: 0.3102 - learning_rate: 2.5000e-04
# Epoch 49/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0226 - mae: 0.1111 - val_loss: 0.2183 - val_mae: 0.3682 - learning_rate: 2.5000e-04
# Epoch 50/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0251 - mae: 0.1176 - val_loss: 0.2028 - val_mae: 0.3436 - learning_rate: 2.5000e-04
# Epoch 51/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0232 - mae: 0.1126 - val_loss: 0.1677 - val_mae: 0.3035 - learning_rate: 2.5000e-04
# Epoch 52/300
# 52/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0208 - mae: 0.1100
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0226 - mae: 0.1134 - val_loss: 0.2086 - val_mae: 0.3505 - learning_rate: 2.5000e-04
# Epoch 52: early stopping
# Restoring model weights from the end of the best epoch: 22.
# ✓ Modelo salvo em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro/BEEF3.SA_Janela_5_model.keras
#
# 📊 RESULTADOS:
# MAE: 0.7778 | MSE: 0.9270 | RMSE: 0.9628 | R²: 0.7325
# Variação Real: 0.1933 | Variação Prevista: 0.1814
# Previsões travadas? Não
# ✓ Experimento concluído!
#
#
# ============================================================
# TRANSFORMER MACRO - BEEF3.SA, Janela 10
# ============================================================
# ✓ Shape X_train: (1086, 10, 5), y_train: (1086,)
# ✓ Shape X_test: (355, 10, 5), y_test: (355,)
# ✓ Input shape: (10, 5)
# Model: "TemporalFusionTransformer"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 10, 5)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 10, 128)   │        768 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 10, 128)   │          0 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 10, 128)   │     66,048 │ add_5[0][0],      │
# │ (MultiHeadAttentio… │                   │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 10, 128)   │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 10, 128)   │          0 │ add_5[0][0],      │
# │                     │                   │            │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 128)   │        256 │ add_6[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 10, 256)   │     33,024 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 10, 256)   │          0 │ dense_9[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 10, 128)   │     32,896 │ dropout_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 10, 128)   │          0 │ dense_10[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 10, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 128)   │        256 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 10, 128)   │     66,048 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 10, 128)   │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 10, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_15[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 128)   │        256 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 10, 256)   │     33,024 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 10, 256)   │          0 │ dense_11[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 10, 128)   │     32,896 │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 10, 128)   │          0 │ dense_12[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 10, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 128)   │        256 │ add_9[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 64)        │      8,256 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 64)        │          0 │ dense_13[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 32)        │      2,080 │ dropout_18[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 32)        │          0 │ dense_14[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 1)         │         33 │ dropout_19[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 276,097 (1.05 MB)
#  Trainable params: 276,097 (1.05 MB)
#  Non-trainable params: 0 (0.00 B)
# None
#
# 🚀 Iniciando treinamento...
# Epoch 1/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 0.2239 - mae: 0.3408 - val_loss: 0.2376 - val_mae: 0.3759 - learning_rate: 5.0000e-04
# Epoch 2/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0795 - mae: 0.2178 - val_loss: 0.2143 - val_mae: 0.3559 - learning_rate: 5.0000e-04
# Epoch 3/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0704 - mae: 0.2011 - val_loss: 0.1652 - val_mae: 0.3098 - learning_rate: 5.0000e-04
# Epoch 4/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0517 - mae: 0.1732 - val_loss: 0.1711 - val_mae: 0.3070 - learning_rate: 5.0000e-04
# Epoch 5/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0491 - mae: 0.1667 - val_loss: 0.1944 - val_mae: 0.3371 - learning_rate: 5.0000e-04
# Epoch 6/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0470 - mae: 0.1609 - val_loss: 0.1405 - val_mae: 0.2784 - learning_rate: 5.0000e-04
# Epoch 7/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0446 - mae: 0.1608 - val_loss: 0.1585 - val_mae: 0.2980 - learning_rate: 5.0000e-04
# Epoch 8/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0465 - mae: 0.1608 - val_loss: 0.1390 - val_mae: 0.2785 - learning_rate: 5.0000e-04
# Epoch 9/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0446 - mae: 0.1632 - val_loss: 0.1371 - val_mae: 0.2783 - learning_rate: 5.0000e-04
# Epoch 10/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0349 - mae: 0.1400 - val_loss: 0.2009 - val_mae: 0.3563 - learning_rate: 5.0000e-04
# Epoch 11/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0398 - mae: 0.1491 - val_loss: 0.1154 - val_mae: 0.2499 - learning_rate: 5.0000e-04
# Epoch 12/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0386 - mae: 0.1514 - val_loss: 0.2762 - val_mae: 0.4197 - learning_rate: 5.0000e-04
# Epoch 13/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0357 - mae: 0.1412 - val_loss: 0.2432 - val_mae: 0.3998 - learning_rate: 5.0000e-04
# Epoch 14/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0358 - mae: 0.1436 - val_loss: 0.2321 - val_mae: 0.3941 - learning_rate: 5.0000e-04
# Epoch 15/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0310 - mae: 0.1316 - val_loss: 0.1814 - val_mae: 0.3265 - learning_rate: 5.0000e-04
# Epoch 16/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0351 - mae: 0.1396 - val_loss: 0.2667 - val_mae: 0.4342 - learning_rate: 5.0000e-04
# Epoch 17/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0369 - mae: 0.1442 - val_loss: 0.1441 - val_mae: 0.2809 - learning_rate: 5.0000e-04
# Epoch 18/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0390 - mae: 0.1449 - val_loss: 0.1929 - val_mae: 0.3513 - learning_rate: 5.0000e-04
# Epoch 19/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0326 - mae: 0.1339 - val_loss: 0.1961 - val_mae: 0.3484 - learning_rate: 5.0000e-04
# Epoch 20/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0326 - mae: 0.1356 - val_loss: 0.1587 - val_mae: 0.2995 - learning_rate: 5.0000e-04
# Epoch 21/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0304 - mae: 0.1287 - val_loss: 0.1221 - val_mae: 0.2608 - learning_rate: 5.0000e-04
# Epoch 22/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0320 - mae: 0.1345 - val_loss: 0.1963 - val_mae: 0.3395 - learning_rate: 5.0000e-04
# Epoch 23/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0323 - mae: 0.1336 - val_loss: 0.1744 - val_mae: 0.3187 - learning_rate: 5.0000e-04
# Epoch 24/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0290 - mae: 0.1256 - val_loss: 0.1597 - val_mae: 0.3025 - learning_rate: 5.0000e-04
# Epoch 25/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0284 - mae: 0.1276 - val_loss: 0.2467 - val_mae: 0.3911 - learning_rate: 5.0000e-04
# Epoch 26/300
# 48/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0350 - mae: 0.1398
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0333 - mae: 0.1347 - val_loss: 0.2655 - val_mae: 0.4248 - learning_rate: 5.0000e-04
# Epoch 27/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0332 - mae: 0.1362 - val_loss: 0.3371 - val_mae: 0.4942 - learning_rate: 2.5000e-04
# Epoch 28/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0253 - mae: 0.1164 - val_loss: 0.3304 - val_mae: 0.4888 - learning_rate: 2.5000e-04
# Epoch 29/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0256 - mae: 0.1203 - val_loss: 0.1802 - val_mae: 0.3209 - learning_rate: 2.5000e-04
# Epoch 30/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0228 - mae: 0.1123 - val_loss: 0.2516 - val_mae: 0.4018 - learning_rate: 2.5000e-04
# Epoch 31/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0257 - mae: 0.1195 - val_loss: 0.1484 - val_mae: 0.2821 - learning_rate: 2.5000e-04
# Epoch 32/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0256 - mae: 0.1173 - val_loss: 0.1607 - val_mae: 0.2962 - learning_rate: 2.5000e-04
# Epoch 33/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0255 - mae: 0.1178 - val_loss: 0.2486 - val_mae: 0.4041 - learning_rate: 2.5000e-04
# Epoch 34/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0259 - mae: 0.1172 - val_loss: 0.3070 - val_mae: 0.4671 - learning_rate: 2.5000e-04
# Epoch 35/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0261 - mae: 0.1226 - val_loss: 0.1785 - val_mae: 0.3192 - learning_rate: 2.5000e-04
# Epoch 36/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0251 - mae: 0.1194 - val_loss: 0.1884 - val_mae: 0.3386 - learning_rate: 2.5000e-04
# Epoch 37/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0254 - mae: 0.1185 - val_loss: 0.2701 - val_mae: 0.4284 - learning_rate: 2.5000e-04
# Epoch 38/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0245 - mae: 0.1170 - val_loss: 0.1934 - val_mae: 0.3348 - learning_rate: 2.5000e-04
# Epoch 39/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0248 - mae: 0.1192 - val_loss: 0.1899 - val_mae: 0.3302 - learning_rate: 2.5000e-04
# Epoch 40/300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0255 - mae: 0.1184 - val_loss: 0.2259 - val_mae: 0.3727 - learning_rate: 2.5000e-04
# Epoch 41/300
# 48/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0214 - mae: 0.1076
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0214 - mae: 0.1081 - val_loss: 0.2527 - val_mae: 0.4132 - learning_rate: 2.5000e-04
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 11.
# ✓ Modelo salvo em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro/BEEF3.SA_Janela_10_model.keras
#
# 📊 RESULTADOS:
# MAE: 0.7250 | MSE: 0.7493 | RMSE: 0.8656 | R²: 0.7776
# Variação Real: 0.1914 | Variação Prevista: 0.1687
# Previsões travadas? Não
# ✓ Experimento concluído!
#
#
# ============================================================
# TRANSFORMER MACRO - BEEF3.SA, Janela 15
# ============================================================
# ✓ Shape X_train: (1081, 15, 5), y_train: (1081,)
# ✓ Shape X_test: (350, 15, 5), y_test: (350,)
# ✓ Input shape: (15, 5)
# Model: "TemporalFusionTransformer"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 15, 5)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 15, 128)   │        768 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 15, 128)   │          0 │ dense_16[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 15, 128)   │     66,048 │ add_10[0][0],     │
# │ (MultiHeadAttentio… │                   │            │ add_10[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 15, 128)   │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 15, 128)   │          0 │ add_10[0][0],     │
# │                     │                   │            │ dropout_21[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 15, 128)   │        256 │ add_11[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 15, 256)   │     33,024 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 15, 256)   │          0 │ dense_17[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 15, 128)   │     32,896 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 15, 128)   │          0 │ dense_18[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 15, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_23[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 15, 128)   │        256 │ add_12[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 15, 128)   │     66,048 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 15, 128)   │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 15, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_25[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 15, 128)   │        256 │ add_13[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 15, 256)   │     33,024 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 15, 256)   │          0 │ dense_19[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 15, 128)   │     32,896 │ dropout_26[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_27          │ (None, 15, 128)   │          0 │ dense_20[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 15, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_27[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 15, 128)   │        256 │ add_14[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 64)        │      8,256 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_28          │ (None, 64)        │          0 │ dense_21[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 32)        │      2,080 │ dropout_28[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_29          │ (None, 32)        │          0 │ dense_22[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 1)         │         33 │ dropout_29[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 276,097 (1.05 MB)
#  Trainable params: 276,097 (1.05 MB)
#  Non-trainable params: 0 (0.00 B)
# None
#
# 🚀 Iniciando treinamento...
# Epoch 1/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.4216 - mae: 0.4593 - val_loss: 0.2349 - val_mae: 0.3861 - learning_rate: 5.0000e-04
# Epoch 2/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1149 - mae: 0.2578 - val_loss: 0.1713 - val_mae: 0.3217 - learning_rate: 5.0000e-04
# Epoch 3/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0802 - mae: 0.2173 - val_loss: 0.1997 - val_mae: 0.3370 - learning_rate: 5.0000e-04
# Epoch 4/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0602 - mae: 0.1908 - val_loss: 0.1392 - val_mae: 0.2802 - learning_rate: 5.0000e-04
# Epoch 5/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0524 - mae: 0.1731 - val_loss: 0.2202 - val_mae: 0.3588 - learning_rate: 5.0000e-04
# Epoch 6/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0501 - mae: 0.1706 - val_loss: 0.1884 - val_mae: 0.3264 - learning_rate: 5.0000e-04
# Epoch 7/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0399 - mae: 0.1533 - val_loss: 0.1822 - val_mae: 0.3291 - learning_rate: 5.0000e-04
# Epoch 8/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0427 - mae: 0.1566 - val_loss: 0.2296 - val_mae: 0.3797 - learning_rate: 5.0000e-04
# Epoch 9/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0407 - mae: 0.1555 - val_loss: 0.3365 - val_mae: 0.4709 - learning_rate: 5.0000e-04
# Epoch 10/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0482 - mae: 0.1696 - val_loss: 0.2757 - val_mae: 0.4203 - learning_rate: 5.0000e-04
# Epoch 11/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0367 - mae: 0.1450 - val_loss: 0.1438 - val_mae: 0.2875 - learning_rate: 5.0000e-04
# Epoch 12/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0379 - mae: 0.1466 - val_loss: 0.4016 - val_mae: 0.5637 - learning_rate: 5.0000e-04
# Epoch 13/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0391 - mae: 0.1566 - val_loss: 0.3618 - val_mae: 0.4930 - learning_rate: 5.0000e-04
# Epoch 14/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0397 - mae: 0.1500 - val_loss: 0.2465 - val_mae: 0.3967 - learning_rate: 5.0000e-04
# Epoch 15/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0359 - mae: 0.1442 - val_loss: 0.3672 - val_mae: 0.5144 - learning_rate: 5.0000e-04
# Epoch 16/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0322 - mae: 0.1332 - val_loss: 0.2220 - val_mae: 0.3690 - learning_rate: 5.0000e-04
# Epoch 17/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0353 - mae: 0.1399 - val_loss: 0.4856 - val_mae: 0.6321 - learning_rate: 5.0000e-04
# Epoch 18/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0343 - mae: 0.1438 - val_loss: 0.1207 - val_mae: 0.2671 - learning_rate: 5.0000e-04
# Epoch 19/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0329 - mae: 0.1373 - val_loss: 0.1316 - val_mae: 0.2750 - learning_rate: 5.0000e-04
# Epoch 20/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0312 - mae: 0.1348 - val_loss: 0.1294 - val_mae: 0.2699 - learning_rate: 5.0000e-04
# Epoch 21/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0318 - mae: 0.1360 - val_loss: 0.2482 - val_mae: 0.3960 - learning_rate: 5.0000e-04
# Epoch 22/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0303 - mae: 0.1336 - val_loss: 0.2133 - val_mae: 0.3610 - learning_rate: 5.0000e-04
# Epoch 23/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0328 - mae: 0.1333 - val_loss: 0.2203 - val_mae: 0.3715 - learning_rate: 5.0000e-04
# Epoch 24/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0337 - mae: 0.1321 - val_loss: 0.3230 - val_mae: 0.4826 - learning_rate: 5.0000e-04
# Epoch 25/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0302 - mae: 0.1339 - val_loss: 0.1026 - val_mae: 0.2420 - learning_rate: 5.0000e-04
# Epoch 26/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0334 - mae: 0.1400 - val_loss: 0.2531 - val_mae: 0.4163 - learning_rate: 5.0000e-04
# Epoch 27/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0289 - mae: 0.1296 - val_loss: 0.2163 - val_mae: 0.3675 - learning_rate: 5.0000e-04
# Epoch 28/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0310 - mae: 0.1313 - val_loss: 0.2686 - val_mae: 0.4169 - learning_rate: 5.0000e-04
# Epoch 29/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0278 - mae: 0.1233 - val_loss: 0.3093 - val_mae: 0.4656 - learning_rate: 5.0000e-04
# Epoch 30/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0282 - mae: 0.1259 - val_loss: 0.2897 - val_mae: 0.4407 - learning_rate: 5.0000e-04
# Epoch 31/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0267 - mae: 0.1226 - val_loss: 0.1903 - val_mae: 0.3382 - learning_rate: 5.0000e-04
# Epoch 32/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0294 - mae: 0.1278 - val_loss: 0.1792 - val_mae: 0.3325 - learning_rate: 5.0000e-04
# Epoch 33/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0295 - mae: 0.1293 - val_loss: 0.3005 - val_mae: 0.4658 - learning_rate: 5.0000e-04
# Epoch 34/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0267 - mae: 0.1212 - val_loss: 0.2728 - val_mae: 0.4306 - learning_rate: 5.0000e-04
# Epoch 35/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0262 - mae: 0.1227 - val_loss: 0.3487 - val_mae: 0.4898 - learning_rate: 5.0000e-04
# Epoch 36/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0263 - mae: 0.1224 - val_loss: 0.2575 - val_mae: 0.4051 - learning_rate: 5.0000e-04
# Epoch 37/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0255 - mae: 0.1199 - val_loss: 0.2427 - val_mae: 0.3926 - learning_rate: 5.0000e-04
# Epoch 38/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0229 - mae: 0.1154 - val_loss: 0.2861 - val_mae: 0.4429 - learning_rate: 5.0000e-04
# Epoch 39/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0256 - mae: 0.1212 - val_loss: 0.3369 - val_mae: 0.4826 - learning_rate: 5.0000e-04
# Epoch 40/300
# 49/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0275 - mae: 0.1236
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0272 - mae: 0.1237 - val_loss: 0.2947 - val_mae: 0.4404 - learning_rate: 5.0000e-04
# Epoch 41/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0242 - mae: 0.1175 - val_loss: 0.2868 - val_mae: 0.4345 - learning_rate: 2.5000e-04
# Epoch 42/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0228 - mae: 0.1130 - val_loss: 0.2708 - val_mae: 0.4230 - learning_rate: 2.5000e-04
# Epoch 43/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0212 - mae: 0.1094 - val_loss: 0.1993 - val_mae: 0.3474 - learning_rate: 2.5000e-04
# Epoch 44/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0236 - mae: 0.1141 - val_loss: 0.2897 - val_mae: 0.4382 - learning_rate: 2.5000e-04
# Epoch 45/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0211 - mae: 0.1089 - val_loss: 0.2841 - val_mae: 0.4346 - learning_rate: 2.5000e-04
# Epoch 46/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0227 - mae: 0.1130 - val_loss: 0.3988 - val_mae: 0.5342 - learning_rate: 2.5000e-04
# Epoch 47/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0225 - mae: 0.1106 - val_loss: 0.3296 - val_mae: 0.4728 - learning_rate: 2.5000e-04
# Epoch 48/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0210 - mae: 0.1092 - val_loss: 0.2886 - val_mae: 0.4393 - learning_rate: 2.5000e-04
# Epoch 49/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0197 - mae: 0.1043 - val_loss: 0.3393 - val_mae: 0.4841 - learning_rate: 2.5000e-04
# Epoch 50/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0203 - mae: 0.1064 - val_loss: 0.2760 - val_mae: 0.4217 - learning_rate: 2.5000e-04
# Epoch 51/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0222 - mae: 0.1108 - val_loss: 0.2906 - val_mae: 0.4327 - learning_rate: 2.5000e-04
# Epoch 52/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0207 - mae: 0.1086 - val_loss: 0.2502 - val_mae: 0.3939 - learning_rate: 2.5000e-04
# Epoch 53/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0209 - mae: 0.1102 - val_loss: 0.3252 - val_mae: 0.4733 - learning_rate: 2.5000e-04
# Epoch 54/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0208 - mae: 0.1070 - val_loss: 0.2783 - val_mae: 0.4282 - learning_rate: 2.5000e-04
# Epoch 55/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0194 - mae: 0.1060
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0203 - mae: 0.1079 - val_loss: 0.3962 - val_mae: 0.5328 - learning_rate: 2.5000e-04
# Epoch 55: early stopping
# Restoring model weights from the end of the best epoch: 25.
# ✓ Modelo salvo em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro/BEEF3.SA_Janela_15_model.keras
#
# 📊 RESULTADOS:
# MAE: 0.6886 | MSE: 0.8138 | RMSE: 0.9021 | R²: 0.7378
# Variação Real: 0.1850 | Variação Prevista: 0.1851
# Previsões travadas? Não
# ✓ Experimento concluído!
#
#
# ============================================================
# TRANSFORMER MACRO - BEEF3.SA, Janela 20
# ============================================================
# ✓ Shape X_train: (1076, 20, 5), y_train: (1076,)
# ✓ Shape X_test: (345, 20, 5), y_test: (345,)
# ✓ Input shape: (20, 5)
# Model: "TemporalFusionTransformer"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 20, 5)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_24 (Dense)    │ (None, 20, 128)   │        768 │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 20, 128)   │          0 │ dense_24[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 20, 128)   │     66,048 │ add_15[0][0],     │
# │ (MultiHeadAttentio… │                   │            │ add_15[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_31          │ (None, 20, 128)   │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 20, 128)   │          0 │ add_15[0][0],     │
# │                     │                   │            │ dropout_31[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 20, 128)   │        256 │ add_16[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_25 (Dense)    │ (None, 20, 256)   │     33,024 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_32          │ (None, 20, 256)   │          0 │ dense_25[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_26 (Dense)    │ (None, 20, 128)   │     32,896 │ dropout_32[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_33          │ (None, 20, 128)   │          0 │ dense_26[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 20, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_33[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 20, 128)   │        256 │ add_17[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 20, 128)   │     66,048 │ layer_normalizat… │
# ...
# Epoch 40/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0378 - mae: 0.1491 - val_loss: 0.0696 - val_mae: 0.2230 - learning_rate: 2.5000e-04
# Epoch 41/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0344 - mae: 0.1444 - val_loss: 0.0525 - val_mae: 0.1967 - learning_rate: 2.5000e-04
# Epoch 42/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0328 - mae: 0.1377 - val_loss: 0.0743 - val_mae: 0.2311 - learning_rate: 2.5000e-04
# Epoch 43/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0374 - mae: 0.1438 - val_loss: 0.0551 - val_mae: 0.1993 - learning_rate: 2.5000e-04
# Epoch 44/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0320 - mae: 0.1332 - val_loss: 0.0586 - val_mae: 0.2078 - learning_rate: 2.5000e-04
# Epoch 45/300
# 50/54 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0348 - mae: 0.1425
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0333 - mae: 0.1382 - val_loss: 0.0498 - val_mae: 0.1912 - learning_rate: 2.5000e-04
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 15.
# ✓ Modelo salvo em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro/SUZB3.SA_Janela_15_model.keras
#
# 📊 RESULTADOS:
# MAE: 1.5964 | MSE: 3.5426 | RMSE: 1.8822 | R²: 0.8318
# Variação Real: 0.1006 | Variação Prevista: 0.0693
# Previsões travadas? Não
# ✓ Experimento concluído!
#
#
# ============================================================
# TRANSFORMER MACRO - SUZB3.SA, Janela 20
# ============================================================
# ✓ Shape X_train: (1076, 20, 5), y_train: (1076,)
# ✓ Shape X_test: (345, 20, 5), y_test: (345,)
# ✓ Input shape: (20, 5)
# Model: "TemporalFusionTransformer"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_31      │ (None, 20, 5)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_248 (Dense)   │ (None, 20, 128)   │        768 │ input_layer_31[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_155 (Add)       │ (None, 20, 128)   │          0 │ dense_248[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 20, 128)   │     66,048 │ add_155[0][0],    │
# │ (MultiHeadAttentio… │                   │            │ add_155[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_311         │ (None, 20, 128)   │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_156 (Add)       │ (None, 20, 128)   │          0 │ add_155[0][0],    │
# │                     │                   │            │ dropout_311[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 20, 128)   │        256 │ add_156[0][0]     │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_249 (Dense)   │ (None, 20, 256)   │     33,024 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_312         │ (None, 20, 256)   │          0 │ dense_249[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_250 (Dense)   │ (None, 20, 128)   │     32,896 │ dropout_312[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_313         │ (None, 20, 128)   │          0 │ dense_250[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_157 (Add)       │ (None, 20, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_313[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 20, 128)   │        256 │ add_157[0][0]     │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 20, 128)   │     66,048 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_315         │ (None, 20, 128)   │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_158 (Add)       │ (None, 20, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_315[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 20, 128)   │        256 │ add_158[0][0]     │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_251 (Dense)   │ (None, 20, 256)   │     33,024 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_316         │ (None, 20, 256)   │          0 │ dense_251[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_252 (Dense)   │ (None, 20, 128)   │     32,896 │ dropout_316[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_317         │ (None, 20, 128)   │          0 │ dense_252[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_159 (Add)       │ (None, 20, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_317[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 20, 128)   │        256 │ add_159[0][0]     │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_253 (Dense)   │ (None, 64)        │      8,256 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_318         │ (None, 64)        │          0 │ dense_253[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_254 (Dense)   │ (None, 32)        │      2,080 │ dropout_318[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_319         │ (None, 32)        │          0 │ dense_254[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_255 (Dense)   │ (None, 1)         │         33 │ dropout_319[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 276,097 (1.05 MB)
#  Trainable params: 276,097 (1.05 MB)
#  Non-trainable params: 0 (0.00 B)
# None
#
# 🚀 Iniciando treinamento...
# Epoch 1/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.3374 - mae: 0.4351 - val_loss: 0.0882 - val_mae: 0.2470 - learning_rate: 5.0000e-04
# Epoch 2/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1532 - mae: 0.3032 - val_loss: 0.0736 - val_mae: 0.2264 - learning_rate: 5.0000e-04
# Epoch 3/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1312 - mae: 0.2718 - val_loss: 0.1102 - val_mae: 0.2852 - learning_rate: 5.0000e-04
# Epoch 4/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0897 - mae: 0.2261 - val_loss: 0.0185 - val_mae: 0.1084 - learning_rate: 5.0000e-04
# Epoch 5/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0877 - mae: 0.2215 - val_loss: 0.0246 - val_mae: 0.1302 - learning_rate: 5.0000e-04
# Epoch 6/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0691 - mae: 0.1930 - val_loss: 0.0573 - val_mae: 0.2057 - learning_rate: 5.0000e-04
# Epoch 7/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0625 - mae: 0.1899 - val_loss: 0.0220 - val_mae: 0.1214 - learning_rate: 5.0000e-04
# Epoch 8/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0655 - mae: 0.1936 - val_loss: 0.0280 - val_mae: 0.1365 - learning_rate: 5.0000e-04
# Epoch 9/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0628 - mae: 0.1917 - val_loss: 0.0214 - val_mae: 0.1139 - learning_rate: 5.0000e-04
# Epoch 10/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0519 - mae: 0.1724 - val_loss: 0.0307 - val_mae: 0.1450 - learning_rate: 5.0000e-04
# Epoch 11/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0538 - mae: 0.1731 - val_loss: 0.0215 - val_mae: 0.1180 - learning_rate: 5.0000e-04
# Epoch 12/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0640 - mae: 0.1888 - val_loss: 0.0161 - val_mae: 0.1045 - learning_rate: 5.0000e-04
# Epoch 13/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0627 - mae: 0.1900 - val_loss: 0.0813 - val_mae: 0.2462 - learning_rate: 5.0000e-04
# Epoch 14/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0527 - mae: 0.1736 - val_loss: 0.0374 - val_mae: 0.1579 - learning_rate: 5.0000e-04
# Epoch 15/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0459 - mae: 0.1649 - val_loss: 0.0286 - val_mae: 0.1378 - learning_rate: 5.0000e-04
# Epoch 16/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0505 - mae: 0.1687 - val_loss: 0.0290 - val_mae: 0.1423 - learning_rate: 5.0000e-04
# Epoch 17/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0463 - mae: 0.1650 - val_loss: 0.0284 - val_mae: 0.1312 - learning_rate: 5.0000e-04
# Epoch 18/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0504 - mae: 0.1723 - val_loss: 0.0349 - val_mae: 0.1444 - learning_rate: 5.0000e-04
# Epoch 19/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0422 - mae: 0.1572 - val_loss: 0.0198 - val_mae: 0.1152 - learning_rate: 5.0000e-04
# Epoch 20/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0472 - mae: 0.1668 - val_loss: 0.0166 - val_mae: 0.1040 - learning_rate: 5.0000e-04
# Epoch 21/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0426 - mae: 0.1555 - val_loss: 0.0237 - val_mae: 0.1262 - learning_rate: 5.0000e-04
# Epoch 22/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0427 - mae: 0.1536 - val_loss: 0.0341 - val_mae: 0.1530 - learning_rate: 5.0000e-04
# Epoch 23/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0490 - mae: 0.1708 - val_loss: 0.0393 - val_mae: 0.1668 - learning_rate: 5.0000e-04
# Epoch 24/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0448 - mae: 0.1589 - val_loss: 0.0265 - val_mae: 0.1351 - learning_rate: 5.0000e-04
# Epoch 25/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0408 - mae: 0.1542 - val_loss: 0.0298 - val_mae: 0.1417 - learning_rate: 5.0000e-04
# Epoch 26/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0423 - mae: 0.1549 - val_loss: 0.0276 - val_mae: 0.1366 - learning_rate: 5.0000e-04
# Epoch 27/300
# 51/54 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0376 - mae: 0.1494
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0417 - mae: 0.1554 - val_loss: 0.0235 - val_mae: 0.1241 - learning_rate: 5.0000e-04
# Epoch 28/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0428 - mae: 0.1525 - val_loss: 0.0557 - val_mae: 0.2012 - learning_rate: 2.5000e-04
# Epoch 29/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0389 - mae: 0.1487 - val_loss: 0.0246 - val_mae: 0.1277 - learning_rate: 2.5000e-04
# Epoch 30/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0381 - mae: 0.1431 - val_loss: 0.0435 - val_mae: 0.1758 - learning_rate: 2.5000e-04
# Epoch 31/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0415 - mae: 0.1490 - val_loss: 0.0333 - val_mae: 0.1516 - learning_rate: 2.5000e-04
# Epoch 32/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0312 - mae: 0.1322 - val_loss: 0.0231 - val_mae: 0.1243 - learning_rate: 2.5000e-04
# Epoch 33/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0369 - mae: 0.1404 - val_loss: 0.0291 - val_mae: 0.1407 - learning_rate: 2.5000e-04
# Epoch 34/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0357 - mae: 0.1399 - val_loss: 0.0289 - val_mae: 0.1415 - learning_rate: 2.5000e-04
# Epoch 35/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0331 - mae: 0.1364 - val_loss: 0.0462 - val_mae: 0.1795 - learning_rate: 2.5000e-04
# Epoch 36/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0377 - mae: 0.1399 - val_loss: 0.0325 - val_mae: 0.1509 - learning_rate: 2.5000e-04
# Epoch 37/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0351 - mae: 0.1377 - val_loss: 0.0315 - val_mae: 0.1477 - learning_rate: 2.5000e-04
# Epoch 38/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0370 - mae: 0.1446 - val_loss: 0.0328 - val_mae: 0.1515 - learning_rate: 2.5000e-04
# Epoch 39/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0346 - mae: 0.1400 - val_loss: 0.0302 - val_mae: 0.1444 - learning_rate: 2.5000e-04
# Epoch 40/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0357 - mae: 0.1387 - val_loss: 0.0413 - val_mae: 0.1719 - learning_rate: 2.5000e-04
# Epoch 41/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0383 - mae: 0.1453 - val_loss: 0.0338 - val_mae: 0.1544 - learning_rate: 2.5000e-04
# Epoch 42/300
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0293 - mae: 0.1278
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0333 - mae: 0.1368 - val_loss: 0.0392 - val_mae: 0.1692 - learning_rate: 2.5000e-04
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 12.
# ✓ Modelo salvo em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro/SUZB3.SA_Janela_20_model.keras
#
# 📊 RESULTADOS:
# MAE: 1.4666 | MSE: 3.2828 | RMSE: 1.8119 | R²: 0.8461
# Variação Real: 0.1012 | Variação Prevista: 0.0707
# Previsões travadas? Não
# ✓ Experimento concluído!
#
#
# ============================================================
# 📈 RESUMO DOS RESULTADOS
# ============================================================
#                MAE      RMSE        R2
# Ticker
# BEEF3.SA  0.688821  0.875353  0.758477
# BRFS3.SA  2.560163  2.925924 -0.467438
# CSNA3.SA  1.160932  1.367749  0.533197
# GGBR3.SA  1.549971  1.720561 -1.720403
# JBSS3.SA  1.920103  2.054846 -0.050397
# SOJA3.SA  0.767571  0.908110  0.635569
# SUZB3.SA  1.411992  1.703323  0.859827
# VALE3.SA  1.655169  2.064078  0.900302
#
# ✓ Resultados salvos em: C:\Users\leona\OneDrive\Área de Trabalho\Machine-Learning---Stock-Prediction\CodigoTransformers\resultados_transformer_macro/resultados_consolidados_transformer.csv
#
# ============================================================
# ✅ TODOS EXPERIMENTOS CONCLUÍDOS!
# ============================================================
